# %% [markdown]
# # Data Cleaning
# Sonia Castelo Quispe (scq202@nyu.edu)

# %% [markdown]
# ## Cleaning Parking Violations

# %% [markdown]
# Start Spark for Python (pyspark):

# %%
from pyspark import SparkContext, SparkConf
cf = SparkConf()
cf.set("spark.submit.deployMode","client")
sc = SparkContext.getOrCreate(cf)
from pyspark.sql import SparkSession
spark = SparkSession \
	    .builder \
	    .appName("Python Spark SQL basic example") \
	    .config("spark.some.config.option", "some-value") \
	    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/04/20 03:50:17 INFO org.apache.spark.SparkEnv: Registering MapOutputTracker
# 23/04/20 03:50:17 INFO org.apache.spark.SparkEnv: Registering BlockManagerMaster
# 23/04/20 03:50:17 INFO org.apache.spark.SparkEnv: Registering BlockManagerMasterHeartbeat
# 23/04/20 03:50:17 INFO org.apache.spark.SparkEnv: Registering OutputCommitCoordinator

# %% [markdown]
# Load the CSV file:

# %%
parking_df = spark.read.csv(path='/shared/CS-GY-6513/parking-violations/parking-violations-header.csv',header=True)

# %% [markdown]
# ### Check data

# %%
# Check the columns by looking at the schema
parking_df.printSchema()
# Out:
# root
#  |-- summons_number: string (nullable = true)
#  |-- issue_date: string (nullable = true)
#  |-- violation_code: string (nullable = true)
#  |-- violation_county: string (nullable = true)
#  |-- violation_description: string (nullable = true)
#  |-- violation_location: string (nullable = true)
#  |-- violation_precinct: string (nullable = true)
#  |-- violation_time: string (nullable = true)
#  |-- time_first_observed: string (nullable = true)
#  |-- meter_number: string (nullable = true)
#  |-- issuer_code: string (nullable = true)
#  |-- issuer_command: string (nullable = true)
#  |-- issuer_precinct: string (nullable = true)
#  |-- issuing_agency: string (nullable = true)
#  |-- plate_id: string (nullable = true)
#  |-- plate_type: string (nullable = true)
#  |-- registration_state: string (nullable = true)
#  |-- street_name: string (nullable = true)
#  |-- vehicle_body_type: string (nullable = true)
#  |-- vehicle_color: string (nullable = true)
#  |-- vehicle_make: string (nullable = true)
#  |-- vehicle_year: string (nullable = true)

# %%
# Display 2 rows & columns vertically to see how the data look like.
parking_df.show(2, vertical=True)
# Out:
# -RECORD 0------------------------------
#  summons_number        | 1307964308
#  issue_date            | 2016-03-07
#  violation_code        | 14
#  violation_county      | NY
#  violation_description | null
#  violation_location    | 1
#  violation_precinct    | 1
#  violation_time        | 1040P
#  time_first_observed   | null
#  meter_number          | -
#  issuer_code           | 160307
#  issuer_command        | 0001
#  issuer_precinct       | 1
#  issuing_agency        | K
#  plate_id              | GBH2444
#  plate_type            | PAS
#  registration_state    | NY
#  street_name           | N/S WARREN ST
#  vehicle_body_type     | SDN
#  vehicle_color         | BLACK
#  vehicle_make          | HONDA
#  vehicle_year          | 2008
# -RECORD 1------------------------------
#  summons_number        | 1362655727
#  issue_date            | 2016-03-02
#  violation_code        | 98
#  violation_county      | BX
#  violation_description | null
#  violation_location    | 45
#  violation_precinct    | 45
#  violation_time        | 0910P
#  time_first_observed   | null
#  meter_number          | -
#  issuer_code           | 945115
#  issuer_command        | 0043
#  issuer_precinct       | 43
#  issuing_agency        | X
#  plate_id              | GKZ2313
#  plate_type            | PAS
#  registration_state    | NY
#  street_name           | PHILPS
#  vehicle_body_type     | SUBN
#  vehicle_color         | WHITE
#  vehicle_make          | JEEP
#  vehicle_year          | 1999
# only showing top 2 rows

# %%
# Show the statistics
parking_df.describe().show(vertical=True)
# Out:
# [Stage 2:===================================================>       (7 + 1) / 8]
# -RECORD 0-------------------------------------
#  summary               | count
#  summons_number        | 1014017
#  issue_date            | 1014017
#  violation_code        | 1014017
#  violation_county      | 821043
#  violation_description | 912310
#  violation_location    | 1014017
#  violation_precinct    | 1014017
#  violation_time        | 1014003
#  time_first_observed   | 113101
#  meter_number          | 179551
#  issuer_code           | 1014017
#  issuer_command        | 824678
#  issuer_precinct       | 1014017
#  issuing_agency        | 1014017
#  plate_id              | 1014017
#  plate_type            | 1014017
#  registration_state    | 1014017
#  street_name           | 1013615
#  vehicle_body_type     | 1010433
#  vehicle_color         | 1001041
#  vehicle_make          | 1008101
#  vehicle_year          | 1014017
# -RECORD 1-------------------------------------
#  summary               | mean
#  summons_number        | 6.546786384382384E9
#  issue_date            | null
#  violation_code        | 34.99229105626434
#  violation_county      | null
#  violation_description | null
#  violation_location    | 43.5931212198612
#  violation_precinct    | 43.78075219646219
#  violation_time        | null
#  time_first_observed   | 1051.5833333333333
#  meter_number          | null
#  issuer_code           | 337682.3721121046
#  issuer_command        | 99.14423207449842
#  issuer_precinct       | 45.63472210031982
#  issuing_agency        | null
#  plate_id              | Infinity
#  plate_type            | 999.0
#  registration_state    | 99.0
#  street_name           | 265.75471698113205
#  vehicle_body_type     | 3.9745504840940526
#  vehicle_color         | 14.0
#  vehicle_make          | 1684.8
#  vehicle_year          | 1567.1328735119826
# -RECORD 2-------------------------------------
#  summary               | stddev
#  summons_number        | 2.116995809493249E9
#  issue_date            | null
#  violation_code        | 18.650282858459995
#  violation_county      | null
#  violation_description | null
#  violation_location    | 40.28744820809242
#  violation_precinct    | 40.0811276112853
#  violation_time        | null
#  time_first_observed   | 567.7346464571973
#  meter_number          | null
#  issuer_code           | 224340.8715627861
#  issuer_command        | 189.33282221123898
#  issuer_precinct       | 59.68455946813706
#  issuing_agency        | null
#  plate_id              | NaN
#  plate_type            | 0.0
#  registration_state    | 0.0
#  street_name           | 662.4060138168913
#  vehicle_body_type     | 2.9028571428399226
#  vehicle_color         | null
#  vehicle_make          | 3595.484696115393
#  vehicle_year          | 832.3590905314855
# -RECORD 3-------------------------------------
#  summary               | min
#  summons_number        | 1017773075
#  issue_date            | 2016-03-01
#  violation_code        | 1
#  violation_county      | BX
#  violation_description | 01-No Intercity P...
#  violation_location    | -1
#  violation_precinct    | 0
#  violation_time        | 0000A
#  time_first_observed   | 0000A
#  meter_number          | -
#  issuer_code           | 0
#  issuer_command        | 00 2
#  issuer_precinct       | 0
#  issuing_agency        | A
#  plate_id              | #1MDM
#  plate_type            | 999
#  registration_state    | 99
#  street_name           | -100 STREET
#  vehicle_body_type     | 00
#  vehicle_color         | 14
#  vehicle_make          | .
#  vehicle_year          | 0
# -RECORD 4-------------------------------------
#  summary               | max
#  summons_number        | 8297500482
#  issue_date            | 2016-03-31
#  violation_code        | 99
#  violation_county      | R
#  violation_description | PHTO SCHOOL ZN SP...
#  violation_location    | 99
#  violation_precinct    | 99
#  violation_time        | 8725P
#  time_first_observed   | 2356P
#  meter_number          | 999-9999
#  issuer_code           | 999843
#  issuer_command        | Y506
#  issuer_precinct       | 992
#  issuing_agency        | X
#  plate_id              | ZZZCRNA
#  plate_type            | VPL
#  registration_state    | YT
#  street_name           | paerdegat south
#  vehicle_body_type     | ZQR
#  vehicle_color         | ZW
#  vehicle_make          | ZXYV
#  vehicle_year          | 2069

# %% [markdown]
# ### 1. Uniqueness Constraints
#
# Uniqueness Constraints or Key constraints: keys are unique across all tuples and null values are not allowed.

# %% [markdown]
# #### 1.1. Checking for Duplicates
# - Use ``parking_df.count()`` to check how many instances we have, then check how many distinct/unique values we have by using ``parking_df.select('summons_number').distinct().count()``. If there are more instances than distinct values, this would mean that we have duplicate keys.

# %%
# Check how many instances we have
total_instances = parking_df.count()
print('Count total number of instances      : ', total_instances)

# Check how many distinct/unique values we have
distinct_values = parking_df.select('summons_number').distinct().count()
print('Count total number of distinct values: ', distinct_values)
# Out:
# Count total number of instances      :  1014017
# [Stage 8:====================================>                      (5 + 3) / 8]
# Count total number of distinct values:  1014017

# %% [markdown]
# Based on the above results, we can conclude that the keys are uniques since both results are the same.

# %% [markdown]
# #### 1.2. Checking for Null values
# - In the below snippet ``isnan()`` is a SQL function that is used to check for NAN values and ``isNull()`` is a Column class function that is used to check for Null values.

# %%
from pyspark.sql.functions import col,isnan,when,count

df_Columns=["summons_number"]
parking_df.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in df_Columns]
   ).show()
# Out:
# +--------------+
# |summons_number|
# +--------------+
# |             0|
# +--------------+

# %% [markdown]
# Based on the above result, there are no null values.

# %% [markdown]
# ### Create a Temp Table

# %%
# Register the DataFrame as a SQL temporary view
parking_df.createOrReplaceTempView("parking")

# Testing
spark.sql("SELECT count(DISTINCT plate_type) FROM parking").show()
# Out:
# [Stage 17:==================================================>       (7 + 1) / 8]
# +--------------------------+
# |count(DISTINCT plate_type)|
# +--------------------------+
# |                        75|
# +--------------------------+

# %% [markdown]
# ### 2. Outliers and Anomalies in Dataset Columns
# One common profiling task is the detection of outliers (anomalies) in datasets. In our example we focus on outlier values in individual columns.

# %% [markdown]
# #### Plate ID
# This example looks at the distinct values in the column Plate ID.

# %%
# List the distinct plate types in the table. Display 20 rows 
spark.sql("SELECT DISTINCT plate_type FROM parking").show(20)
# Out:
# +----------+
# |plate_type|
# +----------+
# |       APP|
# |       RGL|
# |       CHC|
# |       CCK|
# |       CLG|
# |       NYA|
# |       FAR|
# |       BOT|
# |       SOS|
# |       SPC|
# |       SUP|
# |       OMO|
# |       LMB|
# |       STA|
# |       COM|
# |       HAM|
# |       NYS|
# |       RGC|
# |       TRC|
# |       BOB|
# +----------+
# only showing top 20 rows

# %% [markdown]
# #### Plate Type
# List each distinct ``plate type`` and its frequency in the table

# %%
# List each distinct plate type and its frequency in the table
# e.g.
#    plate_type count
#    PAS        740554
#    COM        190147
distinc_plate_type = spark.sql("SELECT DISTINCT plate_type, count(*) AS COUNT FROM parking GROUP BY plate_type")   
distinc_plate_type.show()
# Out:
# +----------+------+
# |plate_type| COUNT|
# +----------+------+
# |       APP|  1952|
# |       RGL|   524|
# |       CHC|    35|
# |       CCK|     2|
# |       CLG|     2|
# |       NYA|     3|
# |       FAR|     2|
# |       BOT|     2|
# |       SOS|    15|
# |       SPC|    28|
# |       SUP|     8|
# |       OMO|     2|
# |       LMB|     2|
# |       STA|    33|
# |       COM|190147|
# |       HAM|    19|
# |       NYS|     5|
# |       RGC|    25|
# |       TRC|  2784|
# |       BOB|     6|
# +----------+------+
# only showing top 20 rows

# %% [markdown]
# Order the results of the previous query by count, the most frequent should appear first.

# %%
# order the results of the previous query by count, the most frequent should appear first
order_distinc_plate_type = spark.sql("SELECT DISTINCT plate_type, count(*) AS COUNT FROM parking GROUP BY plate_type ORDER BY COUNT desc")   
order_distinc_plate_type.show()
# Out:
# +----------+------+
# |plate_type| COUNT|
# +----------+------+
# |       PAS|740554|
# |       COM|190147|
# |       OMT| 35480|
# |       OMS|  9032|
# |       SRF|  8341|
# |       IRP|  5291|
# |       999|  4467|
# |       TRC|  2784|
# |       OMR|  2158|
# |       APP|  1952|
# |       MOT|  1851|
# |       ORG|  1591|
# |       CMB|  1368|
# |       MED|  1211|
# |       OML|  1181|
# |       PSD|   900|
# |       SPO|   823|
# |       SCL|   700|
# |       TOW|   611|
# |       RGL|   524|
# +----------+------+
# only showing top 20 rows

# %% [markdown]
# Change ``plate_type`` 999 to null

# %%
# change plate_type 999 to null
from pyspark.sql import functions as F
parking_df2 = parking_df.withColumn('plate_type', F.when(parking_df['plate_type']=='999', 'null').otherwise(parking_df['plate_type']))
parking_df2.groupBy('plate_type').count().orderBy('count', ascending=False).show(26)
# Out:
# +----------+------+
# |plate_type| count|
# +----------+------+
# |       PAS|740554|
# |       COM|190147|
# |       OMT| 35480|
# |       OMS|  9032|
# |       SRF|  8341|
# |       IRP|  5291|
# |      null|  4467|
# |       TRC|  2784|
# |       OMR|  2158|
# |       APP|  1952|
# |       MOT|  1851|
# |       ORG|  1591|
# |       CMB|  1368|
# |       MED|  1211|
# |       OML|  1181|
# |       PSD|   900|
# |       SPO|   823|
# |       SCL|   700|
# |       TOW|   611|
# |       RGL|   524|
# |       VAS|   427|
# |       SRN|   348|
# |       DLR|   333|
# |       TRA|   318|
# |       ITP|   283|
# |       TRL|   223|
# +----------+------+
# only showing top 26 rows

# %% [markdown]
# Remove all rows where ``plate_type=999``

# %%
# remove all rows where plate_type=999
parking_df3 = parking_df.filter(parking_df["plate_type"] != '999')

print('Count total number of rows before filtering:               ', parking_df.count())
print('Count total number of rows after removing  plate_type=999: ', parking_df3.count())
# Out:
# Count total number of rows before filtering:                1014017
# Count total number of rows after removing  plate_type=999:  1009550

# %% [markdown]
# Based on the about results, we can see that ``4467`` rows contained ``plate_type=999``. They werer removed by using the filter function.

# %% [markdown]
# #### Violation County

# %% [markdown]
# Suppose we are interested in analyzing violations based on what county they occur. We might want to exclude rows that have a blank entry in the violation_county column.

# %%
# How many rows have Blank Entries in violation_county?
blank_entries_viocounty = parking_df.filter( parking_df["violation_county"].isNull()).count()

print('Count total number of rows with blank entries in violation_county: ', blank_entries_viocounty)
# Out:
# Count total number of rows with blank entries in violation_county:  192974

# %% [markdown]
# Check each distinct ``violation_county`` and its frequency in the table. Then order the results of the previous query by count, the most frequent should appear first

# %%
spark.sql("SELECT DISTINCT violation_county, count(*) AS COUNT FROM parking GROUP BY violation_county ORDER BY COUNT desc").show()
# Out:
# +----------------+------+
# |violation_county| COUNT|
# +----------------+------+
# |              NY|341628|
# |               K|207630|
# |            null|192974|
# |               Q|164615|
# |              BX| 98643|
# |               R|  8527|
# +----------------+------+

# %% [markdown]
# To clean this data, we can create a new dataframe without any black entries in violation_county.

# %%
# Create a new dataframe without any black entries in violation_county
parking_df4 = parking_df.filter(parking_df["violation_county"].isNotNull())
print('Count total number of rows before filtering:                                  ', parking_df.count())
print('Count total number of rows after removing  black entries in violation_county: ', parking_df4.count())
print(parking_df.count()-parking_df4.count(), 'rows which contains back entries were removed from violation_county.')
# Out:
# Count total number of rows before filtering:                                   1014017
# Count total number of rows after removing  black entries in violation_county:  821043
# 192974 rows which contains back entries were removed from violation_county.

# %% [markdown]
# ### 3. Clustering
# Clustering is one of the Similarity-based method for cleaning.

# %% [markdown]
# Let's clean the plate_ids.
# ``Clustering`` helps detect entries in a column that are close together (and thus represent the same value)

# %%
# Let's clean the plate_ids
plate_id_rdd = parking_df.select('plate_id').rdd.flatMap(list)
plate_id_rdd.take(50)
# Out:
# ['GBH2444',
#  'GKZ2313',
#  'N346594',
#  'GDP2624',
#  '42555JU',
#  '62636MD',
#  'DPE3045',
#  'FMW7832',
#  'DSD2130',
#  '65111MB',
#  'GMZ3750',
#  '44884',
#  'XZ876G',
#  'PIKINE',
#  'GMU4296',
#  'GEJ8235',
#  '74452JW',
#  '42972JW',
#  '66951',
#  '63400JM',
#  'GGS5172',
#  '51329A',
#  '49216KA',
#  '31695JZ',
#  '79638KA',
#  '88720MB',
#  'ERP5344',
#  'FWM1758',
#  '14307LV',
#  'EWT1353',
#  '65566PA',
#  'FPF5158',
#  '24393MC',
#  '24393MG',
#  'FXR1798',
#  'FWH9893',
#  '88629JH',
#  '1510332',
#  'DJE1615',
#  '2208656',
#  'GXC7520',
#  'GRC4443',
#  'T639084C',
#  'GARFR5',
#  'GTJ6780',
#  '401ZGU',
#  'ZWF21Z',
#  'S274036',
#  'PF090W',
#  'GLR6718']

# %% [markdown]
# "Key Collision" methods are based on the idea of creating a key value that contains only
#  the most valuable or meaningful part of the string and groups together different strings based
#  on the fact that their key is the same (hence the name "key collision").
# Fingerprinting Method:
# note that the order of these operations (the last 3 lines) is significant.
# remove leading and trailing whitespace
# change all characters to their lowercase representation
# remove all punctuation and control characters
# normalize extended western characters to their ASCII representation (for example "gödel" → "godel")
# split the string into whitespace-separated tokens
# sort the tokens and remove duplicates
# join the tokens back together

# %%
import string, unicodedata
def fingerprint(value):
    key = unicodedata.normalize('NFKD', value).encode('ascii','ignore').decode()
    key = set(key.strip().lower().translate(str.maketrans('','',string.punctuation)).split())
    key = ' '.join(sorted(list(key)))
    return (key, value)

# %%
plate_id_rdd.distinct().map(fingerprint).first()
# Out:
# ('ghn4591', 'GHN4591')

# %% [markdown]
# Apply the fingerprint function to all plate_id values, and group the ones that have the same key

# %%
# mapValues(list) - makes the grouped values into a list
plate_id_rdd.distinct(). \
	map(fingerprint). \
	groupByKey(). \
	filter(lambda x: len(x[1])>1). \
	mapValues(list). \
	collect()
# Out:
# [('2970cp', ['2970.CP', '2970CP']),
#  ('41690ja', ['41690JA', '41690JA+']),
#  ('jnp981', ['JNP981', 'JNP981&']),
#  ('xt549k', ['XT.549K', 'XT549K']),
#  ('ap717y', ['AP717Y', 'AP7!17Y']),
#  ('xbgv20', ['XBGV20', 'XBG.V20']),
#  ('zgk7779', ['ZGK7779', 'ZGK.7779']),
#  ('12224mg', ['12224MG', '1222]4MG']),
#  ('47879mg', ['47879MG.', '47879MG']),
#  ('jhd0328', ['JHD0328', 'JHD0328.']),
#  ('849rzb', ['849RZB', '849RZB.']),
#  ('l08275', ['L08(275', 'L08275']),
#  ('hkv4504', ['HKV4504', 'HKV!4504']),
#  ('7', ['7', '7!']),
#  ('ab73725', ['AB.73725', 'AB73725']),
#  ('ete3059', ['ETE3059+', 'ETE3059']),
#  ('88cs02', ['88CS02', '88C.S02']),
#  ('l21741', ['L.21741', 'L21741']),
#  ('l21687', ['L21687', 'L.21687']),
#  ('na', ['N/A', 'NA']),
#  ('jcw0303', ['JCW0303`', 'JCW0303']),
#  ('64582md', ['64582MD.', '64582MD']),
#  ('6786cx', ['6786CX', '6786.CX']),
#  ('zxf293', ['ZXF293+', 'ZXF293']),
#  ('k90404', ['K.90404', 'K90404']),
#  ('aj511c', ['AJ511C', 'AJ.511C']),
#  ('u57afu', ['U57AFU', 'U57.AFU']),
#  ('hcv1327', ['HCV1327', 'HCV!1327']),
#  ('24787jz', ['24787JZ', '24787,JZ']),
#  ('fcz8588', ['FCZ8588', 'FCZ!8588']),
#  ('smutty', ['SMUTTY+', 'SMUTTY']),
#  ('1mdm', ['1MDM', '#1MDM']),
#  ('ns', ['N/S', 'NS'])]

# %%
plate_id_rdd.distinct(). \
	map(fingerprint). \
	groupByKey(). \
	filter(lambda x: len(x[1])>1).take(5)
# Out:
# [('xbgv20', <pyspark.resultiterable.ResultIterable at 0x7f9fd0859190>),
#  ('ap717y', <pyspark.resultiterable.ResultIterable at 0x7f9fd0859700>),
#  ('zgk7779', <pyspark.resultiterable.ResultIterable at 0x7f9fd0859220>),
#  ('xt549k', <pyspark.resultiterable.ResultIterable at 0x7f9fd08595b0>),
#  ('41690ja', <pyspark.resultiterable.ResultIterable at 0x7f9fd08591f0>)]

# %% [markdown]
# To determine a cluster should be merged or not, we can look more closely at the data. As we can see in the example bellow, it seems like both ``2970CP`` and ``2970.CP`` represent the same plate id. So, we may want to rename all of tthem using one of the values, for example, the value ``2970CP``.

# %%
# check the other attributes to determine if the two ids correspond to the same entity
parking_df.where((parking_df.plate_id == '2970CP') | \
	(parking_df.plate_id == '2970.CP')). \
	show()
# Out:
# +--------------+----------+--------------+----------------+---------------------+------------------+------------------+--------------+-------------------+------------+-----------+--------------+---------------+--------------+--------+----------+------------------+---------------+-----------------+-------------+------------+------------+
# |summons_number|issue_date|violation_code|violation_county|violation_description|violation_location|violation_precinct|violation_time|time_first_observed|meter_number|issuer_code|issuer_command|issuer_precinct|issuing_agency|plate_id|plate_type|registration_state|    street_name|vehicle_body_type|vehicle_color|vehicle_make|vehicle_year|
# +--------------+----------+--------------+----------------+---------------------+------------------+------------------+--------------+-------------------+------------+-----------+--------------+---------------+--------------+--------+----------+------------------+---------------+-----------------+-------------+------------+------------+
# |    7081878969|2016-03-10|            48|              BX|         48-Bike Lane|                40|                40|         1019A|               null|        null|     358609|          T201|             40|             T|  2970CP|       COM|                CT|    Melrose Ave|             PICK|          TAN|        FORD|           0|
# |    7191964236|2016-03-04|            38|              BX| 38-Failure to Dis...|                47|                47|         0254P|               null|        null|     363080|          T201|             47|             T|  2970CP|       999|                CT|      Boston Rd|             PICK|        WHITE|        FORD|           0|
# |    7417510589|2016-03-16|            46|              BX| 46B-Double Parkin...|                44|                44|         0356P|              1200P|        null|     361796|          T201|             44|             T|  2970CP|       CMB|                CT|Grand Concourse|              VAN|        WHITE|        FORD|           0|
# |    7554375489|2016-03-08|            46|              BX| 46B-Double Parkin...|                45|                45|         1055A|              1050A|        null|     362268|          T201|             45|             T| 2970.CP|       CMB|                CT|  E Tremont Ave|             PICK|        WHITE|        FORD|           0|
# |    7637915049|2016-03-15|            37|              BX| 37-Expired Muni M...|                43|                43|         0421P|              0415P|    217-3200|     363079|          T201|             43|             T|  2970CP|       999|                CT|        Wood Rd|             PICK|        WHITE|        FORD|           0|
# +--------------+----------+--------------+----------------+---------------------+------------------+------------------+--------------+-------------------+------------+-----------+--------------+---------------+--------------+--------+----------+------------------+---------------+-----------------+-------------+------------+------------+

# %% [markdown]
# We can perform the same analysis on other columns like ``street_name``. As shown bellow.

# %%
# clustering on the street_name column.
street_name_rdd = parking_df.select('street_name').distinct().rdd.flatMap(list).filter(lambda x: x!=None)

stname_clusters = street_name_rdd.distinct(). \
	map(fingerprint). \
	groupByKey(). \
	filter(lambda x: len(x[1])>1). \
	mapValues(list). \
	collect()

stname_clusters
# Out:
# [('plains rd white', ['White Plains Rd', 'WHITE PLAINS RD']),
#  ('ave riverdale', ['Riverdale Ave', 'RIVERDALE AVE']),
#  ('eldert ln', ['ELDERT LN', 'Eldert Ln']),
#  ('ave chittenden', ['CHITTENDEN AVE', 'Chittenden Ave']),
#  ('5 avenue', ['5 AVENUE', 'AVENUE 5']),
#  ('184th st', ['184th St', '184TH ST']),
#  ('ave ryder', ['Ryder Ave', 'RYDER AVE']),
#  ('ave foothill', ['Foothill Ave', 'FOOTHILL AVE']),
#  ('ave lott', ['Lott Ave', 'LOTT AVE']),
#  ('marine way', ['Marine Way', 'MARINE WAY']),
#  ('astor pl', ['Astor Pl', 'ASTOR PL']),
#  ('37th ave', ['37TH AVE', '37th Ave']),
#  ('clawson st', ['Clawson St', 'CLAWSON ST']),
#  ('ave shepard', ['SHEPARD AVE', 'Shepard Ave']),
#  ('gramercy park', ['Gramercy Park', 'GRAMERCY PARK']),
#  ('degraw st', ['Degraw St', 'DEGRAW ST']),
#  ('ave glenmore', ['Glenmore Ave', 'GLENMORE AVE']),
#  ('ave neptune', ['Neptune Ave', 'NEPTUNE  AVE', 'NEPTUNE AVE']),
#  ('hartman ln', ['HARTMAN LN', 'Hartman Ln']),
#  ('7 arr jfkia terminal', ['TERMINAL 7 JFKIA ARR', 'JFKIA TERMINAL 7 ARR']),
#  ('leavitt st', ['Leavitt St', 'LEAVITT ST']),
#  ('market ns slip', ['N/S MARKET SLIP', 'N/S MARKET  SLIP']),
#  ('dongan st', ['Dongan St', 'DONGAN ST']),
#  ('richardson st', ['RICHARDSON ST', 'Richardson St']),
#  ('oval reservoir', ['Reservoir Oval', 'RESERVOIR OVAL']),
#  ('156th st w', ['W 156TH ST', 'W 156th St']),
#  ('albemarle rd', ['Albemarle Rd', 'ALBEMARLE RD']),
#  ('avenue x', ['AVENUE X', 'Avenue X']),
#  ('college manhattan pk', ['MANHATTAN COLLEGE PK', 'Manhattan College Pk']),
#  ('ave co ne third', ['NE C/O THIRD AVE', 'N/E C/O THIRD AVE']),
#  ('fleet st', ['Fleet St', 'FLEET ST']),
#  ('120th e st', ['E 120TH ST', 'E 120th St']),
#  ('5th ave', ['5th Ave', '5TH  AVE', '5TH AVE']),
#  ('st woodhull', ['WOODHULL ST', 'Woodhull St']),
#  ('spencer st', ['SPENCER ST', 'Spencer St']),
#  ('hwy kings', ['Kings Hwy', 'KINGS HWY', 'KINGS .HWY']),
#  ('bedford blvd park', ['BEDFORD PARK BLVD', 'Bedford Park Blvd']),
#  ('ave byron', ['Byron Ave', 'BYRON AVE']),
#  ('ave garfield', ['Garfield Ave', 'GARFIELD AVE']),
#  ('st worth', ['WORTH ST', 'Worth St']),
#  ('55 e st', ['E 55 ST', 'E .55 ST']),
#  ('96th e st', ['E 96TH ST', 'E 96th St', 'E 96TH  ST']),
#  ('hemlock st', ['Hemlock St', 'HEMLOCK  ST', 'HEMLOCK ST']),
#  ('ave puritan', ['Puritan Ave', 'PURITAN AVE']),
#  ('bush st', ['Bush St', 'BUSH ST']),
#  ('ave pleasant', ['PLEASANT AVE', 'Pleasant Ave']),
#  ('pl thornton', ['THORNTON PL', 'Thornton Pl']),
#  ('ave burnside w', ['W BURNSIDE AVE', 'W Burnside Ave']),
#  ('st stockholm', ['Stockholm St', 'STOCKHOLM ST', 'STOCKHOLM  ST']),
#  ('amboy st', ['Amboy St', 'AMBOY ST']),
#  ('223rd pl', ['223rd Pl', '223RD PL']),
#  ('ave lasalle', ['Lasalle Ave', 'LASALLE AVE']),
#  ('sagamore st', ['SAGAMORE ST', 'Sagamore St']),
#  ('amethyst st', ['AMETHYST ST', 'Amethyst St']),
#  ('kosciusko st', ['Kosciusko St', 'KOSCIUSKO ST']),
#  ('selfridge st', ['Selfridge St', 'SELFRIDGE ST']),
#  ('middletown rd', ['MIDDLETOWN RD', 'Middletown Rd']),
#  ('berry st', ['BERRY ST', 'Berry St']),
#  ('carroll pl', ['CARROLL PL', 'Carroll Pl', 'CARROLL  PL']),
#  ('pelham pkwy so', ['PELHAM PKWY  SO', 'PELHAM PKWY SO', 'PELHAM  PKWY SO']),
#  ('fuller pl', ['FULLER PL', 'Fuller Pl']),
#  ('st truxton', ['Truxton St', 'TRUXTON ST']),
#  ('40th ave', ['40TH AVE', '40th Ave']),
#  ('ave summit', ['SUMMIT  AVE', 'Summit Ave', 'SUMMIT AVE']),
#  ('164th st', ['164TH ST', '164th St']),
#  ('expy harding horace', ['HORACE HARDING EXPY', 'Horace Harding Expy']),
#  ('105th e st', ['E 105TH ST', 'E 105th St']),
#  ('102 e st', ['E 102  ST', 'E 102 ST', 'E .102 ST']),
#  ('ave patchen', ['PATCHEN AVE', 'Patchen Ave']),
#  ('corporal st stone', ['CORPORAL STONE ST', 'Corporal Stone St']),
#  ('15th brighton st', ['BRIGHTON 15TH ST', 'Brighton 15th St']),
#  ('ave st theresa', ['St Theresa Ave', 'ST THERESA AVE']),
#  ('st waterbury', ['Waterbury St', 'WATERBURY ST']),
#  ('grand st', ['GRAND ST', 'Grand St']),
#  ('ave wilder', ['Wilder Ave', 'WILDER AVE']),
#  ('nicholas st ter', ['St Nicholas Ter', 'ST NICHOLAS TER']),
#  ('lorimer st', ['Lorimer St', 'LORIMER  ST', 'LORIMER ST']),
#  ('campus rd', ['Campus Rd', 'CAMPUS RD']),
#  ('astoria blvd n', ['ASTORIA BLVD  N', 'ASTORIA BLVD N']),
#  ('st varet', ['Varet St', 'VARET ST']),
#  ('ave dixon', ['DIXON AVE', 'Dixon Ave']),
#  ('n oxford st', ['N Oxford St', 'N OXFORD ST']),
#  ('ave muliner', ['Muliner Ave', 'MULINER AVE']),
#  ('ave cedar', ['CEDAR  AVE', 'CEDAR AVE', 'Cedar Ave']),
#  ('osborn st', ['Osborn St', 'OSBORN ST']),
#  ('62nd dr', ['62ND DR', '62nd Dr']),
#  ('henry n st', ['N Henry St', 'N HENRY ST']),
#  ('ave sprague', ['Sprague Ave', 'SPRAGUE AVE']),
#  ('23rd st w', ['W 23RD ST', 'W 23rd St']),
#  ('22nd beach st', ['BEACH 22ND ST', 'Beach 22nd St']),
#  ('bronx cross expy', ['CROSS BRONX EXPY', 'Cross Bronx Expy']),
#  ('ave co franklin nw', ['NW C/O FRANKLIN AVE', 'N/W C/O FRANKLIN AVE']),
#  ('noble st', ['Noble St', 'NOBLE ST']),
#  ('krier pl', ['Krier Pl', 'KRIER PL']),
#  ('44th e st', ['E 44TH ST', 'E 44th St']),
#  ('126th st', ['126TH ST', '126th St']),
#  ('ave nagle', ['Nagle Ave', 'NAGLE AVE']),
#  ('127th st', ['127TH ST', '127th St']),
#  ('eagle st', ['Eagle St', 'EAGLE ST']),
#  ('172nd e st', ['E 172nd St', 'E 172ND ST']),
#  ('ave close', ['CLOSE AVE', 'Close Ave']),
#  ('lyman pl', ['LYMAN PL', 'Lyman Pl']),
#  ('32nd st', ['32ND ST', '32nd St']),
#  ('cross st', ['CROSS ST', 'Cross St']),
#  ('fernside pl', ['Fernside Pl', 'FERNSIDE PL']),
#  ('9th ave', ['9th Ave', '9TH AVE', '9TH  AVE']),
#  ('charlton st', ['CHARLTON ST', 'Charlton St']),
#  ('ave thatford', ['THATFORD AVE', 'Thatford Ave']),
#  ('ave delaware', ['Delaware Ave', 'DELAWARE AVE']),
#  ('ave coolidge', ['COOLIDGE AVE', 'Coolidge Ave']),
#  ('hancock st', ['HANCOCK ST', 'Hancock St']),
#  ('167 w', ['W 167', 'W .167']),
#  ('ave willett', ['WILLETT AVE', 'Willett Ave']),
#  ('blvd highland', ['Highland Blvd', 'HIGHLAND BLVD']),
#  ('juniper rd valley', ['Juniper Valley Rd', 'JUNIPER VALLEY RD']),
#  ('lincoln st', ['Lincoln St', 'LINCOLN ST']),
#  ('ave harper', ['HARPER AVE', 'Harper Ave']),
#  ('crotona n park', ['CROTONA  PARK N', 'CROTONA PARK N']),
#  ('ave vireo', ['Vireo Ave', 'VIREO AVE']),
#  ('3rd paerdegat st', ['Paerdegat 3rd St', 'PAERDEGAT 3RD ST']),
#  ('6th n st', ['N 6th St', 'N 6TH ST']),
#  ('ave plimpton', ['Plimpton Ave', 'PLIMPTON AVE']),
#  ('st wall', ['WALL ST', 'Wall St']),
#  ('51st e st', ['E 51st St', 'E 51ST ST']),
#  ('alstyne ave', ['ALSTYNE AVE', 'ALSTYNE  AVE', 'Alstyne Ave']),
#  ('ave stratford', ['STRATFORD AVE', 'Stratford Ave']),
#  ('ave longfellow', ['Longfellow Ave', 'LONGFELLOW AVE']),
#  ('102nd e st', ['E 102nd St', 'E 102ND ST']),
#  ('ellery st', ['Ellery St', 'ELLERY ST']),
#  ('ave madison nb', ['MADISON AVE (N/B) @', 'N/B MADISON AVE']),
#  ('ave waverly', ['Waverly Ave', 'WAVERLY AVE']),
#  ('st william', ['William St', 'WILLIAM ST', 'WILLIAM  ST']),
#  ('ave starling', ['Starling Ave', 'STARLING AVE']),
#  ('ave fort george', ['FORT GEORGE AVE', 'Fort George Ave']),
#  ('oxford s st', ['S OXFORD ST', 'S Oxford St']),
#  ('5th st', ['5TH ST', '5th St']),
#  ('ave schieffelin', ['Schieffelin Ave', 'SCHIEFFELIN AVE']),
#  ('harman st', ['HARMAN ST', 'Harman St']),
#  ('197th e st', ['E 197th St', 'E 197TH ST']),
#  ('mitchell pl', ['Mitchell Pl', 'MITCHELL PL']),
#  ('cumberland st', ['CUMBERLAND ST', 'Cumberland St']),
#  ('50th st w', ['W 50th St', 'W 50TH ST']),
#  ('ave laurel', ['Laurel Ave', 'LAUREL AVE']),
#  ('ave bruner', ['Bruner Ave', 'BRUNER AVE']),
#  ('ave putnam', ['Putnam Ave', 'PUTNAM AVE']),
#  ('lowerre pl', ['LOWERRE PL', 'Lowerre Pl']),
#  ('ave willis', ['WILLIS AVE', 'Willis Ave']),
#  ('ave strang', ['STRANG AVE', 'Strang Ave']),
#  ('12th n st', ['N 12th St', 'N 12TH ST']),
#  ('barclay st', ['Barclay St', 'BARCLAY ST']),
#  ('200th st', ['200TH ST', '200th St']),
#  ('monaco pl', ['MONACO PL', 'Monaco Pl']),
#  ('41st rd', ['41st Rd', '41ST RD']),
#  ('hendrix st', ['Hendrix St', 'HENDRIX ST']),
#  ('243rd st', ['243rd St', '243RD ST']),
#  ('admiral ave', ['ADMIRAL AVE', 'Admiral Ave']),
#  ('ford st', ['Ford St', 'FORD ST']),
#  ('91st ave', ['91ST AVE', '91st Ave']),
#  ('briar pl', ['BRIAR PL', 'Briar Pl']),
#  ('malta st', ['Malta St', 'MALTA ST']),
#  ('ave reid', ['Reid Ave', 'REID AVE']),
#  ('north st', ['North St', 'NORTH ST']),
#  ('hall st', ['Hall St', 'HALL ST']),
#  ('autumn ave', ['AUTUMN AVE', 'AUTUMN  AVE', 'Autumn Ave']),
#  ('159 st', ['159 ST', '159  ST']),
#  ('ave lincoln', ['LINCOLN AVE', 'Lincoln Ave']),
#  ('ave cayuga', ['CAYUGA AVE', 'Cayuga Ave']),
#  ('ave soundview', ['SOUNDVIEW AVE', 'Soundview Ave']),
#  ('127 co ne st', ['NE C/O 127 ST', 'N/E C/O 127 ST']),
#  ('concourse grand sb',
#   ['GRAND CONCOURSE (S/B', 'SB GRAND CONCOURSE.', 'SB GRAND CONCOURSE @']),
#  ('james st', ['ST JAMES ST', 'James St', 'ST JAMES']),
#  ('bellamy loop', ['Bellamy Loop', 'BELLAMY LOOP', 'BELLAMY LOOP.']),
#  ('hoffman st', ['Hoffman St', 'HOFFMAN ST']),
#  ('crotona pl', ['CROTONA PL', 'Crotona Pl']),
#  ('ainslie st', ['Ainslie St', 'AINSLIE ST']),
#  ('23rd st', ['23rd St', '23RD ST']),
#  ('dorchester rd', ['DORCHESTER RD', 'Dorchester Rd']),
#  ('blvd farmers', ['Farmers Blvd', 'FARMERS BLVD']),
#  ('saunders st', ['SAUNDERS ST', 'Saunders St']),
#  ('ave vedder', ['VEDDER AVE', 'Vedder Ave']),
#  ('ave n portland', ['N Portland Ave', 'N PORTLAND AVE']),
#  ('ave flushing', ['FLUSHING AVE', 'Flushing Ave']),
#  ('167th e st', ['E 167th St', 'E 167TH ST']),
#  ('ave throop', ['THROOP AVE', 'Throop Ave']),
#  ('ave varick', ['VARICK AVE', 'Varick Ave']),
#  ('lefferts pl', ['LEFFERTS PL', 'Lefferts Pl']),
#  ('181st e st', ['E 181ST ST', 'E 181st St']),
#  ('ave townsend', ['Townsend Ave', 'TOWNSEND AVE']),
#  ('danforth st', ['Danforth St', 'DANFORTH ST']),
#  ('179th st w', ['W 179TH ST', 'W 179th St']),
#  ('11th st', ['11th St', '11TH ST']),
#  ('100th beach st', ['BEACH 100TH ST', 'Beach 100th St']),
#  ('64th ave', ['64TH AVE', '64th Ave']),
#  ('bay blvd cross', ['CROSS BAY BLVD', 'Cross Bay Blvd']),
#  ('penrod st', ['PENROD ST', 'Penrod St']),
#  ('179th e st', ['E 179TH ST', 'E 179th St']),
#  ('147th st', ['147th St', '147TH ST']),
#  ('ave pitkin', ['Pitkin Ave', 'PITKIN AVE']),
#  ('ave bath', ['BATH  AVE', 'Bath Ave', 'BATH AVE']),
#  ('ave homestead', ['Homestead Ave', 'HOMESTEAD AVE']),
#  ('blvd northern', ['NORTHERN BLVD', 'Northern Blvd']),
#  ('4th st w', ['W 4th St', 'W 4TH ST']),
#  ('94 e st', ['E .94 ST', 'E 94 ST']),
#  ('irwin st', ['IRWIN ST', 'Irwin St']),
#  ('ave stillwell', ['Stillwell Ave', 'STILLWELL AVE']),
#  ('pl raleigh', ['Raleigh Pl', 'RALEIGH PL']),
#  ('44 st w', ['W 44 ST', 'W  44 ST']),
#  ('burnet pl', ['Burnet Pl', 'BURNET PL']),
#  ('calloway st', ['CALLOWAY ST', 'Calloway St']),
#  ('marks pl st', ['ST MARKS PL', 'St Marks Pl']),
#  ('ave decatur',
#   ['DECATUR AVE', 'DECATUR AVE .', 'DECATUR  AVE', 'Decatur Ave']),
#  ('oceania st', ['Oceania St', 'OCEANIA ST']),
#  ('ave underhill', ['UNDERHILL AVE', 'Underhill Ave']),
#  ('72nd st w', ['W 72nd St', 'W 72ND ST']),
#  ('dr garland', ['Garland Dr', 'GARLAND DR']),
#  ('93rd e st', ['E 93rd St', 'E 93RD ST']),
#  ('ave mcclellan', ['MCCLELLAN AVE', 'Mcclellan Ave.']),
#  ('21st ave', ['21ST AVE', '21st Ave']),
#  ('ave pettit', ['Pettit Ave', 'PETTIT AVE']),
#  ('noll st', ['NOLL ST', 'NOLL  ST', 'Noll St']),
#  ('ave plainview', ['PLAINVIEW AVE', 'Plainview Ave']),
#  ('rd woodrow', ['Woodrow Rd', 'WOODROW RD']),
#  ('north pelham pkwy', ['Pelham  Pkwy North', 'PELHAM PKWY NORTH']),
#  ('100th e st', ['E 100th St', 'E 100TH ST']),
#  ('pl sterling', ['Sterling Pl', 'STERLING PL', 'STERLING  PL']),
#  ('jefferson st', ['Jefferson St', 'JEFFERSON ST']),
#  ('ave mcgraw', ['MCGRAW AVE', 'McGraw Ave']),
#  ('129 co st sw', ['S/W C/O 129 ST', 'SW C/O 129 ST']),
#  ('ave seton', ['SETON AVE', 'Seton Ave']),
#  ('neilson st', ['NEILSON  ST', 'NEILSON ST', 'Neilson St']),
#  ('bronx east park', ['Bronx Park East', 'BRONX PARK EAST']),
#  ('cedar st', ['CEDAR ST', 'Cedar St']),
#  ('albany st', ['ALBANY ST', 'Albany St', 'ALBANY  ST']),
#  ('monument walk', ['Monument Walk', 'MONUMENT WALK']),
#  ('ave cromwell', ['Cromwell Ave', 'CROMWELL AVE']),
#  ('ave fort washington', ['Fort Washington Ave', 'FORT WASHINGTON AVE']),
#  ('ave city island', ['CITY ISLAND AVE', 'City Island Ave']),
#  ('33rd e st', ['E 33RD ST', 'E 33rd St']),
#  ('ave blossom', ['BLOSSOM AVE', 'Blossom Ave']),
#  ('ave newport', ['Newport Ave', 'NEWPORT AVE']),
#  ('ave bailey', ['Bailey Ave', 'BAILEY AVE']),
#  ('park prospect sw',
#   ['PROSPECT PARK S/W', 'PROSPECT PARK SW', 'Prospect Park SW']),
#  ('av coney es island', ['E/S CONEY ISLAND AV', 'E/S  CONEY ISLAND AV']),
#  ('ave cherry', ['Cherry Ave', 'CHERRY AVE']),
#  ('ave zerega', ['Zerega Ave', 'ZEREGA AVE']),
#  ('blvd queens', ['QUEE,NS BLVD', 'QUEENS BLVD', 'Queens Blvd']),
#  ('st whittier', ['WHITTIER  ST', 'WHITTIER ST', 'Whittier St']),
#  ('88th e st', ['E 88th St', 'E 88TH ST']),
#  ('73rd st w', ['W 73RD ST', 'W 73rd St']),
#  ('24th st', ['24TH ST', '24th St']),
#  ('baisley blvd', ['BAISLEY BLVD', 'Baisley Blvd']),
#  ('duncan st', ['DUNCAN ST', 'Duncan St']),
#  ('79th st', ['79TH ST', '79th St']),
#  ('208th e st', ['E 208TH ST', 'E 208th St']),
#  ('blvd brewer guy r', ['Guy R Brewer Blvd', 'GUY R BREWER BLVD']),
#  ('ave claremont', ['CLAREMONT AVE', 'Claremont Ave']),
#  ('50th e st', ['E 50TH ST', 'E 50th St']),
#  ('24th e st', ['E 24th St', 'E 24TH ST']),
#  ('ave metropolitan', ['METROPOLITAN AVE', 'Metropolitan Ave']),
#  ('ave conduit s', ['S Conduit Ave', 'S CONDUIT AVE']),
#  ('ave wellman', ['WELLMAN AVE', 'Wellman Ave']),
#  ('haring st', ['HARING ST', 'Haring St']),
#  ('ave jerome', ['Jerome Ave', 'JEROME  AVE', 'JEROME AVE']),
#  ('55th st', ['55TH ST', '55th St']),
#  ('125th st w', ['W 125TH ST', 'W 125th St']),
#  ('st stanton', ['Stanton St', 'STANTON ST']),
#  ('121st st w', ['W 121st St', 'W 121ST ST']),
#  ('45th e st', ['E 45TH ST', 'E 45th St']),
#  ('beaver st', ['BEAVER ST', 'Beaver St']),
#  ('st wright', ['WRIGHT ST', 'Wright St']),
#  ('hill rd richmond',
#   ['Richmond Hill Rd', 'RICHMOND HILL  RD', 'RICHMOND HILL RD']),
#  ('co maran pl sw', ['S/W C/O MARAN PL', 'SW C/O MARAN PL']),
#  ('newel st', ['NEWEL ST', 'Newel St']),
#  ('195th e st', ['E 195TH ST', 'E 195th St']),
#  ('ave pinehurst', ['PINEHURST AVE', 'Pinehurst Ave']),
#  ('beverley rd', ['BEVERLEY RD', 'Beverley Rd']),
#  ('ave crosby', ['Crosby Ave', 'CROSBY AVE']),
#  ('spring st', ['SPRING ST', 'Spring St']),
#  ('ave hollers', ['Hollers Ave', 'HOLLERS AVE']),
#  ('blvd nb woodhaven', ['WOODHAVEN BLVD (N/B)', 'NB WOODHAVEN BLVD @']),
#  ('st willoughby', ['Willoughby St', 'WILLOUGHBY ST']),
#  ('east park terrace', ['PARK TERRACE EAST', 'Park Terrace East']),
#  ('125 st w', ['W 125 ST', 'W 125  ST']),
#  ('blvd cabrini', ['CABRINI  BLVD', 'Cabrini Blvd', 'CABRINI BLVD']),
#  ('3rd pl', ['3RD PL', '3rd Pl']),
#  ('ave c', ['AVE C', 'AVE  C']),
#  ('avenue j', ['AVENUE J', 'Avenue J']),
#  ('66th dr', ['66th Dr', '66TH DR']),
#  ('38th st', ['38TH ST', '38th St']),
#  ('carmel mount pl', ['Mount Carmel Pl', 'MOUNT CARMEL PL']),
#  ('fairview pl', ['FAIRVIEW PL', 'Fairview Pl']),
#  ('amador st', ['Amador St', 'AMADOR ST']),
#  ('ave woodruff', ['WOODRUFF AVE', 'Woodruff Ave']),
#  ('178 e st', ['E 178 ST', 'E  178 ST']),
#  ('ave major', ['MAJOR AVE', 'Major Ave']),
#  ('moffat st', ['MOFFAT ST', 'Moffat St']),
#  ('central grand pkwy', ['GRAND CENTRAL  PKWY', 'GRAND CENTRAL PKWY']),
#  ('ave brush', ['BRUSH AVE', 'Brush Ave']),
#  ('ave hill marble',
#   ['Marble Hill Ave', 'MARBLE HILL AVE.', 'MARBLE HILL AVE']),
#  ('ave lurting', ['Lurting Ave', 'LURTING AVE']),
#  ('86th ave', ['86th Ave', '86TH AVE']),
#  ('162nd e st', ['E 162ND ST', 'E 162nd St']),
#  ('st withers', ['WITHERS ST', 'Withers St']),
#  ('pl washington', ['Washington Pl', 'WASHINGTON PL']),
#  ('ave fountain', ['FOUNTAIN AVE', 'Fountain Ave']),
#  ('57th e st', ['E 57TH ST', 'E 57th St']),
#  ('pl rockwell', ['Rockwell Pl', 'ROCKWELL PL']),
#  ('ave lafayette', ['Lafayette Ave', 'LAFAYETTE AVE', 'LAFAYETTE  AVE']),
#  ('ct woodhaven', ['Woodhaven Ct', 'WOODHAVEN CT']),
#  ('mazeau st', ['MAZEAU ST', 'Mazeau St']),
#  ('bristow st', ['Bristow St', 'BRISTOW ST']),
#  ('brunt st van', ['VAN BRUNT ST', 'Van Brunt St']),
#  ('35th st w', ['W 35TH ST', 'W 35th St']),
#  ('111th st', ['111TH ST', '111th St']),
#  ('ave concord', ['CONCORD AVE', 'Concord Ave']),
#  ('ave emmons', ['Emmons Ave', 'EMMONS AVE']),
#  ('fulton st', ['Fulton St', 'FULTON  ST', 'FULTON ST']),
#  ('68th st', ['68TH ST', '68th St']),
#  ('perry st', ['PERRY ST', 'Perry St']),
#  ('av ocean', ['OCEAN AV .', 'OCEAN AV']),
#  ('havenwood rd', ['Havenwood Rd', 'HAVENWOOD RD']),
#  ('pike slip', ['PIKE SLIP', 'Pike Slip']),
#  ('ave cauldwell', ['CAULDWELL AVE', 'Cauldwell Ave']),
#  ('pineapple st', ['Pineapple St', 'PINEAPPLE ST']),
#  ('seabring st', ['Seabring St', 'SEABRING ST']),
#  ('lake rd silver', ['SILVER LAKE RD', 'Silver Lake Rd']),
#  ('apex pl', ['APEX PL', 'Apex Pl']),
#  ('rd shell', ['Shell Rd', 'SHELL RD']),
#  ('7 e st', ['E 7 ST', 'E  7 ST']),
#  ('1st st', ['1st St', '1ST ST']),
#  ('ave engert', ['ENGERT AVE', 'Engert Ave']),
#  ('28th ave', ['28th Ave', '28TH AVE']),
#  ('218th e st', ['E 218th St', 'E 218TH ST']),
#  ('67th e st', ['E 67th St', 'E 67TH ST']),
#  ('boyland st thomas', ['THOMAS BOYLAND ST', 'THOMAS  BOYLAND ST']),
#  ('ave remsen', ['Remsen Ave', 'REMSEN AVE']),
#  ('19th st w', ['W 19th St', 'W 19TH ST']),
#  ('72nd e st', ['E 72nd St', 'E 72ND ST']),
#  ('ave roebling', ['Roebling Ave', 'ROEBLING AVE']),
#  ('cleveland st', ['CLEVELAND ST', 'Cleveland St']),
#  ('elliott n pl', ['N ELLIOTT PL', 'N Elliott Pl']),
#  ('ave independence', ['Independence Ave', 'INDEPENDENCE AVE']),
#  ('ave harrison', ['HARRISON AVE', 'Harrison Ave']),
#  ('indian rd', ['Indian Rd', 'INDIAN RD']),
#  ('ave nelson', ['NELSON  AVE', 'Nelson Ave', 'NELSON AVE']),
#  ('18 ave co se', ['S/E C/O 18 AVE', 'SE C/O 18 AVE']),
#  ('ave k', ['AVE  K', 'AVE K']),
#  ('ave wilcox', ['Wilcox Ave', 'WILCOX AVE']),
#  ('carroll st', ['CARROLL ST', 'CARROLL  ST', 'Carroll St']),
#  ('heyward st', ['Heyward St', 'HEYWARD ST']),
#  ('pl royce', ['ROYCE PL', 'Royce Pl']),
#  ('ave bradley', ['BRADLEY AVE', 'Bradley Ave']),
#  ('ave brighton', ['BRIGHTON AVE', 'Brighton Ave']),
#  ('ave river', ['River Ave', 'RIVER  AVE', 'RIVER AVE']),
#  ('172nd st w', ['W 172nd St', 'W 172ND ST']),
#  ('33rd st', ['33rd St', '33RD ST']),
#  ('ave melbourne', ['MELBOURNE AVE', 'Melbourne Ave']),
#  ('70th st', ['70th St', '70TH ST']),
#  ('orchard st', ['Orchard St', 'ORCHARD ST']),
#  ('147th st w', ['W 147th St', 'W 147TH ST']),
#  ('76th st', ['76TH ST', '76th St']),
#  ('78th st', ['78TH ST', '78th St']),
#  ('blvd empire', ['EMPIRE BLVD .', 'EMPIRE BLVD', 'Empire Blvd']),
#  ('24th ave', ['24TH AVE', '24th Ave']),
#  ('187th e st', ['E 187TH ST', 'E 187th St']),
#  ('st state', ['State St', 'STATE ST']),
#  ('18 st west', ['WEST 18 ST', 'WEST 18 ST+']),
#  ('40th st w', ['W 40th St', 'W 40TH ST']),
#  ('aguilar ave', ['AGUILAR AVE', 'Aguilar Ave']),
#  ('ave depew', ['Depew Ave', 'DEPEW AVE']),
#  ('avenue u', ['Avenue U', 'AVENUE U']),
#  ('avenue i', ['Avenue I', 'AVENUE I']),
#  ('pilot st', ['Pilot St', 'PILOT ST']),
#  ('108th beach st', ['Beach 108th St', 'BEACH 108TH ST']),
#  ('47th bay st', ['BAY 47TH ST', 'Bay 47th St']),
#  ('kingsbridge ter', ['KINGSBRIDGE TER', 'Kingsbridge Ter']),
#  ('ave ovington', ['Ovington Ave', 'OVINGTON  AVE', 'OVINGTON AVE']),
#  ('ave norton', ['Norton Ave', 'NORTON AVE']),
#  ('ave dongan', ['Dongan Ave', 'DONGAN AVE']),
#  ('ave sampson', ['SAMPSON AVE', 'Sampson Ave']),
#  ('ave ft washington', ['FT WASHINGTON AVE', 'Ft Washington Ave']),
#  ('ave burchell', ['BURCHELL  AVE', 'Burchell Ave']),
#  ('108 es st', ['E/S 108 ST', 'ES 108 ST']),
#  ('84th rd', ['84th Rd', '84TH RD']),
#  ('60th pl', ['60th Pl', '60TH PL']),
#  ('atlantic ave co nw', ['NW C/O ATLANTIC AVE', 'N/W C/O ATLANTIC AVE']),
#  ('ave bergen', ['Bergen Ave', 'BERGEN AVE']),
#  ('locust st', ['Locust St', 'LOCUST ST']),
#  ('ave tompkins', ['TOMPKINS AVE', 'Tompkins Ave']),
#  ('118th e st', ['E 118th St', 'E 118TH ST']),
#  ('42 st w', ['W 42 ST', 'W .42 ST']),
#  ('st waltham', ['Waltham St', 'WALTHAM ST']),
#  ('ave wilson', ['Wilson Ave', 'WILSON AVE.', 'WILSON AVE', 'WILSON  AVE']),
#  ('ave bartow', ['BARTOW AVE', 'Bartow Ave']),
#  ('57th st w', ['W 57TH ST', 'W 57th St']),
#  ('morris st', ['Morris St', 'MORRIS ST']),
#  ('ave rhinelander', ['Rhinelander Ave', 'RHINELANDER AVE']),
#  ('adelphi st', ['ADELPHI ST', 'Adelphi St']),
#  ('ave lots new', ['NEW LOTS AVE', 'New Lots Ave']),
#  ('meserole st', ['Meserole St', 'MESEROLE ST']),
#  ('rutgers slip', ['RUTGERS SLIP', 'Rutgers Slip']),
#  ('ave larue', ['LARUE AVE', 'Larue Ave']),
#  ('48 e plaza un', ['U.N. PLAZA E 48', 'UN PLAZA E 48', 'U.N.  PLAZA E 48']),
#  ('19th beach st', ['BEACH 19TH ST', 'Beach 19th St']),
#  ('mckibben st', ['MCKIBBEN ST', 'McKibben St']),
#  ('ave hollis', ['HOLLIS AVE', 'Hollis Ave']),
#  ('37th dr', ['37th Dr', '37TH DR']),
#  ('loon st van', ['VAN LOON ST', 'Van Loon St']),
#  ('ave hillman', ['Hillman Ave', 'HILLMAN AVE']),
#  ('ave livingston', ['Livingston Ave', 'LIVINGSTON AVE']),
#  ('7th n st', ['N 7TH ST', 'N 7th St']),
#  ('ave blake', ['BLAKE AVE', 'Blake Ave']),
#  ('17th e st', ['E 17TH ST', 'E 17th St', 'E 17TH  ST']),
#  ('hicks st', ['Hicks St', 'HICKS ST']),
#  ('69th e st', ['E 69th St', 'E 69TH ST']),
#  ('ridge st', ['Ridge St', 'RIDGE ST']),
#  ('ave roma', ['ROMA AVE', 'Roma Ave']),
#  ('dr kenilworth', ['KENILWORTH DR', 'Kenilworth Dr']),
#  ('46th st', ['46th St', '46TH ST']),
#  ('8 st', ['8  ST', '8 ST']),
#  ('drake st', ['DRAKE ST', 'Drake St']),
#  ('india st', ['India St', 'INDIA ST']),
#  ('34th st', ['34th St', '34TH ST']),
#  ('43rd e st', ['E 43rd St', 'E 43RD  ST', 'E 43RD ST']),
#  ('schaefer st', ['Schaefer St', 'SCHAEFER ST']),
#  ('circle colombus', ['COLOMBUS  CIRCLE', 'COLOMBUS CIRCLE']),
#  ('ave review', ['Review Ave', 'REVIEW AVE']),
#  ('ave tratman', ['Tratman Ave', 'TRATMAN AVE']),
#  ('149th e st', ['E 149TH ST', 'E 149TH  ST', 'E 149th St']),
#  ('sq times', ['Times Sq', 'TIMES SQ']),
#  ('ave waldo', ['WALDO AVE', 'Waldo Ave']),
#  ('ave vanderbilt', ['Vanderbilt Ave', 'VANDERBILT AVE']),
#  ('16th e st', ['E 16th St', 'E 16TH ST']),
#  ('ave vernon', ['Vernon Ave', 'VERNON AVE']),
#  ('169th e st', ['E 169TH ST', 'E 169th St']),
#  ('baruch pl', ['BARUCH PL', 'Baruch Pl']),
#  ('168th e st', ['E 168th St', 'E 168TH ST']),
#  ('duzer st van', ['VAN DUZER ST', 'Van Duzer St']),
#  ('melba st', ['Melba St', 'MELBA ST']),
#  ('bay st', ['BAY ST', 'Bay St']),
#  ('overing st', ['Overing St', 'OVERING ST']),
#  ('57th st', ['57th St', '57TH ST']),
#  ('corbin pl', ['CORBIN PL', 'Corbin Pl']),
#  ('ave henderson', ['Henderson Ave', 'HENDERSON AVE']),
#  ('st w41', ['W.41 ST ST', 'W41 ST']),
#  ('32nd e st', ['E 32ND ST', 'E 32nd St']),
#  ('astor ave', ['ASTOR AVE', 'Astor Ave']),
#  ('ave porter', ['Porter Ave', 'PORTER AVE']),
#  ('10 ave', ['10 AVE', '10  AVE']),
#  ('ave columbia', ['Columbia Ave', 'COLUMBIA AVE']),
#  ('humboldt st', ['HUMBOLDT ST', 'Humboldt St']),
#  ('ave mckinley', ['MCKINLEY AVE', 'McKinley Ave']),
#  ('beadel st', ['BEADEL ST', 'Beadel St']),
#  ('108th st', ['108th St', '108TH ST']),
#  ('edgewater rd', ['Edgewater Rd', 'EDGEWATER RD']),
#  ('st tillary', ['Tillary St', 'TILLARY ST']),
#  ('ave miller', ['MILLER AVE', 'Miller Ave']),
#  ('50 st', ['50 ST', '50  ST']),
#  ('navy st', ['Navy St', 'NAVY ST']),
#  ('37th rd', ['37th Rd', '37TH RD']),
#  ('2nd ave', ['2ND AVE', '2nd Ave']),
#  ('ave poplar', ['POPLAR AVE', 'Poplar Ave']),
#  ('butler pl', ['Butler Pl', 'BUTLER PL']),
#  ('pike st', ['PIKE ST', 'Pike St']),
#  ('140th st', ['140TH ST', '140th St']),
#  ('ave cozine', ['Cozine Ave', 'COZINE AVE']),
#  ('95th st w', ['W 95TH ST', 'W 95th St']),
#  ('lorraine st', ['LORRAINE ST', 'Lorraine St']),
#  ('19th ave', ['19th Ave', '19TH AVE']),
#  ('150th st', ['150th St', '150TH ST']),
#  ('93rd st w', ['W 93rd St', 'W 93RD ST']),
#  ('newtown rd', ['NEWTOWN RD', 'Newtown Rd']),
#  ('bedford st', ['BEDFORD ST', 'Bedford St']),
#  ('ave conklin', ['CONKLIN AVE', 'Conklin Ave']),
#  ('ave gildersleeve', ['GILDERSLEEVE AVE', 'Gildersleeve Ave']),
#  ('glen st', ['Glen St', 'GLEN ST']),
#  ('blvd louis nine', ['Louis Nine Blvd', 'LOUIS NINE BLVD']),
#  ('ave barnes', ['BARNES AVE', 'Barnes Ave']),
#  ('downing st', ['Downing St', 'DOWNING ST']),
#  ('austin st', ['Austin St', 'AUSTIN ST']),
#  ('elk st', ['ELK ST', 'Elk St']),
#  ('ave parkville', ['Parkville Ave', 'PARKVILLE AVE']),
#  ('30th st w', ['W 30th St', 'W 30TH ST']),
#  ('ave harway', ['HARWAY AVE', 'Harway Ave']),
#  ('ave kingsland', ['Kingsland Ave', 'KINGSLAND AVE']),
#  ('dr radio', ['Radio Dr', 'RADIO DR']),
#  ('39th w', ['W  39TH', 'W 39TH']),
#  ('ave baisley', ['Baisley Ave', 'BAISLEY AVE']),
#  ('bank st', ['BANK ST', 'Bank St']),
#  ('ave grandview', ['GRANDVIEW AVE', 'Grandview Ave']),
#  ('ave powell', ['POWELL AVE', 'Powell Ave']),
#  ('clove rd', ['CLOVE RD', 'Clove Rd']),
#  ('ave liberty', ['LIBERTY AVE', 'Liberty Ave']),
#  ('ave lanett', ['LANETT AVE', 'Lanett Ave']),
#  ('guerlain st', ['Guerlain St', 'GUERLAIN ST']),
#  ('45th st w', ['W 45TH ST', 'W 45th St']),
#  ('blvd woodhaven', ['WOODHAVEN BLVD', 'Woodhaven Blvd']),
#  ('172nd st', ['172ND ST', '172nd St']),
#  ('ave orient', ['ORIENT AVE', 'Orient Ave']),
#  ('15th e st', ['E 15TH ST', 'E 15th St']),
#  ('ave haven', ['Haven Ave', 'HAVEN AVE']),
#  ('crotona park', ['Crotona Park', 'CROTONA PARK']),
#  ('ave braddock', ['BRADDOCK AVE', 'Braddock Ave']),
#  ('boerum st', ['BOERUM ST', 'Boerum St']),
#  ('40th rd', ['40TH RD', '40th Rd']),
#  ('halsey st', ['HALSEY ST', 'Halsey St']),
#  ('ave rockville', ['ROCKVILLE AVE', 'Rockville Ave']),
#  ('farms rd west', ['WEST FARMS RD', 'West Farms RD']),
#  ('18th st w', ['W 18TH ST', 'W 18th St']),
#  ('featherbed lane', ['FEATHERBED  LANE', 'FEATHERBED LANE']),
#  ('ave edison', ['EDISON AVE', 'Edison Ave']),
#  ('ave ridgewood', ['Ridgewood Ave', 'RIDGEWOOD AVE']),
#  ('montgomery st', ['MONTGOMERY  ST', 'Montgomery St', 'MONTGOMERY ST']),
#  ('fieldstone rd', ['FIELDSTONE RD', 'Fieldstone Rd']),
#  ('blvd gansevoort', ['Gansevoort Blvd', 'GANSEVOORT BLVD']),
#  ('fulton street', ['FULTON STREET', 'FULTON  STREET']),
#  ('arthur kill rd', ['ARTHUR  KILL RD', 'ARTHUR KILL RD', 'Arthur Kill Rd']),
#  ('ave martense', ['MARTENSE AVE', 'Martense Ave']),
#  ('dwight st', ['DWIGHT ST', 'Dwight St']),
#  ('forest hill rd', ['Forest Hill Rd', 'FOREST HILL RD']),
#  ('ave hamilton', ['Hamilton Ave', 'HAMILTON AVE']),
#  ('ave scott', ['Scott Ave', 'SCOTT AVE']),
#  ('st suydam', ['Suydam St', 'SUYDAM ST']),
#  ('ave booth memorial',
#   ['BOOTH MEMORIAL AVE (', 'Booth Memorial Ave', 'BOOTH MEMORIAL AVE']),
#  ('st zoe', ['ZOE ST', 'Zoe St']),
#  ('butler st', ['BUTLER ST', 'Butler St']),
#  ('ave myrtle', ['MYRTLE AVE', 'Myrtle Ave']),
#  ('ave sheffield', ['Sheffield Ave', 'SHEFFIELD AVE', 'SHEFFIELD  AVE']),
#  ('bethel loop', ['BETHEL LOOP', 'Bethel Loop']),
#  ('ave bennett', ['BENNETT AVE', 'Bennett Ave']),
#  ('blvd cloverdale',
#   ['Cloverdale Blvd', 'CLOVERDALE BLVD', 'CLOVERDALE  BLVD']),
#  ('park st', ['Park St', 'PARK ST']),
#  ('ave eva', ['Eva Ave', 'EVA AVE']),
#  ('ave classon', ['Classon Ave', 'CLASSON AVE']),
#  ('pitt st', ['PITT ST', 'Pitt St']),
#  ('ave buhre', ['Buhre Ave', 'BUHRE AVE']),
#  ('ave miles', ['Miles Ave', 'MILES AVE']),
#  ('64th ln', ['64th Ln', '64TH LN']),
#  ('horatio st', ['HORATIO ST', 'Horatio St']),
#  ('north plaza queens', ['QUEENS PLAZA NORTH', 'Queens Plaza North']),
#  ('ave dyer', ['DYER AVE', 'Dyer Ave']),
#  ('chauncey st', ['CHAUNCEY ST', 'Chauncey St']),
#  ('ave paerdegat', ['PAERDEGAT AVE', 'Paerdegat Ave']),
#  ('elizabeth st', ['Elizabeth St', 'ELIZABETH ST']),
#  ('ave york', ['YORK AVE', 'York Ave']),
#  ('90th ave', ['90th Ave', '90TH AVE']),
#  ('cadman east plaza', ['Cadman Plaza  East', 'CADMAN PLAZA EAST']),
#  ('ave kingsbridge', ['Kingsbridge Ave', 'KINGSBRIDGE AVE']),
#  ('ave willow', ['Willow Ave', 'WILLOW AVE']),
#  ('rd westminster', ['Westminster Rd', 'WESTMINSTER RD']),
#  ('42nd st w', ['W 42ND ST', 'W 42nd St']),
#  ('rockne st', ['Rockne St', 'ROCKNE ST']),
#  ('st summit', ['SUMMIT ST', 'Summit St']),
#  ('ave hoyt north', ['HOYT  AVE NORTH', 'Hoyt Ave North', 'HOYT AVE NORTH']),
#  ('ave olinville', ['OLINVILLE AVE', 'Olinville Ave']),
#  ('halleck st', ['Halleck St', 'HALLECK ST']),
#  ('ludlow st', ['LUDLOW ST', 'Ludlow St']),
#  ('minna st', ['Minna St', 'MINNA ST']),
#  ('ave farragut', ['FARRAGUT AVE', 'Farragut Ave']),
#  ('father pl zeiser', ['Father Zeiser Pl', 'FATHER ZEISER PL']),
#  ('st stanwix', ['Stanwix St', 'STANWIX ST']),
#  ('hamilton pl', ['HAMILTON PL', 'Hamilton Pl']),
#  ('johns pl st',
#   ['ST . JOHNS PL',
#    'ST JOHNS PL',
#    'ST  JOHNS PL',
#    'St Johns Pl',
#    'ST .JOHNS PL']),
#  ('johns plc st', ['ST JOHNS  PLC', 'ST JOHNS PLC']),
#  ('rivington st', ['RIVINGTON ST', 'Rivington St']),
#  ('ash ave', ['Ash Ave', 'ASH AVE']),
#  ('russell st', ['RUSSELL ST', 'Russell St']),
#  ('hannah st', ['Hannah St', 'HANNAH ST']),
#  ('hoyt st', ['Hoyt St', 'HOYT ST', 'HOYT  ST']),
#  ('29th st w', ['W 29TH ST', 'W 29th St']),
#  ('ave fenton', ['Fenton Ave', 'FENTON AVE']),
#  ('14 ave co ne', ['N/E C/O 14 AVE', 'C/O N/E 14 AVE']),
#  ('moreland st', ['Moreland St', 'MORELAND ST']),
#  ('st stockton', ['STOCKTON ST', 'Stockton St']),
#  ('knapp st', ['Knapp St', 'KNAPP ST']),
#  ('cortelyou rd', ['CORTELYOU RD', 'Cortelyou Rd']),
#  ('ave dumont', ['DUMONT AVE', 'Dumont Ave']),
#  ('ave h', ['AVE H', 'H AVE']),
#  ('174th e st', ['E 174TH ST', 'E 174th St']),
#  ('9th n st', ['N 9TH ST', 'N 9th St']),
#  ('st victor', ['Victor St', 'VICTOR ST']),
#  ('cameron ct', ['CAMERON CT', 'Cameron Ct']),
#  ('8th st w', ['W 8TH ST', 'W 8th St']),
#  ('176th st w', ['W 176TH ST', 'W 176th St']),
#  ('ave seagate', ['Seagate Ave', 'SEAGATE AVE']),
#  ('104th st', ['104TH ST', '104th St']),
#  ('allen st', ['ALLEN ST', 'Allen St']),
#  ('rd rutland', ['RUTLAND RD', 'RUTLAND  RD', 'Rutland Rd']),
#  ('ave neill', ['Neill Ave', 'NEILL AVE']),
#  ('blvd hill laurel', ['LAUREL HILL BLVD', 'Laurel Hill Blvd']),
#  ('ave railroad', ['Railroad Ave', 'RAILROAD AVE']),
#  ('jackson pl', ['JACKSON PL', 'Jackson Pl']),
#  ('bay pky', ['Bay Pky', 'BAY PKY']),
#  ('36th e st', ['E 36th St', 'E 36TH ST']),
#  ('59th e st', ['E 59TH ST', 'E 59th St']),
#  ('169th st', ['169TH ST', '169th St']),
#  ('ave terrace view', ['Terrace View Ave', 'TERRACE VIEW AVE']),
#  ('ave gunther', ['GUNTHER AVE', 'Gunther Ave']),
#  ('linden st', ['Linden St', 'LINDEN ST']),
#  ('ave mill', ['MILL AVE', 'Mill Ave']),
#  ('82nd rd', ['82nd Rd', '82ND RD']),
#  ('bergen st', ['BERGEN ST', 'Bergen St', 'BERGEN  ST']),
#  ('donough mac st', ['Mac Donough St', 'MAC DONOUGH ST']),
#  ('ave weeks', ['WEEKS AVE', 'Weeks Ave']),
#  ('ave douglas', ['DOUGLAS AVE', 'Douglas Ave']),
#  ('ave highlawn', ['HIGHLAWN AVE', 'Highlawn Ave']),
#  ('63rd rd', ['63RD RD', '63rd Rd']),
#  ('sickles st', ['Sickles St', 'SICKLES ST']),
#  ('park terrace west', ['PARK TERRACE WEST', 'Park Terrace West']),
#  ('ave montauk', ['Montauk Ave', 'MONTAUK AVE']),
#  ('ave balcom', ['BALCOM AVE', 'Balcom Ave']),
#  ('98 es st', ['E/S 98 ST', 'ES 98 ST']),
#  ('89th e st', ['E 89TH ST', 'E 89th St']),
#  ('229th e st', ['E 229th St', 'E 229TH ST']),
#  ('ave palmer', ['PALMER AVE', 'Palmer Ave']),
#  ('ave carter', ['CARTER AVE', 'Carter Ave']),
#  ('183rd e st', ['E 183rd St', 'E 183RD ST']),
#  ('26th e st', ['E 26TH  ST', 'E 26th St', 'E 26TH ST']),
#  ('8th ave', ['8th Ave', '8TH AVE', '8TH  AVE']),
#  ('110th st w', ['W 110TH ST', 'W 110th St']),
#  ('56th e st', ['E 56TH ST', 'E 56th St']),
#  ('75th st w', ['W 75TH ST', 'W 75th St']),
#  ('rd station', ['Station Rd', 'STATION RD']),
#  ('milton st', ['MILTON ST', 'Milton St']),
#  ('11th ave', ['11th Ave', '11TH AVE']),
#  ('ft hamilton pky', ['FT HAMILTON PKY', 'Ft Hamilton Pky']),
#  ('69th pl', ['69th Pl', '69TH PL']),
#  ('enfield pl', ['ENFIELD PL', 'Enfield Pl']),
#  ('17th beach st', ['Beach 17th St', 'BEACH 17TH ST']),
#  ('hausman st', ['Hausman St', 'HAUSMAN ST']),
#  ('amity st', ['AMITY ST', 'Amity St']),
#  ('kimberly pl', ['KIMBERLY PL', 'Kimberly Pl']),
#  ('gatling pl', ['Gatling Pl', 'GATLING PL']),
#  ('128th e st', ['E 128th St', 'E 128TH  ST', 'E 128TH ST']),
#  ('st willmohr', ['WILLMOHR ST', 'Willmohr St']),
#  ('220th st', ['220TH ST', '220th St']),
#  ('220th e st', ['E 220TH ST', 'E 220th St']),
#  ('liverpool st', ['Liverpool St', 'LIVERPOOL ST']),
#  ('ave viele', ['VIELE AVE', 'Viele Ave']),
#  ('170th st', ['170TH ST', '170th St']),
#  ('pilling st', ['Pilling St', 'PILLING ST']),
#  ('gleane st', ['Gleane St', 'GLEANE ST']),
#  ('ave ny', ['NY  AVE', 'NY AVE']),
#  ('debevoise st', ['DEBEVOISE ST', 'Debevoise St']),
#  ('ave new utrecht',
#   ['New Utrecht Ave', 'NEW UTRECHT  AVE', 'NEW UTRECHT AVE']),
#  ('167 st w', ['W .167 ST', 'W 167 ST']),
#  ('ave harrington', ['Harrington Ave', 'HARRINGTON AVE']),
#  ('ave sherman', ['Sherman Ave', 'SHERMAN AVE']),
#  ('fieldston rd', ['FIELDSTON RD', 'Fieldston Rd']),
#  ('nicholas st', ['Nicholas St', 'ST NICHOLAS']),
#  ('ave havemeyer', ['Havemeyer Ave', 'HAVEMEYER AVE']),
#  ('ave christie', ['CHRISTIE AVE', 'Christie Ave']),
#  ('ave kent', ['KENT AVE', 'Kent Ave']),
#  ('parkside pl', ['PARKSIDE PL', 'Parkside Pl']),
#  ('ct hurley', ['HURLEY CT', 'Hurley Ct']),
#  ('rd rugby', ['Rugby Rd', 'RUGBY RD']),
#  ('arlington pl', ['ARLINGTON PL', 'Arlington Pl']),
#  ('beach st', ['BEACH ST', 'Beach St']),
#  ('eastern pkwy', ['EASTERN PKWY', 'EASTERN  PKWY']),
#  ('ave siclen van', ['Van Siclen Ave', 'VAN SICLEN AVE', 'VAN SICLEN  AVE']),
#  ('midwood st', ['Midwood St', 'MIDWOOD ST']),
#  ('macdonough', ['MACDONOUGH', 'Macdonough']),
#  ('e fordham rd', ['E Fordham Rd', 'E FORDHAM RD']),
#  ('arlington terrace', ['Arlington Terrace', 'ARLINGTON TERRACE']),
#  ('83rd ave', ['83rd Ave', '83RD AVE']),
#  ('ave stadium', ['STADIUM AVE', 'Stadium Ave']),
#  ('ave burnside e', ['E Burnside Ave', 'E BURNSIDE AVE']),
#  ('ave morrison', ['MORRISON AVE', 'Morrison Ave']),
#  ('chester st', ['CHESTER ST', 'Chester St']),
#  ('ave edson', ['Edson Ave', 'EDSON AVE']),
#  ('pl schiefflin', ['Schiefflin Pl', 'SCHIEFFLIN PL']),
#  ('17th st w', ['W 17TH ST', 'W 17th St']),
#  ('lewiston st', ['LEWISTON ST', 'Lewiston St']),
#  ('central park west',
#   ['Central Park West',
#    'CENTRAL PARK  WEST',
#    'Central Park West.',
#    'CENTRAL PARK WEST']),
#  ('71st st', ['71st St', '71ST ST']),
#  ('ave narrows', ['NARROWS AVE', 'Narrows Ave']),
#  ('110th st', ['110th St', '110TH ST']),
#  ('plaza street west', ['Plaza Street West', 'PLAZA STREET WEST']),
#  ('dr regis', ['Regis Dr', 'REGIS DR']),
#  ('ave catalpa', ['CATALPA AVE', 'Catalpa Ave']),
#  ('blvd kissena', ['Kissena Blvd', 'KISSENA BLVD']),
#  ('135th st w', ['W 135TH ST', 'W 135th St']),
#  ('bedford co', ['C/O  BEDFORD', 'C/O BEDFORD']),
#  ('ave euclid', ['EUCLID AVE', 'Euclid Ave']),
#  ('124th pl', ['124TH PL', '124th Pl']),
#  ('75th ave', ['75th Ave', '75TH AVE']),
#  ('es market slip', ['E/S MARKET SLIP', 'E/S  MARKET SLIP']),
#  ('ave holland', ['HOLLAND AVE', 'Holland Ave']),
#  ('dominick st', ['Dominick St', 'DOMINICK ST']),
#  ('blvd center', ['Center Blvd', 'CENTER BLVD']),
#  ('ave gurley', ['GURLEY AVE', 'Gurley Ave']),
#  ('smith st', ['SMITH ST', 'Smith St']),
#  ('ave union', ['UNION  AVE', 'Union Ave', 'UNION AVE']),
#  ('ave eagle', ['Eagle Ave', 'EAGLE AVE']),
#  ('87th rd', ['87TH RD', '87th Rd']),
#  ('ave sterling', ['Sterling Ave', 'STERLING AVE']),
#  ('ave blackrock', ['Blackrock Ave', 'BLACKROCK AVE']),
#  ('ave creston', ['Creston Ave', 'CRESTON AVE']),
#  ('devoe st', ['DEVOE ST', 'Devoe St']),
#  ('ave greene', ['GREENE AVE', 'Greene Ave']),
#  ('kane st', ['Kane St', 'KANE ST']),
#  ('ave nassau', ['Nassau Ave', 'NASSAU AVE']),
#  ('82nd st', ['82nd St', '82ND ST']),
#  ('115th e st', ['E 115th St', 'E 115TH ST']),
#  ('hooper st', ['HOOPER ST', 'Hooper St']),
#  ('rd shore', ['SHORE RD', 'Shore Rd']),
#  ('catherine slip', ['Catherine Slip', 'CATHERINE SLIP']),
#  ('ave sunnyside', ['SUNNYSIDE AVE', 'Sunnyside Ave']),
#  ('ave dix', ['DIX AVE', 'Dix Ave']),
#  ('ave howard', ['Howard Ave', 'HOWARD AVE']),
#  ('7th e st', ['E 7th St', 'E 7TH ST']),
#  ('ave parkside', ['PARKSIDE AVE', 'Parkside Ave']),
#  ('ave mickle', ['MICKLE AVE', 'Mickle Ave']),
#  ('ave beach', ['BEACH  AVE', 'BEACH AVE', 'Beach Ave']),
#  ('205th e st', ['E 205TH ST', 'E 205th St']),
#  ('ave veterans', ['Veterans Ave', 'VETERANS AVE']),
#  ('2nd e st', ['E 2ND ST', 'E 2nd St']),
#  ('ave virginia', ['VIRGINIA AVE', 'Virginia Ave']),
#  ('29th ave', ['29TH AVE', '29th Ave']),
#  ('st warren', ['WARREN ST', 'Warren St']),
#  ('62nd st', ['62nd St', '62ND ST']),
#  ('ave norwood', ['NORWOOD AVE', 'Norwood Ave']),
#  ('ave inwood', ['INWOOD AVE', 'Inwood Ave']),
#  ('25th st', ['25TH ST', '25th St']),
#  ('craven st', ['Craven St', 'CRAVEN ST']),
#  ('ave maspeth', ['Maspeth Ave', 'MASPETH AVE']),
#  ('ave shakespeare', ['SHAKESPEARE AVE', 'Shakespeare Ave']),
#  ('164th e st', ['E 164th St', 'E 164TH ST']),
#  ('48th e st', ['E 48TH ST', 'E 48th St']),
#  ('ave netherland', ['NETHERLAND AVE', 'Netherland Ave']),
#  ('46th rd', ['46TH RD', '46th Rd']),
#  ('pinegrove st', ['PINEGROVE ST', 'Pinegrove St']),
#  ('ave onderdonk', ['Onderdonk Ave', 'ONDERDONK AVE']),
#  ('92nd st w', ['W 92nd St', 'W 92ND ST']),
#  ('exeter st', ['Exeter St', 'EXETER ST']),
#  ('29th st', ['29TH ST', '29th St']),
#  ('ave darlington', ['Darlington Ave', 'DARLINGTON AVE']),
#  ('193rd st', ['193RD ST', '193rd St']),
#  ('111th st w', ['W 111th St', 'W 111TH ST']),
#  ('skillman st', ['SKILLMAN ST', 'Skillman St']),
#  ('banker st', ['BANKER ST', 'Banker St', 'BANKER  ST']),
#  ('18th e st', ['E 18TH ST', 'E 18th St']),
#  ('oliver pl', ['Oliver Pl', 'OLIVER PL']),
#  ('livingston st', ['LIVINGSTON  ST', 'LIVINGSTON ST', 'Livingston St']),
#  ('125th st', ['125th St', '125TH ST']),
#  ('ave barker', ['BARKER AVE', 'Barker Ave']),
#  ('89th ave', ['89TH AVE', '89th Ave']),
#  ('ave sheldon', ['Sheldon Ave', 'SHELDON AVE']),
#  ('47th st w', ['W 47TH ST', 'W 47th St']),
#  ('rd veterans', ['Veterans Rd', 'VETERANS RD']),
#  ('rd richmond', ['RICHMOND RD', 'Richmond Rd']),
#  ('ave roberts', ['Roberts Ave', 'ROBERTS AVE']),
#  ('antin pl', ['ANTIN PL', 'Antin Pl']),
#  ('broadway', ['Broadway', 'BROADWAY']),
#  ('ave wallace', ['WALLACE AVE', 'Wallace Ave']),
#  ('238th st w', ['W 238TH ST', 'W 238th St']),
#  ('72nd st', ['72ND ST', '72nd St']),
#  ('clara st', ['CLARA ST', 'Clara St']),
#  ('lorillard pl', ['LORILLARD PL', 'Lorillard Pl']),
#  ('adee ave', ['ADEE  AVE', 'Adee Ave', 'ADEE AVE']),
#  ('ave brighton w', ['W Brighton Ave', 'W BRIGHTON AVE']),
#  ('162nd st w', ['W 162nd St', 'W 162ND ST']),
#  ('ave irving', ['IRVING AVE', 'Irving Ave', 'IRVING  AVE']),
#  ('ave boller', ['BOLLER AVE', 'Boller Ave']),
#  ('99 street', ['99 STREET', '99  STREET']),
#  ('gipson st', ['GIPSON ST', 'Gipson St']),
#  ('ave rochambeau', ['Rochambeau Ave', 'ROCHAMBEAU AVE']),
#  ('gerber pl', ['GERBER PL', 'Gerber Pl']),
#  ('st york', ['York St', 'YORK ST']),
#  ('ave surf', ['Surf Ave', 'SURF AVE']),
#  ('aqueduct ave', ['Aqueduct Ave', 'AQUEDUCT AVE']),
#  ('eastern pky', ['Eastern Pky', 'EASTERN PKY']),
#  ('27th st w', ['W 27th St', 'W 27TH ST']),
#  ('138th st w', ['W 138TH ST', 'W 138th St']),
#  ('hewes st', ['Hewes St', 'HEWES ST']),
#  ('church st', ['CHURCH ST', 'Church St', 'ST CHURCH ST']),
#  ('106th e st', ['E 106TH ST', 'E 106th St']),
#  ('190th st w', ['W 190TH ST', 'W 190th St']),
#  ('gerry st', ['GERRY ST', 'Gerry St']),
#  ('8th st', ['8th St', '8TH ST']),
#  ('47th ave', ['47TH AVE', '47th Ave']),
#  ('36th st w', ['W 36TH ST', 'W 36th St']),
#  ('77th st w', ['W 77th St', 'W 77TH ST']),
#  ('atkins ave', ['Atkins Ave', 'ATKINS AVE']),
#  ('ave mohegan', ['Mohegan Ave', 'MOHEGAN AVE']),
#  ('137th st w', ['W 137th St', 'W 137TH ST']),
#  ('ave manhattan', ['Manhattan Ave', 'MANHATTAN AVE']),
#  ('ave ross', ['Ross Ave', 'ROSS AVE']),
#  ('st washington', ['WASHINGTON ST', 'Washington St']),
#  ('ave church', ['CHURCH  AVE', 'Church Ave', 'CHURCH AVE']),
#  ('30 w', ['W 30', 'W .30']),
#  ('144 st w', ['W .144 ST', 'W 144 ST']),
#  ('ave banner', ['BANNER AVE', 'Banner Ave']),
#  ('ave gleason', ['GLEASON AVE', 'Gleason Ave']),
#  ('avenue t', ['AVENUE T', 'Avenue T']),
#  ('court sq', ['COURT SQ', 'Court Sq']),
#  ('212th st', ['212TH ST', '212th St']),
#  ('ave hoover', ['HOOVER AVE', 'Hoover Ave']),
#  ('pl sullivan', ['Sullivan Pl', 'SULLIVAN PL']),
#  ('4 south', ['SOUTH  4', 'SOUTH 4']),
#  ('ave birchall', ['Birchall Ave', 'BIRCHALL AVE']),
#  ('ave dahlia', ['Dahlia Ave', 'DAHLIA AVE']),
#  ('portal st', ['Portal St', 'PORTAL ST']),
#  ('pl seton', ['Seton Pl', 'SETON PL']),
#  ('ave brook', ['BROOK AVE', 'Brook Ave']),
#  ('roxbury st', ['ROXBURY ST', 'Roxbury St']),
#  ('5 ave', ['5 AVE', '5  AVE']),
#  ('ave howard ws', ['W/S HOWARD AVE', 'W/S  HOWARD AVE']),
#  ('ave paidge', ['Paidge Ave', 'PAIDGE AVE']),
#  ('bloomingdale rd', ['BLOOMINGDALE RD', 'Bloomingdale Rd']),
#  ('pl tiemann', ['Tiemann Pl', 'TIEMANN PL']),
#  ('freeport loop', ['FREEPORT LOOP', 'Freeport Loop']),
#  ('ln maiden', ['MAIDEN LN', 'Maiden Ln']),
#  ('linwood st', ['Linwood St', 'LINWOOD ST']),
#  ('ave schiefflin', ['SCHIEFFLIN AVE .', 'SCHIEFFLIN AVE']),
#  ('nevins st', ['Nevins St', 'NEVINS ST']),
#  ('ave saratoga', ['Saratoga Ave', 'SARATOGA AVE']),
#  ('ave valles', ['Valles Ave', 'VALLES AVE']),
#  ('beekman st', ['Beekman St', 'BEEKMAN ST']),
#  ('eyck ten walk', ['Ten Eyck Walk', 'TEN EYCK WALK']),
#  ('28th st', ['28TH ST', '28th St']),
#  ('ave pratt', ['Pratt Ave', 'PRATT AVE']),
#  ('ave spencer', ['Spencer Ave', 'SPENCER AVE']),
#  ('dash pl', ['Dash Pl', 'DASH PL']),
#  ('dr essex', ['Essex Dr', 'ESSEX DR']),
#  ('amber st', ['AMBER ST', 'Amber St']),
#  ('ave mangin', ['MANGIN AVE', 'Mangin Ave']),
#  ('ave thomson', ['Thomson Ave', 'THOMSON AVE']),
#  ('ave irwin', ['IRWIN AVE', 'Irwin Ave']),
#  ('ave lafontaine', ['Lafontaine Ave', 'LAFONTAINE AVE']),
#  ('ave skillman', ['SKILLMAN AVE', 'Skillman Ave']),
#  ('barretto st', ['BARRETTO ST', 'Barretto St']),
#  ('colonial rd', ['COLONIAL RD', 'Colonial Rd']),
#  ('12th e st', ['E 12TH ST', 'E 12th St']),
#  ('manning st', ['MANNING ST', 'Manning St']),
#  ('clinton pl', ['CLINTON PL', 'Clinton Pl']),
#  ('ave tillotson', ['Tillotson Ave', 'TILLOTSON AVE']),
#  ('ct dana', ['DANA CT', 'Dana Ct']),
#  ('george st', ['George St', 'GEORGE ST']),
#  ('132nd e st', ['E 132ND ST', 'E 132nd St']),
#  ('48th ave', ['48TH AVE', '48th Ave']),
#  ('ave graham', ['GRAHAM  AVE', 'Graham Ave', 'GRAHAM AVE']),
#  ('crown st', ['Crown St', 'CROWN ST .', 'CROWN ST']),
#  ('lombardy st', ['Lombardy St', 'LOMBARDY ST']),
#  ('ave wyckoff', ['Wyckoff Ave', 'WYCKOFF AVE']),
#  ('175th st w', ['W 175th St', 'W 175TH ST']),
#  ('ave stronghurst', ['Stronghurst Ave', 'STRONGHURST AVE']),
#  ('ave jackson', ['JACKSON AVE.', 'JACKSON AVE', 'Jackson Ave']),
#  ('ave prospect', ['PROSPECT AVE', 'PROSPECT  AVE', 'Prospect Ave']),
#  ('st strauss', ['Strauss St', 'STRAUSS ST']),
#  ('ave beech', ['Beech Ave', 'BEECH AVE']),
#  ('88th st w', ['W 88th St', 'W 88TH ST']),
#  ('ave richmond', ['Richmond Ave', 'RICHMOND AVE']),
#  ('9th st', ['9TH ST', '9th St']),
#  ('ave east ny', ['EAST NY AVE', 'EAST NY  AVE']),
#  ('duffield st', ['Duffield St', 'DUFFIELD ST']),
#  ('ave edwards', ['EDWARDS AVE', 'Edwards Ave']),
#  ('ave flatbush', ['FLATBUSH AVE', 'Flatbush Ave']),
#  ('63rd e st', ['E 63rd St', 'E 63RD ST']),
#  ('ave main', ['Main Ave', 'MAIN AVE']),
#  ('178th st w', ['W 178th St', 'W 178TH ST']),
#  ('ave lyon', ['LYON AVE', 'Lyon Ave']),
#  ('ave carpenter', ['Carpenter Ave', 'CARPENTER AVE']),
#  ('drew st', ['Drew St', 'DREW ST']),
#  ('ave rathbun', ['Rathbun Ave', 'RATHBUN AVE']),
#  ('67th rd', ['67TH RD', '67th Rd']),
#  ('ave barnett', ['Barnett Ave', 'BARNETT AVE']),
#  ('ave titus', ['Titus Ave', 'TITUS AVE']),
#  ('park prospect west',
#   ['PROSPECT PARK WEST+', 'Prospect Park West', 'PROSPECT PARK WEST']),
#  ('ave hunts point', ['Hunts Point Ave', 'HUNTS POINT AVE']),
#  ('st varick', ['VARICK ST', 'Varick St']),
#  ('165th st w', ['W 165th St', 'W 165TH ST']),
#  ('st worthen', ['Worthen St', 'WORTHEN ST']),
#  ('pelham pkwy south', ['PELHAM PKWY  SOUTH', 'PELHAM PKWY SOUTH']),
#  ('ave pople', ['POPLE AVE', 'Pople Ave']),
#  ('ave breeze sea', ['SEA BREEZE AVE', 'Sea Breeze Ave']),
#  ('avenue n', ['Avenue N', 'AVENUE N']),
#  ('27th e st', ['E 27TH ST', 'E 27th St']),
#  ('blvd garvey marcus', ['MARCUS GARVEY BLVD', 'Marcus Garvey Blvd']),
#  ('53rd e st', ['E 53rd St', 'E 53RD ST']),
#  ('almeda ave', ['ALMEDA AVE', 'ALMEDA  AVE', 'Almeda Ave']),
#  ('remsen st', ['REMSEN ST', 'Remsen St']),
#  ('bragg st', ['BRAGG ST', 'Bragg St']),
#  ('ave redfern', ['REDFERN AVE', 'Redfern Ave']),
#  ('shiloh st', ['SHILOH ST', 'Shiloh St']),
#  ('17th st', ['17TH ST', '17th St']),
#  ('8 avenue', ['8 AVENUE', '8  AVENUE']),
#  ('miriam st', ['Miriam St', 'MIRIAM ST']),
#  ('ave saxon', ['SAXON AVE', 'Saxon Ave']),
#  ('ave barrett', ['Barrett Ave', 'BARRETT AVE']),
#  ('scholes st', ['Scholes St', 'SCHOLES ST']),
#  ('blvd winchester', ['Winchester Blvd', 'WINCHESTER BLVD']),
#  ('monroe st', ['MONROE ST', 'Monroe St']),
#  ('ave columbus', ['COLUMBUS  AVE', 'Columbus Ave', 'COLUMBUS AVE']),
#  ('maujer st', ['MAUJER ST', 'Maujer St']),
#  ('himrod st', ['Himrod St', 'HIMROD ST']),
#  ('87th e st', ['E 87th St', 'E 87TH ST']),
#  ('benchley pl', ['Benchley Pl', 'BENCHLEY PL']),
#  ('blvd olympia', ['OLYMPIA BLVD', 'Olympia Blvd']),
#  ('ave cebra', ['Cebra Ave', 'CEBRA AVE']),
#  ('ave kearney', ['Kearney Ave', 'KEARNEY AVE']),
#  ('argyle rd', ['Argyle Rd', 'ARGYLE RD']),
#  ('148th st', ['148TH ST', '148th St']),
#  ('freedom pl', ['FREEDOM PL', 'Freedom Pl']),
#  ('boss st', ['BOSS ST', 'Boss St']),
#  ('ave e new york', ['E New York Ave', 'E NEW YORK AVE']),
#  ('arden st', ['Arden St', 'ARDEN ST']),
#  ('ave james st', ['St James Ave', 'ST JAMES AVE']),
#  ('ave clarkson', ['CLARKSON AVE', 'Clarkson Ave']),
#  ('237th e st', ['E 237TH ST', 'E 237th St']),
#  ('112th e st', ['E 112TH ST', 'E 112th St']),
#  ('ave woehrle', ['Woehrle Ave', 'WOEHRLE  AVE', 'WOEHRLE AVE']),
#  ('68th e st', ['E 68th St', 'E 68TH ST']),
#  ('clarendon rd', ['Clarendon Rd', 'CLARENDON RD']),
#  ('knox pl', ['Knox Pl', 'KNOX PL']),
#  ('bethune st', ['Bethune St', 'BETHUNE ST']),
#  ('clymer st', ['CLYMER ST', 'Clymer St']),
#  ('montague st', ['MONTAGUE  ST', 'MONTAGUE ST', 'Montague St']),
#  ('ave lockman', ['Lockman Ave', 'LOCKMAN AVE']),
#  ('218th st w', ['W 218TH ST', 'W 218th St']),
#  ('arthur ave', ['Arthur Ave', 'ARTHUR AVE']),
#  ('st stanhope', ['STANHOPE ST', 'Stanhope St']),
#  ('103 e st', ['E 103 ST', 'E .103 ST']),
#  ('ave richard', ['RICHARD AVE', 'Richard Ave']),
#  ('st troutman', ['TROUTMAN ST', 'Troutman St']),
#  ('84th st', ['84th St', '84TH ST', '84TH  ST']),
#  ('ave haven new', ['New Haven Ave', 'NEW HAVEN AVE']),
#  ('catherine st', ['CATHERINE ST .', 'CATHERINE ST', 'Catherine St']),
#  ('cass pl', ['Cass Pl', 'CASS PL']),
#  ('165th st', ['165TH ST', '165th St']),
#  ('pioneer st', ['Pioneer St', 'PIONEER ST']),
#  ('ave pugsley', ['Pugsley Ave', 'PUGSLEY AVE']),
#  ('34th st w', ['W 34TH ST', 'W 34th St']),
#  ('ave clay', ['Clay Ave', 'CLAY AVE']),
#  ('219th e st', ['E 219th St', 'E 219TH ST']),
#  ('attorney st', ['ATTORNEY ST', 'Attorney St']),
#  ('ave edgecombe', ['Edgecombe Ave', 'EDGECOMBE AVE']),
#  ('183rd st w', ['W 183RD ST', 'W 183rd St']),
#  ('ave katan', ['Katan Ave', 'KATAN AVE']),
#  ('186th st w', ['W 186th St', 'W 186TH ST']),
#  ('ln ludwig', ['LUDWIG LN', 'Ludwig Ln']),
#  ('14th ave', ['14TH AVE', '14th Ave']),
#  ('av siclen van', ['VAN  SICLEN AV', 'VAN SICLEN AV']),
#  ('bronx co nw park', ['N/W  C/O BRONX PARK', 'N/W C/O BRONX PARK']),
#  ('seigel st', ['Seigel St', 'SEIGEL ST']),
#  ('86th st w', ['W 86th St', 'W 86TH ST']),
#  ('ave beaumont', ['Beaumont Ave', 'BEAUMONT AVE']),
#  ('95 e st', ['E .95 ST', 'E 95 ST']),
#  ('ave dekalb', ['Dekalb Ave', 'DEKALB AVE', 'DEKALB  AVE']),
#  ('27th ave', ['27TH AVE', '27th Ave']),
#  ('ave walnut', ['Walnut Ave', 'WALNUT AVE']),
#  ('ave pearsall', ['PEARSALL AVE', 'Pearsall Ave']),
#  ('co montauk st', ['C/O MONTAUK ST', 'C/O  MONTAUK ST']),
#  ('pl timpson', ['Timpson Pl', 'TIMPSON PL']),
#  ('e houston st', ['E Houston St', 'E HOUSTON ST', 'E Houston St.']),
#  ('nansen st', ['NANSEN ST', 'Nansen St']),
#  ('barbey st', ['BARBEY ST', 'Barbey St']),
#  ('rd watchogue', ['WATCHOGUE RD', 'Watchogue Rd']),
#  ('ave goulden', ['GOULDEN AVE', 'Goulden Ave']),
#  ('bedford blvd pk', ['BEDFORD  PK BLVD', 'BEDFORD PK BLVD']),
#  ('johnson st', ['JOHNSON ST', 'Johnson St']),
#  ('manhattan st', ['Manhattan St', 'MANHATTAN ST']),
#  ('division st', ['DIVISION ST', 'Division St']),
#  ('18th st', ['18th St', '18TH ST']),
#  ('evelyn pl', ['EVELYN PL', 'Evelyn Pl']),
#  ('richmond st', ['Richmond St', 'RICHMOND ST']),
#  ('light st', ['LIGHT ST', 'Light St']),
#  ('fitchett st', ['Fitchett St', 'FITCHETT ST']),
#  ('ave seaver', ['Seaver Ave', 'SEAVER AVE']),
#  ('ave lamont', ['Lamont Ave', 'LAMONT AVE']),
#  ('150 st w', ['W 150 ST', 'W 150  ST']),
#  ('dalny rd', ['Dalny Rd', 'DALNY RD']),
#  ('montauk st', ['Montauk St', 'MONTAUK ST']),
#  ('essex st', ['ESSEX ST', 'Essex St']),
#  ('211th e st', ['E 211TH ST', 'E 211th St']),
#  ('baruch dr', ['Baruch Dr', 'BARUCH DR']),
#  ('ave hudson', ['Hudson Ave', 'HUDSON AVE']),
#  ('godwin ter', ['Godwin Ter', 'GODWIN TER']),
#  ('ln tysens', ['Tysens Ln', 'TYSENS LN']),
#  ('nameoke st', ['NAMEOKE ST', 'Nameoke St']),
#  ('christopher st', ['Christopher St', 'CHRISTOPHER ST']),
#  ('136th ave', ['136TH AVE', '136th Ave']),
#  ('baxter st', ['Baxter St', 'BAXTER ST']),
#  ('ave bogart', ['Bogart Ave', 'BOGART AVE']),
#  ('hart st', ['Hart St', 'HART  ST', 'HART ST']),
#  ('eyck st ten', ['TEN EYCK ST', 'Ten Eyck St']),
#  ('ave story', ['Story Ave', 'STORY AVE']),
#  ('ave tilden', ['TILDEN AVE', 'Tilden Ave']),
#  ('quincy st', ['QUINCY ST', 'Quincy St']),
#  ('145th dr', ['145th Dr', '145TH DR']),
#  ('isham st', ['ISHAM ST', 'Isham St']),
#  ('ave convent', ['CONVENT AVE', 'Convent Ave']),
#  ('brabant st', ['BRABANT ST', 'Brabant St']),
#  ('ave coney island',
#   ['CONEY ISLAND AVE .',
#    'CONEY  ISLAND AVE',
#    'CONEY ISLAND AVE',
#    'Coney Island Ave']),
#  ('151st e st', ['E 151ST ST', 'E 151st St']),
#  ('30th st', ['30TH ST', '30th St']),
#  ('ave longstreet', ['Longstreet Ave', 'LONGSTREET AVE']),
#  ('av lots new', ['NEW LOTS  AV', 'NEW LOTS AV']),
#  ('122nd st', ['122ND ST', '122nd St']),
#  ('ave grant', ['GRANT AVE', 'Grant Ave']),
#  ...]

# %%
street_name_rdd.take(3)
# Out:
# ['Mount Hope Pl', 'Carver Loop', 'Rombouts Ave']

# %%
# apply the fingerprint to all street addresses
#[('court square', 'COURT SQUARE'),
# ('31 e st', 'E 31 ST'),
# ('island randalls', 'RANDALLS ISLAND'),
# ('45th e street', 'E 45TH STREET'),
# ('ave sheridan', 'SHERIDAN AVE')]
street_name_rdd.distinct(). \
	map(fingerprint). \
	collect()
# Out:
# [('ave sheridan', 'SHERIDAN AVE'),
#  ('a jerome street west', 'WEST STREET JEROME A'),
#  ('ave monticello', 'Monticello Ave'),
#  ('richmond terale', 'RICHMOND TERALE'),
#  ('dr riverside', 'RIVERSIDE  DR'),
#  ('ns remser st', 'N/S REMSER ST'),
#  ('gorsline st', 'GORSLINE ST'),
#  ('fame hall of terrace', 'HALL OF FAME TERRACE'),
#  ('ave kingsland', 'Kingsland Ave'),
#  ('6 ave co sw', 'SW C/O 6 AVE'),
#  ('ave schenck', 'SCHENCK AVE'),
#  ('avenue givan', 'GIVAN AVENUE'),
#  ('31st ave', '31st Ave'),
#  ('ave bolton', 'Bolton Ave'),
#  ('st waldron', 'Waldron St'),
#  ('pl regent', 'Regent Pl'),
#  ('118 st w', 'W 118 ST'),
#  ('52 e str', 'E 52 STR'),
#  ('100 st', '100 ST'),
#  ('autumn ave', 'AUTUMN AVE'),
#  ('172 co e', 'C/O E 172'),
#  ('av jamaica', 'JAMAICA AV'),
#  ('cedar', 'CEDAR'),
#  ('ave porter', 'Porter Ave'),
#  ('gordon st', 'Gordon St'),
#  ('ashland pl', 'ASHLAND PL'),
#  ('227 east', 'EAST 227'),
#  ('avenue manor', 'MANOR AVENUE'),
#  ('ave claflin co', 'C/O CLAFLIN AVE'),
#  ('58 beach street', 'BEACH 58 STREET'),
#  ('ave fort george', 'FORT GEORGE AVE'),
#  ('blvd riverside', 'RIVERSIDE BLVD'),
#  ('ave claklin', 'CLAKLIN AVE'),
#  ('calloway street', 'CALLOWAY STREET'),
#  ('avenue wilson', 'WILSON AVENUE'),
#  ('129th beach st', 'Beach 129th St'),
#  ('dr gothic', 'Gothic Dr'),
#  ('129 st w', 'W 129 ST'),
#  ('buchanan pl', 'BUCHANAN PL'),
#  ('94th dr', '94th Dr'),
#  ('91st pl', '91st Pl'),
#  ('167 street west', 'WEST 167 STREET'),
#  ('192 e ssm', 'S/SM E 192'),
#  ('149 ave co sw', 'S/W C/O 149 AVE'),
#  ('blvd eb northern', 'NORTHERN BLVD (E/B)'),
#  ('163rd ave', '163rd Ave'),
#  ('dr radio', 'Radio Dr'),
#  ('bay parkway ridge', 'BAY RIDGE PARKWAY'),
#  ('avbe corsa', 'CORSA AVBE'),
#  ('12 north st', 'NORTH 12 ST'),
#  ('ave co eny', 'C/O ENY AVE'),
#  ('adrian ave', 'Adrian Ave'),
#  ('co fernside', 'C/O FERNSIDE'),
#  ('4th kingsbourgh walk', 'KINGSBOURGH 4TH WALK'),
#  ('47th st west', 'WEST 47TH ST'),
#  ('ave puritan', 'PURITAN AVE'),
#  ('canal pl', 'CANAL PL'),
#  ('co olmstead', 'C/O OLMSTEAD'),
#  ('e118 st', 'E.118 ST'),
#  ('125 co street', 'C/O 125 STREET'),
#  ('30th ns st', 'N/S 30TH ST'),
#  ('ave hudson', 'HUDSON AVE'),
#  ('amport laguardia', 'LAGUARDIA AMPORT'),
#  ('w42', 'W42'),
#  ('berkey pl', 'BERKEY PL'),
#  ('byrd street', 'BYRD STREET'),
#  ('ave castle hill nb', 'NB CASTLE HILL AVE @'),
#  ('50 ns st w', 'N/S W 50 ST'),
#  ('oak pl tree', 'Oak Tree Pl'),
#  ('abingdon road', 'ABINGDON ROAD'),
#  ('49th avenue lic', '49TH AVENUE LIC'),
#  ('8 east', 'EAST 8'),
#  ('bareto st', 'BARETO ST'),
#  ('ave melvin', 'Melvin Ave'),
#  ('belair rd', 'Belair Rd'),
#  ('ave figurea', 'Figurea Ave'),
#  ('ave es reofern', 'E/S REOFERN AVE'),
#  ('ave green ns', 'N/S GREEN AVE'),
#  ('167 co st w', 'C/O W 167 ST'),
#  ('center metro tech', 'METRO TECH CENTER'),
#  ('co degraw ne st', 'N/E C//O DEGRAW ST'),
#  ('bay co pkwy sw', 'S/W C/O BAY PKWY'),
#  ('allen ss st', 'S/S ALLEN ST'),
#  ('224 co e st', 'C/O E 224 ST'),
#  ('45 e ne of side st', 'N/E SIDE OF E 45 ST'),
#  ('avenue hull', 'HULL AVENUE'),
#  ('13 bay st', 'BAY 13 ST'),
#  ('4th brighton street', 'BRIGHTON 4TH STREET'),
#  ('aqueduc ave', 'AQUEDUC AVE'),
#  ('blvd college point', 'College Point Blvd'),
#  ('ave rodgers', 'RODGERS AVE'),
#  ('1st brighton pl', 'Brighton 1st Pl'),
#  ('159 st', '159 ST'),
#  ('broadway st', 'BROADWAY ST'),
#  ('ave groua', 'GROUA AVE'),
#  ('ave selwyn', 'SELWYN AVE'),
#  ('66 rd', '66 RD'),
#  ('ave rome', 'Rome Ave'),
#  ('10 ave', '10 AVE'),
#  ('avenue morris park', 'MORRIS PARK AVENUE'),
#  ('222 co e ne', 'NE C/O E 222'),
#  ('18th avenue', '18TH AVENUE'),
#  ('97th ave', '97TH AVE'),
#  ('ave rogers', 'Rogers Ave'),
#  ('122 st w', 'W 122 ST'),
#  ('college manhattan pw', 'MANHATTAN COLLEGE PW'),
#  ('fernside place', 'FERNSIDE PLACE'),
#  ('davidson', 'DAVIDSON'),
#  ('donizetti pl', 'Donizetti Pl'),
#  ('av church co nw', 'NW C/O CHURCH AV'),
#  ('212 e ns st', 'N/S E 212 ST'),
#  ('richmond terr', 'RICHMOND TERR'),
#  ('harlem pl river', 'HARLEM RIVER PL'),
#  ('clatemont pkwy', 'CLATEMONT PKWY'),
#  ('135th pl', '135th Pl'),
#  ('bronx co river', 'C/O BRONX RIVER'),
#  ('70 st west', 'WEST 70 ST'),
#  ('blvd south', 'SOUTH BLVD'),
#  ('nicholas pl st', 'St Nicholas Pl'),
#  ('hull st', 'Hull St'),
#  ('ave schurz', 'Schurz Ave'),
#  ('merrill st', 'Merrill St'),
#  ('co glenwood ne rd', 'NE C/O GLENWOOD RD'),
#  ('place sterlng', 'STERLNG PLACE'),
#  ('richmond terrale', 'RICHMOND TERRALE'),
#  ('150 e st', 'E 150 ST'),
#  ('39th w', 'W  39TH'),
#  ('125 b st', 'B . 125 ST'),
#  ('markham pl', 'MARKHAM PL'),
#  ('cinnolin st', 'CINNOLIN ST'),
#  ('199 cp dr', 'C/P 199 DR'),
#  ('ave co foster sw', 'SW C/O FOSTER AVE'),
#  ('142 street w', 'W 142 STREET'),
#  ('es expwy whitestone', 'E/S WHITESTONE EXPWY'),
#  ('124 co street', 'C/O 124 STREET'),
#  ('boad bogby', 'BOGBY BOAD'),
#  ('ave co matthews ne', 'N/E C/O MATTHEWS AVE'),
#  ('151st st', '151st St'),
#  ('albee sq', 'Albee Sq'),
#  ('ericson pl', 'Ericson Pl'),
#  ('pl polhemus', 'POLHEMUS PL'),
#  ('21 streey west', 'WEST 21 STREEY'),
#  ('co paul pl st', 'C/O ST PAUL PL'),
#  ('226th drive', '226TH DRIVE'),
#  ('2nd co e st', 'C/O E 2ND ST'),
#  ('25rd st', '25RD ST'),
#  ('3rd e', 'E 3RD'),
#  ('conduit n', 'N CONDUIT'),
#  ('227th st w', 'W 227TH ST'),
#  ('ave forest s wb', 'FOREST AVE (W/B) @ S'),
#  ('conover st', 'Conover St'),
#  ('63rd dr es', 'E/S 63RD DR'),
#  ('ave valles', 'Valles Ave'),
#  ('co fresh meadow nw', 'N/W C/O FRESH MEADOW'),
#  ('178 w', 'W 178'),
#  ('132 co st sw', 'S/W C/O 132 ST'),
#  ('barclay', 'BARCLAY'),
#  ('143 43 oo st west', 'O/O 143 WEST 43 ST'),
#  ('bathgate', 'BATHGATE'),
#  ('metroploitan oval', 'METROPLOITAN OVAL'),
#  ('7 brighton street', 'BRIGHTON 7 STREET'),
#  ('114th st', '114th St'),
#  ('cambridge rd', 'Cambridge Rd'),
#  ('pl regent', 'REGENT PL'),
#  ('purdy street', 'PURDY STREET'),
#  ('ave seabreeze ss', 'S/S SEABREEZE AVE'),
#  ('ave treadwell', 'Treadwell Ave'),
#  ('ave eny', 'ENY AVE'),
#  ('ave garmin', 'GARMIN AVE'),
#  ('ave noble', 'Noble Ave'),
#  ('st weehawken', 'Weehawken St'),
#  ('road state', 'STATE ROAD'),
#  ('79 street', '79 STREET'),
#  ('ave co conklin se', 'S/E C/O CONKLIN AVE'),
#  ('herbert st', 'HERBERT ST+'),
#  ('pl verveelen', 'Verveelen Pl'),
#  ('104 street', '104 STREET'),
#  ('38th e st', 'E 38th St'),
#  ('ave n', 'AVE N'),
#  ('ave jefferson', 'JEFFERSON AVE'),
#  ('89 e', 'E 89'),
#  ('ave hamson', 'HAMSON AVE'),
#  ('ave ellis', 'Ellis Ave'),
#  ('farraday st', 'Farraday St'),
#  ('king luther martin p', 'Martin Luther King P'),
#  ('neilson', 'NEILSON'),
#  ('co cruger', 'C/O CRUGER'),
#  ('rd woodpoint', 'Woodpoint Rd'),
#  ('elsmere pl', 'Elsmere Pl'),
#  ('garden pl', 'Garden Pl'),
#  ('ave shepherd', 'Shepherd Ave'),
#  ('huron st', 'Huron St'),
#  ('brown st', 'Brown St'),
#  ('av lexington', 'LEXINGTON AV'),
#  ('ann ave st', 'ST ANN AVE'),
#  ('co ne springfield', 'N/E C/O SPRINGFIELD'),
#  ('90 w', 'W 90'),
#  ('pl springfield', 'SPRINGFIELD PL'),
#  ('ave byran', 'BYRAN AVE'),
#  ('84 ave co', 'C/O 84 AVE'),
#  ('14 brighton st', 'BRIGHTON 14 ST'),
#  ('118 co st w', 'C/O W 118 ST'),
#  ('bushwick', 'BUSHWICK'),
#  ('17 co e', 'C/O E 17'),
#  ('devenshire rd', 'DEVENSHIRE RD'),
#  ('dike place', 'DIKE PLACE'),
#  ('15 nw st w', 'N/W W 15 ST'),
#  ('230 of side washingt', 'SIDE OF 230 WASHINGT'),
#  ('wyona', 'WYONA'),
#  ('beach blv rockkaway', 'ROCKKAWAY BEACH BLV'),
#  ('inwood st', 'INWOOD ST'),
#  ('loring st', 'LORING ST'),
#  ('av eb steinwa travis', 'EB TRAVIS AV STEINWA'),
#  ('103rd rd', '103rd Rd'),
#  ('10th brighton ter', 'Brighton 10th Ter'),
#  ('lyman st', 'Lyman St'),
#  ('charlecote ridge', 'CHARLECOTE RIDGE'),
#  ('ave columbia', 'Columbia Ave'),
#  ('albion pl', 'Albion Pl'),
#  ('st starbuck', 'Starbuck St'),
#  ('president ss st', 'S/S PRESIDENT ST'),
#  ('189 co e nw st', 'NW C/O E 189 ST'),
#  ('ae madison ws', 'W/S MADISON AE'),
#  ('183 street w', 'W 183 STREET'),
#  ('co gueanseu st', 'C/O GUEANSEU ST'),
#  ('fhokwy', 'FHOKWY'),
#  ('28 st w', 'W 28 ST'),
#  ('ocean pky', 'Ocean Pky'),
#  ('151 st w', 'W 151 ST'),
#  ('nushoul pkwy', 'NUSHOUL PKWY'),
#  ('beekman st', 'Beekman St'),
#  ('121 street', '121 STREET'),
#  ('5 brighton street', 'BRIGHTON 5 STREET'),
#  ('ave brooklyn', 'BROOKLYN AVE'),
#  ('2nd st', '2ND ST'),
#  ('ave portalnd s', 'S PORTALND AVE'),
#  ('137th st', '137TH ST'),
#  ('101 avenue', '101 AVENUE'),
#  ('32 e', 'E 32'),
#  ('linden', 'LINDEN'),
#  ('humboldt st', 'HUMBOLDT ST'),
#  ('avenue waring', 'WARING AVENUE'),
#  ('196 e street', 'E 196 STREET'),
#  ('ave spoffond', 'SPOFFOND AVE'),
#  ('57th st', '57TH ST'),
#  ('av church', 'CHURCH AV'),
#  ('97 of ss st', 'S/S OF 97 ST'),
#  ('avenue webster', 'WEBSTER AVENUE'),
#  ('barnes co', 'C/O BARNES'),
#  ('ave farmers', 'FARMERS AVE'),
#  ('astor', 'ASTOR'),
#  ('98th st w', 'W 98th St'),
#  ('ave beechwood', 'Beechwood Ave'),
#  ('5 st', '5 ST'),
#  ('ave melrose', 'MELROSE AVE'),
#  ('boulevard bruckner', 'BRUCKNER BOULEVARD'),
#  ('ave netherland', 'Netherland Ave'),
#  ('187th st w', 'W 187th St'),
#  ('st winthrop', 'WINTHROP ST'),
#  ('9th beach st', 'BEACH 9TH ST'),
#  ('ave lincoln', 'LINCOLN AVE'),
#  ('casanovia street', 'CASANOVIA STREET'),
#  ('farragut road', 'FARRAGUT ROAD'),
#  ('112th ave', '112th Ave'),
#  ('beaver rd', 'Beaver Rd'),
#  ('73 ave', '73 AVE'),
#  ('ashford st', 'ASHFORD ST'),
#  ('183 e', 'E 183'),
#  ('flushing ws', 'W/S FLUSHING'),
#  ('ave baisley', 'Baisley Ave'),
#  ('ave sagamore', 'Sagamore Ave'),
#  ('129 street west', 'WEST 129 STREET'),
#  ('keagans ln', 'KEAGANS LN'),
#  ('ave co radcliffe', 'C/O RADCLIFFE AVE'),
#  ('alhemarble rd', 'ALHEMARBLE RD'),
#  ('93 st', '93 ST'),
#  ('54th avenue', '54TH AVENUE'),
#  ('2 street', '2 STREET'),
#  ('father seizer', 'FATHER SEIZER'),
#  ('188 co se st w', 'S/E C/O W 188 ST'),
#  ('stanley street ws', 'W/S STANLEY STREET'),
#  ('69th ave', '69TH AVE'),
#  ('213 e st', 'E 213 ST'),
#  ('st wycoff', 'WYCOFF ST'),
#  ('osbouene place', 'OSBOUENE PLACE'),
#  ('mckeever pl', 'MCKEEVER PL'),
#  ('71st west', 'WEST 71ST'),
#  ('ave livonia ns', 'N/S LIVONIA AVE'),
#  ('ave ns o', 'N/S AVE O'),
#  ('edwards ne st', 'N/E ST EDWARDS ST'),
#  ('berry st ws', 'W/S BERRY ST'),
#  ('41 street west', 'WEST 41 STREET'),
#  ('147 co e st', 'C/O E 147 ST'),
#  ('ave georiga', 'GEORIGA AVE'),
#  ('amboy av pitkin wb', 'WB PITKIN AV. AMBOY'),
#  ('nicholas', 'NICHOLAS'),
#  ('ave nostrand sb su', 'SB NOSTRAND AVE @ SU'),
#  ('13 ave hillside wb', 'WB HILLSIDE AVE @ 13'),
#  ('boynton pl', 'Boynton Pl'),
#  ('ave empire', 'Empire Ave'),
#  ('ave cayuga', 'CAYUGA AVE'),
#  ('161 w', 'W 161'),
#  ('barry ss st', 'S/S BARRY ST'),
#  ('150 west', 'WEST 150'),
#  ('127 e ss st', 'S/S E 127 ST'),
#  ('bank st', 'BANK ST'),
#  ('ave boome', 'BOOME AVE'),
#  ('es st william', 'E/S WILLIAM ST'),
#  ('171st pl', '171st Pl'),
#  ('co wortman', 'C/O WORTMAN'),
#  ('101 av', '101 AV'),
#  ('co nassau', 'C/O NASSAU'),
#  ('co dekalb sw', 'S/W C/O DEKALB'),
#  ('ave lin nwb remsen', 'NWB REMSEN AVE @ LIN'),
#  ('10014 main ny st', 'MAIN ST NY NY 10014'),
#  ('174 st w', 'W 174 ST'),
#  ('ave soundview', 'SOUNDVIEW AVE'),
#  ('maple street', 'MAPLE STREET'),
#  ('madison st', 'MADISON ST'),
#  ('oxford s st', 'S OXFORD ST'),
#  ('street whittier ws', 'W/S WHITTIER STREET'),
#  ('ave westside', 'Westside Ave'),
#  ('72 street', '72 STREET'),
#  ('196 co e st', 'C/O E 196 ST'),
#  ('forbell st', 'Forbell St'),
#  ('ave grandview', 'GRANDVIEW AVE'),
#  ('ericson street', 'ERICSON STREET'),
#  ('avenue h', 'Avenue H'),
#  ('blvd bruckner co', 'C/O BRUCKNER BLVD'),
#  ('ave powell', 'POWELL AVE'),
#  ('204 east st', 'EAST 204 ST'),
#  ('duzer st van', 'Van Duzer St'),
#  ('church st', 'CHURCH ST'),
#  ('108 east street', 'EAST 108 STREET'),
#  ('20th st w', 'W 20th St'),
#  ('ave cortland van', 'VAN CORTLAND AVE'),
#  ('31st rd', '31st Rd'),
#  ('64th st', '64th St'),
#  ('31 st west', 'WEST 31 ST'),
#  ('181 street', '181 STREET'),
#  ('bx cross expwy rs', 'R/S CROSS BX EXPWY'),
#  ('clove rd', 'CLOVE RD'),
#  ('135th st w', 'W 135th St'),
#  ('clearview expy', 'Clearview Expy'),
#  ('119th beach st', 'Beach 119th St'),
#  ('ave liberty', 'LIBERTY AVE'),
#  ('flatlands', 'FLATLANDS'),
#  ('broadway ss', 'S/S BROADWAY'),
#  ('107th st w', 'W 107th St'),
#  ('st thornton', 'Thornton St'),
#  ('16th st', '16th St'),
#  ('park', 'PARK'),
#  ('194th e st', 'E 194th St'),
#  ('st sterling', 'STERLING ST'),
#  ('blvd highland', 'HIGHLAND BLVD'),
#  ('3rd st', '3RD ST'),
#  ('hall place', 'HALL PLACE'),
#  ('223 e street', 'E 223 STREET'),
#  ('ave colonial', 'Colonial Ave'),
#  ('defoe st', 'Defoe St'),
#  ('2075 65 fo st', 'F/O 2075 65 ST'),
#  ('bolton co st', 'C/O BOLTON ST'),
#  ('ave durant', 'DURANT AVE'),
#  ('1870 e', 'E 1870'),
#  ('219 co se st', 'S/E C/O 219 ST'),
#  ('roosevelt ss', 'S/S ROOSEVELT'),
#  ('avenue gardner', 'GARDNER AVENUE'),
#  ('ave webster ws', 'W/S WEBSTER AVE'),
#  ('119th e st', 'E 119TH ST'),
#  ('151 street west', 'WEST 151 STREET'),
#  ('ave nostrand ws', 'W/S NOSTRAND AVE'),
#  ('nevins ns', 'N/S NEVINS'),
#  ('bronx croos expwy', 'CROOS BRONX EXPWY'),
#  ('atlantic ave se', 'S/E ATLANTIC AVE'),
#  ('austin place', 'AUSTIN PLACE'),
#  ('drecser loop', 'DRECSER LOOP'),
#  ('167 st', '167 ST'),
#  ('74 st w', 'W 74 ST'),
#  ('beach channell dr', 'BEACH CHANNELL DR'),
#  ('eyck ten walk', 'Ten Eyck Walk'),
#  ('ave lanett', 'LANETT AVE'),
#  ('laurelton pkwy', 'LAURELTON PKWY'),
#  ('baisley', 'BAISLEY'),
#  ('85 ne rd', 'NE 85 RD'),
#  ('mary st', 'ST MARY ST'),
#  ('18 st w', 'W 18 ST'),
#  ('21 west', 'WEST 21'),
#  ('erasmust st', 'ERASMUST ST'),
#  ('158th co st w', 'C/O W 158TH ST'),
#  ('montvale pl', 'Montvale Pl'),
#  ('139th beach st', 'Beach 139th St'),
#  ('b6 pelham pkwy so', 'PELHAM PKWY SO B6'),
#  ('127 co ne st', 'NE C/O 127 ST'),
#  ('colombus pl', 'COLOMBUS PL'),
#  ('concourse grand sb', 'GRAND CONCOURSE (S/B'),
#  ('ave front', 'Front Ave'),
#  ('50 bay st', 'BAY 50 ST'),
#  ('ave wardwell', 'Wardwell Ave'),
#  ('54 ss st', 'S/S 54 ST'),
#  ('83 hudson pier river', 'PIER 83 HUDSON RIVER'),
#  ('125 co ne st', 'N/E C/O 125 ST'),
#  ('104 ave ss', 'S/S 104 AVE'),
#  ('berkeley ns pl', 'N/S BERKELEY PL'),
#  ('37 w', 'W 37'),
#  ('50 co street', 'C/O 50 STREET'),
#  ('51st e', 'E 51ST'),
#  ('52 co e se', 'S/E C/O E 52'),
#  ('ave clifton', 'CLIFTON AVE'),
#  ('60th west', 'WEST 60TH'),
#  ('3rd ave es', 'E/S 3RD AVE'),
#  ('colubia st', 'COLUBIA ST'),
#  ('hurson st', 'HURSON ST'),
#  ('eden mount parkway', 'MOUNT EDEN PARKWAY'),
#  ('ave patterson', 'PATTERSON AVE'),
#  ('148 beach st', 'BEACH 148 ST'),
#  ('3555 bivona ro stre', 'R/O 3555 BIVONA STRE'),
#  ('ave manok', 'MANOK AVE'),
#  ('kingsbridge rd', 'KINGSBRIDGE RD'),
#  ('av jersey new', 'NEW JERSEY AV'),
#  ('21 e street', 'E 21 STREET'),
#  ('ave sencena', 'SENCENA AVE'),
#  ('claredon rd', 'CLAREDON RD'),
#  ('ave campbell', 'Campbell Ave'),
#  ('oakville st', 'OAKVILLE ST'),
#  ('166th e st', 'E 166TH ST'),
#  ('137th st', '137th St'),
#  ('ave edgewood', 'Edgewood Ave'),
#  ('144 st west', 'WEST 144 ST'),
#  ('241st e st', 'E 241st St'),
#  ('guerlain st', 'Guerlain St'),
#  ('148 e st', 'E 148 ST'),
#  ('strauss street', 'STRAUSS STREET'),
#  ('196 east', 'EAST 196'),
#  ('122nd st w', 'W 122nd St'),
#  ('breeze ns ocean', 'N/S OCEAN BREEZE'),
#  ('ave wheeles', 'WHEELES AVE'),
#  ('franklin st', 'Franklin St'),
#  ('ave roma', 'Roma Ave'),
#  ('kane st', 'KANE ST'),
#  ('83 co east st', 'C/O EAST 83 ST'),
#  ('co narrows', 'C/O NARROWS'),
#  ('60 pl', '60 PL'),
#  ('avenue hunt', 'HUNT AVENUE'),
#  ('39th e st', 'E 39th St'),
#  ('co luguer nw st', 'N/W C/O LUGUER ST'),
#  ('229 drive north', '229 DRIVE NORTH'),
#  ('drake street', 'DRAKE STREET'),
#  ('4 arrivals terminal', 'TERMINAL 4 ARRIVALS'),
#  ('oakland pl', 'Oakland Pl'),
#  ('114 street', '114 STREET'),
#  ('5th st', '5TH ST'),
#  ('207th st w', 'W 207th St'),
#  ('126 co sw w', 'S/W C/O W 126'),
#  ('17 ave ss', 'S/S 17 AVE'),
#  ('marlborduitrd', 'MARLBORDUITRD'),
#  ('ave taylon', 'TAYLON AVE'),
#  ('north ss st', 'S/S NORTH ST'),
#  ('139 avenue co', 'C/O 139 AVENUE'),
#  ('140th e st', 'E 140TH ST'),
#  ('gr hanpton', 'HANPTON GR'),
#  ('28th st', '28TH ST'),
#  ('154th pl', '154th Pl'),
#  ('2520 ave park ro', 'R/O 2520 PARK AVE'),
#  ('45th st w', 'W 45TH ST'),
#  ('aven vermcyea', 'VERMCYEA AVEN'),
#  ('boyland io', 'I/O BOYLAND'),
#  ('forty north runway', 'NORTH FORTY RUNWAY'),
#  ('151 st', '151 ST'),
#  ('carlyle gn', 'CARLYLE GN'),
#  ('interboro pkwy', 'INTERBORO PKWY'),
#  ('boyland s st thomas', 'THOMAS  S BOYLAND ST'),
#  ('crescent knowles', 'KNOWLES CRESCENT'),
#  ('norfold walk', 'NORFOLD WALK'),
#  ('ballrd rd wb woodrw', 'WB WOODRW RD. BALLRD'),
#  ('19 190 69 av eb ln', 'EB 69 AV 190 LN - 19'),
#  ('coonley ct', 'Coonley Ct'),
#  ('ave leonard', 'Leonard Ave'),
#  ('46 ss st w', 'S/S W 46 ST'),
#  ('james st', 'ST JAMES ST'),
#  ('beck street', 'BECK STREET'),
#  ('ave ordell', 'Ordell Ave'),
#  ('ave vireo', 'VIREO AVE'),
#  ('pl tieman', 'TIEMAN PL'),
#  ('240 co e ne st', 'N/E C/O E 240 ST'),
#  ('90th st west', 'WEST 90TH ST'),
#  ('garvey', 'GARVEY'),
#  ('park pl ws', 'W/S PARK PL'),
#  ('59 ss st', 'S/S  59 ST'),
#  ('bogardus', 'BOGARDUS'),
#  ('ave brookman', 'BROOKMAN AVE'),
#  ('ave montroe', 'MONTROE AVE'),
#  ('3 ae', '3 AE'),
#  ('meffaf st', 'MEFFAF ST'),
#  ('ave schieffelin', 'Schieffelin Ave'),
#  ('110th ave', '110th Ave'),
#  ('25 avenue', '25 AVENUE'),
#  ('dr es snediker', 'E/S SNEDIKER DR'),
#  ('ave ss waverly', 'S/S WAVERLY AVE'),
#  ('4th st', '4th St'),
#  ('61 b street', 'B 61 STREET'),
#  ('128th st', '128th St'),
#  ('111th rd', '111th Rd'),
#  ('ave steuben', 'STEUBEN AVE'),
#  ('blvd francis lewis', 'Francis Lewis Blvd'),
#  ('ave pratt', 'Pratt Ave'),
#  ('170 ave serard w', 'W 170 SERARD AVE'),
#  ('co mosh pkwy s', 'C/O MOSH PKWY S'),
#  ('10 e th', 'E 10 TH'),
#  ('ave greenwich', 'Greenwich Ave'),
#  ('53rd st w', 'W 53rd St'),
#  ('107 ave', '107 AVE'),
#  ('172 st w', 'W 172 ST'),
#  ('aquduct avenue', 'AQUDUCT AVENUE'),
#  ('6 st', '6 ST'),
#  ('boyland s st thomas', 'THOMAS S BOYLAND ST'),
#  ('127 e st', 'E 127 ST'),
#  ('183 e st', 'E 183 ST'),
#  ('66 st', '66 ST'),
#  ('farragut rd', 'FARRAGUT RD'),
#  ('43rd st', '43rd St'),
#  ('bond st', 'Bond St'),
#  ('division pl', 'Division Pl'),
#  ('cortlandt st', 'Cortlandt St'),
#  ('avenue c', 'AVENUE C'),
#  ('steinway', 'STEINWAY'),
#  ('204 e st', 'E 204 ST'),
#  ('44th st', '44th St'),
#  ('batchelder ws', 'W/S BATCHELDER'),
#  ('169th e st', 'E 169th St'),
#  ('ave boundary', 'Boundary Ave'),
#  ('clara st', 'Clara St'),
#  ('264 ave', '264 AVE'),
#  ('71st st west', 'WEST 71ST ST'),
#  ('3 ave es', 'E/S 3 AVE'),
#  ('ave eua', 'EUA AVE'),
#  ('233 pl', '233 PL'),
#  ('ave co j se', 'S/E C/O AVE J'),
#  ('ave varick ws', 'W/S VARICK AVE'),
#  ('ave spencer', 'Spencer Ave'),
#  ('166 co st', 'C/O 166 ST'),
#  ('4th st wse', 'W/S/E 4TH ST'),
#  ('blvd lamport', 'LAMPORT BLVD'),
#  ('hecker st', 'Hecker St'),
#  ('12 co e se st', 'S/E C/O E 12 ST'),
#  ('208 east st', 'EAST 208 ST'),
#  ('flushing meadow', 'FLUSHING MEADOW'),
#  ('22nd bay st', 'BAY 22ND ST'),
#  ('livingston st', 'LIVINGSTON ST'),
#  ('garifeld st', 'GARIFELD ST'),
#  ('ave etremont', 'ETREMONT AVE'),
#  ('26 w', 'W 26'),
#  ('ave warrington', 'Warrington Ave'),
#  ('amsterdm av la s sb', 'SB AMSTERDM AV. LA S'),
#  ('ave park was wb', 'PARK AVE (W/B) @ WAS'),
#  ('32 e of st', 'E OF 32 ST'),
#  ('aven ocean pkwy sb', 'SB OCEAN PKWY @ AVEN'),
#  ('ave n pennsylvania', 'PENNSYLVANIA AVE (N/'),
#  ('ave crosa', 'CROSA AVE'),
#  ('237 w', 'W 237'),
#  ('13th street', '13TH STREET'),
#  ('brck st', 'BRCK ST'),
#  ('concord pl', 'Concord Pl'),
#  ('94 co e se st', 'S/E C/O E 94 ST'),
#  ('court einstein', 'EINSTEIN COURT'),
#  ('ct sobel', 'Sobel Ct'),
#  ('23rd ss st', 'S/S 23RD ST'),
#  ('broadway brookyn ny', 'BROADWAY BROOKYN NY'),
#  ('230 pl', '230 PL'),
#  ('fort hamilton pkw y', 'FORT HAMILTON PKW Y'),
#  ('nich st', 'ST NICH'),
#  ('dr russell', 'RUSSELL DR'),
#  ('nicholas sain', 'SAIN NICHOLAS'),
#  ('42nd 83 pier st w', 'PIER 83 W 42ND ST'),
#  ('ocean pkwy', 'OCEAN PKWY'),
#  ('117 st', '117 ST'),
#  ('mathews', 'MATHEWS'),
#  ('harman st', 'HARMAN ST'),
#  ('poyer st', 'Poyer St'),
#  ('garden sunken', 'SUNKEN GARDEN'),
#  ('213 e street', 'E 213 STREET'),
#  ('ave mckinley', 'MCKINLEY AVE'),
#  ('street wallabout', 'WALLABOUT STREET'),
#  ('ave co greencraft', 'C/O GREENCRAFT AVE'),
#  ('5th ave w', 'W 5TH AVE'),
#  ('83rd ave', '83RD AVE'),
#  ('ave quince', 'Quince Ave'),
#  ('parkview ter', 'PARKVIEW TER'),
#  ('anns ave st', 'St Anns Ave'),
#  ('86 beach st', 'BEACH 86 ST'),
#  ('66 btwn rs st', 'R/S 66 ST BTWN'),
#  ('27 beach st', 'BEACH 27 ST'),
#  ('burling st', 'BURLING ST'),
#  ('ave sutter', 'SUTTER AVE'),
#  ('ave graw mc', 'Mc Graw Ave'),
#  ('berriman st', 'Berriman St'),
#  ('bourton st', 'Bourton St'),
#  ('95 ave co sw', 'S/W C/O 95 AVE'),
#  ('berry st', 'Berry St'),
#  ('avenue f', 'Avenue F'),
#  ('28 ave', '28 AVE'),
#  ('ave mosholu', 'MOSHOLU AVE'),
#  ('21 east', 'EAST 21'),
#  ('ave sanford', 'Sanford Ave'),
#  ('232nd st w', 'W 232nd St'),
#  ('ln new', 'New Ln'),
#  ('hill marble', 'MARBLE HILL'),
#  ('st wallabout', 'WALLABOUT ST'),
#  ('145 e street', 'E 145 STREET'),
#  ('columbia street', 'COLUMBIA STREET'),
#  ('lot sunnyside', 'Sunnyside Lot'),
#  ('196th e st', 'E 196th St'),
#  ('120 st w', 'W 120 ST'),
#  ('lawernce place', 'LAWERNCE PLACE'),
#  ('ave co westernvelt', 'C/O WESTERNVELT AVE'),
#  ('co hampden pl se', 'S/E C/O HAMPDEN PL'),
#  ('213 e ss st', 'S/S E 213 ST'),
#  ('124 e ss st', 'S/S E 124 ST'),
#  ('e moshulu n pkwy', 'E MOSHULU PKWY N'),
#  ('63 north of s side w', 'NORTH SIDE OF W 63 S'),
#  ('ave elm', 'ELM  AVE'),
#  ('ct watjean', 'WATJEAN CT'),
#  ('35 street west', 'WEST 35 STREET'),
#  ('william', 'WILLIAM'),
#  ('co nw quarry rd', 'N/W C/O QUARRY RD'),
#  ('32 st w', 'W 32 ST'),
#  ('donizetti pl', 'DONIZETTI PL'),
#  ('suffolk', 'SUFFOLK'),
#  ('albermarle co rd', 'C/O ALBERMARLE RD'),
#  ('ave nicholas ssaint', 'SSAINT NICHOLAS AVE'),
#  ('5 e ns of', 'N/S OF E 5'),
#  ('claflin', 'CLAFLIN'),
#  ('ns st union', 'N/S UNION ST'),
#  ('179 co street w', 'C/O W 179 STREET'),
#  ('eldert ln ns', 'N/S ELDERT LN'),
#  ('ave co nb ne park', 'NE C/O NB PARK AVE'),
#  ('8th', '8TH'),
#  ('cambridge st', 'CAMBRIDGE ST'),
#  ('169 st west', 'WEST 169 ST'),
#  ('ave tiesors', 'TIESORS AVE'),
#  ('211 e ss st', 'S/S E 211 ST'),
#  ('india st', 'INDIA ST'),
#  ('105 essex io st', 'I/O 105 ESSEX ST'),
#  ('barry commodore', 'COMMODORE BARRY'),
#  ('36 ave co', 'C/O 36 AVE'),
#  ('160t archer ave eb', 'EB ARCHER AVE @ 160T'),
#  ('ave coney island nb', 'NB CONEY ISLAND AVE'),
#  ('mckibbin st', 'MCKIBBIN ST'),
#  ('archer ave ns', 'N/S ARCHER AVE'),
#  ('147th on ss st', 'ON S/S 147TH ST'),
#  ('mosholu pkwy so', 'MOSHOLU PKWY SO'),
#  ('11th e', 'E 11TH'),
#  ('hanover square', 'HANOVER SQUARE'),
#  ('central prk s', 'CENTRAL PRK S'),
#  ('batchester ws', 'W/S BATCHESTER'),
#  ('65 avenue b', 'B 65 AVENUE'),
#  ('ave co peartree', 'C/O PEARTREE AVE'),
#  ('164 co e st sw', 'S/W C/O E 164 ST'),
#  ('10th brighton ln', 'Brighton 10th Ln'),
#  ('co of se south', 'SOUTH OF SE C/O'),
#  ('82th st west', 'WEST 82TH ST'),
#  ('blvd garey marcus', 'MARCUS GAREY BLVD'),
#  ('72nd st', '72nd St'),
#  ('bellamy loop', 'Bellamy Loop'),
#  ('pl trantor', 'Trantor Pl'),
#  ('ave stephens', 'Stephens Ave'),
#  ('clarke pl', 'Clarke Pl'),
#  ('82nd st w', 'W 82nd St'),
#  ('88th pl', '88th Pl'),
#  ('ave parkside', 'Parkside Ave'),
#  ('fame hall of ter', 'Hall of Fame Ter'),
#  ('antin pl', 'Antin Pl'),
#  ('ave exten flatbush', 'Flatbush Ave Exten'),
#  ('bradford st', 'Bradford St'),
#  ('dash pl', 'Dash Pl'),
#  ('127th st', '127th St'),
#  ('park row', 'Park Row'),
#  ('41 road', '41 ROAD'),
#  ('hobart st', 'Hobart St'),
#  ('85 av', '85 AV'),
#  ('108th co st', 'C/O 108TH ST'),
#  ('57 east st', 'EAST 57 ST'),
#  ('pl portland', 'Portland Pl'),
#  ('dr essex', 'Essex Dr'),
#  ('fort pl', 'Fort Pl'),
#  ('164 east street', 'EAST 164 STREET'),
#  ('warsoff', 'WARSOFF'),
#  ('dr palma', 'Palma Dr'),
#  ('eastern pkway', 'EASTERN PKWAY'),
#  ('judge st', 'JUDGE ST'),
#  ('chrystie st', 'CHRYSTIE ST'),
#  ('106th e st', 'E 106TH ST'),
#  ('41 co nw street', 'N/W C/O 41 STREET'),
#  ('46 w', 'W 46'),
#  ('beadel st', 'BEADEL ST'),
#  ('88 b st', 'B 88 ST'),
#  ('henry north st', 'NORTH HENRY ST'),
#  ('ave reservoir', 'RESERVOIR AVE'),
#  ('163 e st', 'E 163 ST'),
#  ('ave pleasent', 'PLEASENT AVE'),
#  ('ave co story', 'C/O STORY AVE'),
#  ('collge manhattan pk', 'MANHATTAN COLLGE PK'),
#  ('ave nameole', 'NAMEOLE AVE'),
#  ('54 e es st', 'E/S E 54 ST'),
#  ('heyson rd', 'HEYSON RD'),
#  ('1 av e e102 nb st', 'NB 1 AV E102 ST. - E'),
#  ('82nd e', 'E 82ND'),
#  ('235 nb st w', 'N/B W 235 ST'),
#  ('135 e st', 'E 135 ST'),
#  ('2317 42nd so st', 'S/O 2317 42ND ST'),
#  ('84 co rd', 'C/O 84 RD'),
#  ('ave voorhies', 'VOORHIES AVE'),
#  ('gotham rd', 'Gotham Rd'),
#  ('ave r ss', 'S/S AVE R'),
#  ('6th av', '6TH AV'),
#  ('123 co ne st', 'N/E C/O 123 ST'),
#  ('174th st w', 'W .174TH ST'),
#  ('21 east st', 'EAST 21 ST ST'),
#  ('dr norton', 'Norton Dr'),
#  ('gilbert pl', 'GILBERT PL'),
#  ('johns la st ws', 'W/S ST JOHNS LA'),
#  ('butler ns st', 'N/S BUTLER ST'),
#  ('56 co east street', 'C/O EAST 56 STREET'),
#  ('blvd springfield', ';SPRINGFIELD BLVD'),
#  ('ave tilltson ws', 'W/S TILLTSON AVE'),
#  ('blv southern', 'SOUTHERN BLV'),
#  ('72 co st sw', 'S/W C/O 72 ST'),
#  ('ave rose', 'ROSE AVE'),
#  ('190th st w', 'W 190TH ST'),
#  ('av schenetady', 'SCHENETADY AV'),
#  ('ave co snyder', 'C/O SNYDER AVE'),
#  ('68 co st', 'C/O 68 ST'),
#  ('avenue convent', 'CONVENT AVENUE'),
#  ('ave steele', 'Steele Ave'),
#  ('monument under walk', 'MONUMENT WALK UNDER'),
#  ('11 bay street', 'BAY 11 STREET'),
#  ('billings place', 'BILLINGS PLACE'),
#  ('1st 462 avenue n ro', 'R/O 462 1ST AVENUE N'),
#  ('erasmus st', 'ERASMUS ST'),
#  ('65 east st', 'EAST 65 ST'),
#  ('daniels st', 'DANIELS ST'),
#  ('64', '64'),
#  ('bothel loop', 'BOTHEL LOOP'),
#  ('183 e street', 'E 183 STREET'),
#  ('sutphin', 'SUTPHIN'),
#  ('ave es redfern', 'E/S REDFERN AVE'),
#  ('119 ave co', 'C/O 119 AVE'),
#  ('88th b st', 'B 88TH ST'),
#  ('8 th w', 'W 8 TH'),
#  ('av co pitkin sw', 'S/W C/O PITKIN AV'),
#  ('101st ave', '101st Ave'),
#  ('145th st w', 'W 145th St'),
#  ('ave mcarthur', 'McArthur Ave'),
#  ('hoffman st', 'Hoffman St'),
#  ('138th st w', 'W 138th St'),
#  ('marys st', 'St Marys St'),
#  ('ave troy', 'Troy Ave'),
#  ('ave university', 'University Ave'),
#  ('ave cambridge', 'Cambridge Ave'),
#  ('pl sumner', 'Sumner Pl'),
#  ('falmouth st', 'Falmouth St'),
#  ('corner hicks nw', 'N/W CORNER HICKS'),
#  ('club country rd', 'COUNTRY CLUB RD'),
#  ('115th ct', '115th Ct'),
#  ('e', 'E'),
#  ('23nd east street', 'EAST 23ND STREET'),
#  ('pl radde', 'Radde Pl'),
#  ('ave fish', 'FISH AVE'),
#  ('meyers st', 'Meyers St'),
#  ('ave meadow', 'Meadow Ave'),
#  ('austins n pl st', 'N St Austins Pl'),
#  ('gardens kew', 'KEW GARDENS'),
#  ('blvd woodhaven', 'WOODHAVEN BLVD'),
#  ('amber st', 'AMBER ST'),
#  ('161st e', 'E 161ST'),
#  ('gun hill road', 'GUN HILL ROAD'),
#  ('spring', 'SPRING'),
#  ('216 co e st', 'C/O E 216 ST'),
#  ('35 ave sside', 'S/SIDE 35 AVE'),
#  ('frame pl', 'FRAME PL'),
#  ('hubert ns st', 'N/S HUBERT ST'),
#  ('21st st w', 'W 21ST ST'),
#  ('pitkin', 'PITKIN'),
#  ('columbus place', 'COLUMBUS PLACE'),
#  ('hollers sw', 'S/W HOLLERS'),
#  ('ave mytrle', 'MYTRLE AVE'),
#  ('96 st', '96 ST'),
#  ('166 st', '166 ST'),
#  ('bantam', 'BANTAM'),
#  ('edgewater rd ss', 'S/S EDGEWATER RD'),
#  ('174 audubon w', 'W 174 AUDUBON'),
#  ('14 st w', 'W 14 ST'),
#  ('49th bay st', 'BAY 49TH ST'),
#  ('145 street', '145 STREET'),
#  ('ashland ws', 'W/S ASHLAND'),
#  ('83rd ave e nb park', 'NB PARK AVE @ E 83RD'),
#  ('2nd 53rd ave sb st', 'SB 2ND AVE @ 53RD ST'),
#  ('86 b st', 'B 86 ST'),
#  ('blvd bx', 'BX BLVD'),
#  ('49th nb st', 'N/B 49TH ST'),
#  ('137 e', 'E 137'),
#  ('38 ave ss', 'S/S 38 AVE'),
#  ('201 co st', 'C/O 201 ST'),
#  ('155 e neco st', 'N/EC/O E 155 ST'),
#  ('mcdougal street', 'MCDOUGAL STREET'),
#  ('colden street', 'COLDEN STREET'),
#  ('183nd st w', 'W 183ND ST'),
#  ('cortlandt park s van', 'VAN CORTLANDT PARK S'),
#  ('87 rd', '87 RD'),
#  ('145 dr', '145 DR'),
#  ('ave east end', 'EAST  END AVE'),
#  ('grenada place', 'GRENADA PLACE'),
#  ('street wilson', 'WILSON STREET'),
#  ('16 street', '16 STREET'),
#  ('crotona pl', 'CROTONA PL'),
#  ('blvd front', 'FRONT BLVD'),
#  ('5 avenue', 'AVENUE 5'),
#  ('93 e street', 'E 93 STREET'),
#  ('brg triborough', 'Triborough Brg'),
#  ('ave mersereau', 'Mersereau Ave'),
#  ('172nd st', '172ND ST'),
#  ('11th rd', '11th Rd'),
#  ('rd ruutland', 'RUUTLAND RD'),
#  ('ave mangin', 'MANGIN AVE'),
#  ('5 ss st', 'S/S 5 ST'),
#  ('ave corsa', 'Corsa Ave'),
#  ('108th st', '108th St'),
#  ('cleveland st', 'Cleveland St'),
#  ('136th st w', 'W 136th St'),
#  ('214th e st', 'E 214th St'),
#  ('ave thomson', 'Thomson Ave'),
#  ('ct dekoven', 'Dekoven Ct'),
#  ('231st e st', 'E 231st St'),
#  ('park swc', 'S/W/C PARK'),
#  ('8 e street', 'E 8 STREET'),
#  ('ter whitehall', 'Whitehall Ter'),
#  ('butler co st', 'C/O BUTLER ST'),
#  ('boerum pl', 'BOERUM PL'),
#  ('ave sycamore', 'SYCAMORE AVE'),
#  ('ave weser', 'Weser Ave'),
#  ('dr whitman', 'Whitman Dr'),
#  ('exit st tunnel', 'Tunnel Exit St'),
#  ('ave conkin', 'CONKIN AVE'),
#  ('207 e street', 'E 207 STREET'),
#  ('gerry st', 'GERRY ST'),
#  ('175 e eo townsend', 'E/O E 175 TOWNSEND'),
#  ('leroy street', 'LEROY STREET'),
#  ('89 ave', '89 AVE'),
#  ('111 ave', '111 AVE'),
#  ('125th w', 'W 125TH'),
#  ('229 st', '229 ST'),
#  ('co hull st', 'C/O HULL ST'),
#  ('pl tompkin', 'TOMPKIN PL'),
#  ('ave irwin', 'IRWIN AVE'),
#  ('macon st', 'MACON  ST'),
#  ('co io n nw of wyt', 'N OF N/W C/O I/O WYT'),
#  ('9 street', '9 STREET'),
#  ('ave graystone', 'GRAYSTONE AVE'),
#  ('ave columbia', 'COLUMBIA AVE'),
#  ('broadway e', 'E BROADWAY'),
#  ('180th st', '180TH ST'),
#  ('ave lb woodside', 'L/B WOODSIDE AVE'),
#  ('manhattan street', 'MANHATTAN STREET'),
#  ('blvd lin linden wb', 'WB LINDEN BLVD @ LIN'),
#  ('ave orient', 'ORIENT AVE'),
#  ('181th e st', 'E 181TH ST'),
#  ('198 east st', 'EAST 198 ST'),
#  ('elliot place', 'ELLIOT PLACE'),
#  ('56 beach st', 'BEACH 56 ST'),
#  ('havemeyer st', 'HAVEMEYER  ST'),
#  ('ave ditmars', 'DITMARS AVE'),
#  ('ave eburnside', 'E.BURNSIDE AVE'),
#  ('142 st w', 'W .142 ST'),
#  ('betanical square', 'BETANICAL SQUARE'),
#  ('atlantic cs st', 'C/S ATLANTIC ST'),
#  ('hutchinson parkw riv', 'HUTCHINSON RIV PARKW'),
#  ('ave co ocean se', 'S/E C/O OCEAN AVE'),
#  ('ave es roosevelt', 'E/S ROOSEVELT AVE'),
#  ('126 e', 'E 126'),
#  ('147 co ne st', 'N/E C/O 147 ST'),
#  ('voorhes', 'VOORHES'),
#  ('blvd foch', 'FOCH BLVD'),
#  ('terr wadsworth', 'WADSWORTH TERR'),
#  ('7th ave from pol rs', 'R/S 7TH AVE FROM POL'),
#  ('ave eb jamaica', 'E/B JAMAICA AVE'),
#  ('remsen', 'REMSEN'),
#  ('ave east ne york', 'EAST NE YORK AVE'),
#  ('131 street w', 'W 131 STREET'),
#  ('ave baychester es', 'E/S BAYCHESTER AVE'),
#  ('186 co nw w', 'N/W C/O W 186'),
#  ('ave bedford co sw', 'S/W C/O BEDFORD AVE'),
#  ('95th e street', 'E. 95TH STREET'),
#  ('113 co ne w', 'N/E C/O W 113'),
#  ('whales', 'WHALES'),
#  ('148th st w', 'W 148th St'),
#  ('197th e st', 'E 197th St'),
#  ('ave lafontaine', 'Lafontaine Ave'),
#  ('19th bay st', 'Bay 19th St'),
#  ('delmonico pl', 'Delmonico Pl'),
#  ('ainslie st', 'Ainslie St'),
#  ('dahill rd', 'Dahill Rd'),
#  ('23rd st', '23rd St'),
#  ('15th e st', 'E 15TH ST'),
#  ('ave skillman', 'SKILLMAN AVE'),
#  ('30th e st', 'E 30TH ST'),
#  ('36 w', 'W 36'),
#  ('78 st w', 'W 78 ST'),
#  ('172 street w', 'W 172 STREET'),
#  ('43rd ave', '43RD AVE'),
#  ('heavens pl', 'HEAVENS PL'),
#  ('40 st w', 'W 40 ST'),
#  ('ave roosevelt', 'ROOSEVELT AVE'),
#  ('pl sheridan', 'Sheridan Pl'),
#  ('cir mulberry', 'Mulberry Cir'),
#  ('clifton st', 'Clifton St'),
#  ('narrows rd south', 'NARROWS RD SOUTH'),
#  ('1st west', 'WEST 1ST'),
#  ('draper pl', 'DRAPER PL'),
#  ('37 co st w', 'C/O W 37 ST'),
#  ('blvd queen', 'QUEEN BLVD'),
#  ('ave caton co', 'C/O CATON AVE'),
#  ('ave ditmas', 'DITMAS AVE'),
#  ('119 ave', '119 AVE'),
#  ('16th st', '16TH ST'),
#  ('ave loring', 'LORING AVE'),
#  ('76th st west', 'WEST 76TH ST'),
#  ('110 io st', 'I/O 110 ST'),
#  ('polen street', 'POLEN STREET'),
#  ('avon st', 'AVON ST'),
#  ('73 st wonwco', 'W/O/N/W/C/O 73 ST'),
#  ('irving place', 'IRVING PLACE'),
#  ('11th st west', 'WEST 11TH ST'),
#  ('40th street', '40TH STREET'),
#  ('boulevard bronx', 'BRONX BOULEVARD'),
#  ('dorchester rd', 'DORCHESTER RD'),
#  ('bi rd wb willowbrook', 'WB WILLOWBROOK RD BI'),
#  ('6 62 av main sb st', 'SB MAIN ST 62 AV - 6'),
#  ('eb hollis tpk union', 'EB UNION TPK. HOLLIS'),
#  ('30 avenue', '30 AVENUE'),
#  ('co prospect', 'C/O PROSPECT'),
#  ('174 co e ne st', 'N/E C/O E 174 ST'),
#  ('22 center of st', 'CENTER OF 22 ST'),
#  ('astoria park south', 'ASTORIA PARK SOUTH'),
#  ('ave roosvelt', 'ROOSVELT AVE'),
#  ('av brielle', 'BRIELLE AV'),
#  ('155th co e st', 'C/O E 155TH ST'),
#  ('86 avenue st', 'AVENUE 86 ST'),
#  ('burnet pl ss', 'S/S BURNET PL'),
#  ('lyman st', 'LYMAN ST'),
#  ('7th paerdegat st', 'PAERDEGAT 7TH ST'),
#  ('farmer fish seatown', 'SEATOWN FISH FARMER'),
#  ('midland st', 'MIDLAND ST'),
#  ('45 b st', 'B 45 ST'),
#  ('4 terrace', '4 TERRACE'),
#  ('lambert st', 'Lambert St'),
#  ('159th east street', 'EAST 159TH STREET'),
#  ('baypkwy co se', 'SE C/O BAYPKWY'),
#  ('lamberts lane', 'LAMBERTS LANE'),
#  ('blvd co parsons se', 'S/E C/O PARSONS BLVD'),
#  ('6 paerdegate st', 'PAERDEGATE 6 ST'),
#  ('edgwater es rd', 'E/S EDGWATER RD'),
#  ('28 bay st', 'BAY 28 ST'),
#  ('joralmont st', 'JORALMONT ST'),
#  ('cronta eb north pk', 'E/B CRONTA PK NORTH'),
#  ('51st east str', 'EAST 51ST STR'),
#  ('aqueduct ave east', 'AQUEDUCT AVE EAST'),
#  ('fdrd', 'FDRD'),
#  ('blvd douglas fred', 'FRED DOUGLAS BLVD'),
#  ('cromnelin st', 'CROMNELIN ST'),
#  ('8th co e st', 'C/O E 8TH ST'),
#  ('101 west', 'WEST 101'),
#  ('57th east street', 'EAST 57TH STREET'),
#  ('henshaw st', 'Henshaw St'),
#  ('48th st w', 'W 48th St'),
#  ('ave haven', 'Haven Ave'),
#  ('loring pl', 'Loring Pl'),
#  ('st warren', 'Warren St'),
#  ('mitchell pl', 'Mitchell Pl'),
#  ('cres georges st', 'St Georges Cres'),
#  ('blvd mcguinness', 'McGuinness Blvd'),
#  ('blvd co parsons', 'C/O PARSONS BLVD'),
#  ('municipal p rosedale', 'Rosedale Municipal P'),
#  ('grand intersection', 'INTERSECTION GRAND'),
#  ('175th st', '175TH ST'),
#  ('pl queens south', 'QUEENS PL SOUTH'),
#  ('barretto st', 'BARRETTO ST'),
#  ('watts', 'WATTS'),
#  ('ave sylvan', 'SYLVAN AVE'),
#  ('ave westbury', 'Westbury Ave'),
#  ('117th beach st', 'Beach 117th St'),
#  ('amory ct', 'Amory Ct'),
#  ('172 co nw of w', 'N/W CO OF W 172'),
#  ('expwy sb van wyck', 'S/B VAN WYCK EXPWY'),
#  ('8 arrivals terminal', 'TERMINAL 8 ARRIVALS'),
#  ('cumberland st', 'CUMBERLAND ST'),
#  ('ave elton', 'ELTON AVE'),
#  ('783 co st west', 'C/O WEST 783 ST'),
#  ('sedgwick', 'SEDGWICK'),
#  ('fenimore st', 'FENIMORE ST'),
#  ('179th co east stree', 'C/O EAST 179TH STREE'),
#  ('canal place', 'CANAL PLACE'),
#  ...]

# %% [markdown]
# ### 4. Value Constraints
# Value constraints refine a simple type by defining limits on the values which it can represent. It is often useful to be able to constrain the values which an element can take.

# %% [markdown]
# Suppose we are interested in analyzing Registration_State based on the values that it can take. First at all, it should be a string. We might want to exclude rows that have a numerical entry in the Registration_State column.

# %%
# Check the ticket counts based in registered state
registered_state_wise_tickets = spark.sql("select Registration_State as registration_state, count(*) as ticket_count \
                               from parking \
                               group by registration_state \
                               order by ticket_count desc")

registered_state_wise_tickets.show()
# Out:
# +------------------+------------+
# |registration_state|ticket_count|
# +------------------+------------+
# |                NY|      794106|
# |                NJ|       93049|
# |                PA|       25434|
# |                CT|       13168|
# |                FL|       12440|
# |                MA|        8720|
# |                IN|        8092|
# |                VA|        6628|
# |                MD|        5232|
# |                NC|        5082|
# |                99|        3326|
# |                IL|        3265|
# |                GA|        3188|
# |                TX|        2907|
# |                OH|        2233|
# |                ME|        2092|
# |                AZ|        1992|
# |                CA|        1991|
# |                SC|        1985|
# |                OK|        1857|
# +------------------+------------+
# only showing top 20 rows

# %% [markdown]
# Based on the about results, we can see that ``3326`` rows contained ``Registration_State=99``. It is definetelly wrong since registration state must be a string not a numerical value. To solve this, we can remove all this entries from our data.

# %% [markdown]
# As we can see bellow, they were removed by using the filter function.

# %%
# How many rows have 99 in Registration State?
re_count = parking_df.filter( parking_df["Registration_State"] == "99").count()

print('Count total number of rows with 99 state in Registration_State: ', re_count)

# Remove rows containing Registration_State=99.
filter_99_re = parking_df.filter(~(parking_df["Registration_State"] == "99"))
filter_99_re.groupBy('Registration_State').count().orderBy('count', ascending=False).show(26)
# Out:
# Count total number of rows with 99 state in Registration_State:  3326
# +------------------+------+
# |Registration_State| count|
# +------------------+------+
# |                NY|794106|
# |                NJ| 93049|
# |                PA| 25434|
# |                CT| 13168|
# |                FL| 12440|
# |                MA|  8720|
# |                IN|  8092|
# |                VA|  6628|
# |                MD|  5232|
# |                NC|  5082|
# |                IL|  3265|
# |                GA|  3188|
# |                TX|  2907|
# |                OH|  2233|
# |                ME|  2092|
# |                AZ|  1992|
# |                CA|  1991|
# |                SC|  1985|
# |                OK|  1857|
# |                TN|  1727|
# |                MI|  1557|
# |                MN|  1466|
# |                DE|  1367|
# |                RI|  1084|
# |                NH|   904|
# |                AL|   688|
# +------------------+------+
# only showing top 26 rows

# %% [markdown]
# Otherkind of value constrains can be found in the data depending on the column type, for example, if we are analysing the issue date, the values shouldn't be take place in the future.

# %% [markdown]
# ### 5. Use of master data

# %% [markdown]
# The column ``Registration State`` contains a total of 64 values, which is more than the 50 U.S. states and even two more than in the list of state codes that is published by the NYC Department of Finance.

# %%
# Count of distinct Registration states
spark.sql("select count(distinct Registration_State) as count from parking").show()
# Out:
# +-----+
# |count|
# +-----+
# |   64|
# +-----+

# %%
# Check the ticket counts based in registered state
registered_state_wise_tickets = spark.sql("select Registration_State as registration_state, count(*) as ticket_count \
                               from parking \
                               group by registration_state \
                               order by ticket_count desc")

registered_state_wise_tickets.show(65)
# Out:
# +------------------+------------+
# |registration_state|ticket_count|
# +------------------+------------+
# |                NY|      794106|
# |                NJ|       93049|
# |                PA|       25434|
# |                CT|       13168|
# |                FL|       12440|
# |                MA|        8720|
# |                IN|        8092|
# |                VA|        6628|
# |                MD|        5232|
# |                NC|        5082|
# |                99|        3326|
# |                IL|        3265|
# |                GA|        3188|
# |                TX|        2907|
# |                OH|        2233|
# |                ME|        2092|
# |                AZ|        1992|
# |                CA|        1991|
# |                SC|        1985|
# |                OK|        1857|
# |                TN|        1727|
# |                MI|        1557|
# |                MN|        1466|
# |                DE|        1367|
# |                RI|        1084|
# |                NH|         904|
# |                AL|         688|
# |                WA|         637|
# |                OR|         624|
# |                VT|         583|
# |                WI|         446|
# |                ID|         423|
# |                QB|         421|
# |                MS|         393|
# |                ON|         392|
# |                IA|         377|
# |                MO|         352|
# |                DP|         348|
# |                DC|         346|
# |                CO|         337|
# |                KY|         320|
# |                AR|         292|
# |                LA|         289|
# |                NM|         289|
# |                WV|         257|
# |                NV|         222|
# |                SD|         158|
# |                KS|         132|
# |                UT|         124|
# |                NE|         119|
# |                MT|         100|
# |                GV|          90|
# |                AK|          79|
# |                NS|          79|
# |                ND|          63|
# |                HI|          46|
# |                PR|          24|
# |                WY|          22|
# |                AB|          16|
# |                NB|          11|
# |                PE|          10|
# |                BC|          10|
# |                MB|           3|
# |                YT|           3|
# +------------------+------------+

# %% [markdown]
# One solution is to use a master data to identify the invalid values. In this case, the master data would be a curated list of license plate state codes. The official list of license plate states has 67 values (including the 50 U.S. states, provinces and territories in Canada, Mexico, U.S. government vehicles). For this purpose, we used the open-source library ``refdata``, which is inside the openclean library, to provide access to master datasets available on the Web such as ``NYC Finance - State Codes``. To install ``openclean``, we just need to run ``pip install openclean-core`` in your terminal. More information about how to install openclean is detailed here: https://openclean.readthedocs.io/source/installation.html

# %%
from openclean.data.refdata import RefStore
refdata = RefStore()
for entry in refdata.repository().find():
    print(f'{entry.identifier:<35}:  {entry.name}')
# Out:
# company_suffixes                   :  Company Suffixes
# encyclopaedia_britannica:us_cities :  Cities in the U.S.
# nyc.gov:dof:state_codes            :  NYC Finance - State Codes
# restcountries.eu                   :  REST Countries
# usps:street_abbrev                 :  C1 Street Suffix Abbreviations
# usps:secondary_unit_designators    :  C2 Secondary Unit Designators
# wikipedia:us_states                :  States and territories of the U.S.
# admins                             :  Geo Administrative Levels

# %%
# Download the license plate state codes dataset.
refdata\
    .load('nyc.gov:dof:state_codes', auto_download=True)\
    .df()\
    .head()
# Out:
#   code        name type
# 0   AL     Alabama   US
# 1   AK      Alaska   US
# 2   AZ     Arizona   US
# 3   AR    Arkansas   US
# 4   CA  California   US

# %% [markdown]
# NOTE: In case, you can not install ``openclean`` to get the master data called NYC Finance - State Codes, here is the list of states: Just uncomment the following code:

# %%
# states_ref = {'AB',
#  'AK',
#  'AL',
#  'AR',
#  'AZ',
#  'BC',
#  'CA',
#  'CO',
#  'CT',
#  'DC',
#  'DE',
#  'DP',
#  'FL',
#  'FO',
#  'GA',
#  'GV',
#  'HI',
#  'IA',
#  'ID',
#  'IL',
#  'IN',
#  'KS',
#  'KY',
#  'LA',
#  'MA',
#  'MB',
#  'MD',
#  'ME',
#  'MI',
#  'MN',
#  'MO',
#  'MS',
#  'MT',
#  'MX',
#  'NB',
#  'NC',
#  'ND',
#  'NE',
#  'NF',
#  'NH',
#  'NJ',
#  'NM',
#  'NS',
#  'NT',
#  'NV',
#  'NY',
#  'OH',
#  'OK',
#  'ON',
#  'OR',
#  'PA',
#  'PE',
#  'QB',
#  'RI',
#  'SC',
#  'SD',
#  'SK',
#  'TN',
#  'TX',
#  'UT',
#  'VA',
#  'VT',
#  'WA',
#  'WI',
#  'WV',
#  'WY',
#  'YT'}

# %%
# Get set of distinct state codes from the master data called NYC Finance - State Codes from openclean.
states_ref = refdata.load('nyc.gov:dof:state_codes', auto_download=True).distinct('code')
states_ref
# Out:
# {'AB',
#  'AK',
#  'AL',
#  'AR',
#  'AZ',
#  'BC',
#  'CA',
#  'CO',
#  'CT',
#  'DC',
#  'DE',
#  'DP',
#  'FL',
#  'FO',
#  'GA',
#  'GV',
#  'HI',
#  'IA',
#  'ID',
#  'IL',
#  'IN',
#  'KS',
#  'KY',
#  'LA',
#  'MA',
#  'MB',
#  'MD',
#  'ME',
#  'MI',
#  'MN',
#  'MO',
#  'MS',
#  'MT',
#  'MX',
#  'NB',
#  'NC',
#  'ND',
#  'NE',
#  'NF',
#  'NH',
#  'NJ',
#  'NM',
#  'NS',
#  'NT',
#  'NV',
#  'NY',
#  'OH',
#  'OK',
#  'ON',
#  'OR',
#  'PA',
#  'PE',
#  'QB',
#  'RI',
#  'SC',
#  'SD',
#  'SK',
#  'TN',
#  'TX',
#  'UT',
#  'VA',
#  'VT',
#  'WA',
#  'WI',
#  'WV',
#  'WY',
#  'YT'}

# %%
# Get set of distinct state codes from Registration_State column of our Parking dataset.
registration_state_rdd = parking_df.select('Registration_State').distinct().rdd.flatMap(list).collect()
registration_state_rdd
# Out:
# ['SC',
#  'NS',
#  'LA',
#  'AZ',
#  'MN',
#  'NJ',
#  'DC',
#  'OR',
#  'VA',
#  '99',
#  'RI',
#  'KY',
#  'WY',
#  'BC',
#  'NH',
#  'MI',
#  'NV',
#  'GV',
#  'QB',
#  'WI',
#  'ID',
#  'CA',
#  'CT',
#  'NE',
#  'MT',
#  'NC',
#  'VT',
#  'MD',
#  'DE',
#  'MO',
#  'IL',
#  'ME',
#  'ND',
#  'WA',
#  'MB',
#  'MS',
#  'AL',
#  'IN',
#  'OH',
#  'TN',
#  'NM',
#  'IA',
#  'PA',
#  'SD',
#  'NY',
#  'ON',
#  'AB',
#  'TX',
#  'PE',
#  'WV',
#  'GA',
#  'MA',
#  'FL',
#  'CO',
#  'AK',
#  'KS',
#  'YT',
#  'OK',
#  'PR',
#  'NB',
#  'AR',
#  'HI',
#  'UT',
#  'DP']

# %% [markdown]
# Print information for entries in the ``Registration State`` column that do not occur in the master dataset.

# %%
for state in registration_state_rdd:
    if state not in states_ref:
        print(state)
# Out:
# 99
# PR

# %% [markdown]
# The result shows that 99 and PR are the two values that do not occur in the master dataset.

# %%
# How many rows have 99 and PR in Registration State?
_99_count = parking_df.filter( parking_df["Registration_State"] == "99").count()
_PR_count = parking_df.filter( parking_df["Registration_State"] == "PR").count()


print('Count total number of rows with 99 state in Registration_State: ', _99_count)
print('Count total number of rows with PR state in Registration_State: ', _PR_count)
# Out:
# Count total number of rows with 99 state in Registration_State:  3326
# Count total number of rows with PR state in Registration_State:  24

# %% [markdown]
# ### 6. Functional Dependencies
# A functional dependency is a constraint that specifies the relationship between two sets of attributes where one set can accurately determine the value of other sets.
# For example, the combination of Plate ID and Registration State should uniquely identify a vehicle. For each vehicle we make the assumption that the vehicle color doesn't change within one financial year. Thus, the functional dependency that [Plate ID, Registration State] determines the Vehicle Color should hold. Violations of that dependency point to different representations of the same color value.

# %% [markdown]
# To test our assumption, first, we check if our data is within one financial year. As we can see, our data is actually within the fiscal year ``2016`` so we can go ahead with our example.

# %%
spark.sql("SELECT count(DISTINCT issue_date) FROM parking").show()
spark.sql("select issue_date as issue_date, count(*) as date_count \
                               from parking \
                               group by issue_date \
                               order by date_count desc").show(31)
# Out:
# +--------------------------+
# |count(DISTINCT issue_date)|
# +--------------------------+
# |                        31|
# +--------------------------+
#
# +----------+----------+
# |issue_date|date_count|
# +----------+----------+
# |2016-03-01|     45090|
# |2016-03-08|     44166|
# |2016-03-10|     42878|
# |2016-03-15|     42118|
# |2016-03-03|     41751|
# |2016-03-31|     41558|
# |2016-03-22|     41292|
# |2016-03-02|     40291|
# |2016-03-09|     40289|
# |2016-03-18|     40269|
# |2016-03-17|     40131|
# |2016-03-07|     40062|
# |2016-03-11|     39502|
# |2016-03-23|     39262|
# |2016-03-29|     39179|
# |2016-03-16|     39134|
# |2016-03-30|     38070|
# |2016-03-24|     37037|
# |2016-03-21|     33361|
# |2016-03-28|     33136|
# |2016-03-04|     32235|
# |2016-03-14|     31733|
# |2016-03-25|     27807|
# |2016-03-05|     23431|
# |2016-03-12|     23365|
# |2016-03-19|     21560|
# |2016-03-26|     20909|
# |2016-03-06|     10132|
# |2016-03-13|      8800|
# |2016-03-20|      8301|
# |2016-03-27|      7168|
# +----------+----------+

# %%
# parking_df_fd1 = parking_df.withColumn('vehicle_color', F.lower(parking_df['Vehicle_Color']))


df_vc = parking_df\
    .select(['Plate_ID', 'Registration_State', 'Vehicle_Color'])\
    .filter((~parking_df["Vehicle_Color"].isNull()) & (parking_df["Registration_State"] != '99') & (parking_df["plate_type"] != '999'))\
    .withColumn('vehicle_color', F.upper(parking_df['Vehicle_Color']))

# %%
df_vc.show()
# Out:
# +--------+------------------+-------------+
# |Plate_ID|Registration_State|vehicle_color|
# +--------+------------------+-------------+
# | GBH2444|                NY|        BLACK|
# | GKZ2313|                NY|        WHITE|
# | GDP2624|                NY|        WHITE|
# | 42555JU|                NY|        WHITE|
# | 62636MD|                NY|          WHT|
# | DPE3045|                NY|        GREEN|
# | FMW7832|                NY|        GREEN|
# | DSD2130|                NY|         GOLD|
# | 65111MB|                NY|           WH|
# | GMZ3750|                NY|          BLK|
# |   44884|                RI|        WHITE|
# |  XZ876G|                NJ|        WHITE|
# |  PIKINE|                MA|          GLD|
# | GMU4296|                NY|        WHITE|
# | GEJ8235|                NY|          WHT|
# | 74452JW|                NY|          WHT|
# | 42972JW|                NY|           WT|
# |   66951|                NY|          WHT|
# | 63400JM|                NY|           BR|
# | GGS5172|                NY|           BK|
# +--------+------------------+-------------+
# only showing top 20 rows

# %%
print( parking_df.distinct().count())
print(df_vc.distinct().count())
# Out:
# 1014017
# 660738

# %%
var_pid = df_vc.select('Plate_ID').rdd.flatMap(list).collect()
var_rs = df_vc.select('Registration_State').rdd.flatMap(list).collect()
var_vc = df_vc.select('Vehicle_Color').rdd.flatMap(list).collect()

# %%
obj_fd = {}

for i in range(len(var_pid)):
    obj_name = var_pid[i] + var_rs[i]
    if obj_name in obj_fd:
        temp1 = obj_fd[obj_name]
        vc_new_color = var_vc[i]
        if vc_new_color not in temp1:
            temp1.append(vc_new_color)
            obj_fd[obj_name] = temp1
    else:
        temp = []
        temp.append(var_vc[i])
        obj_fd[obj_name] = temp

# %% [markdown]
# Below are the groups of tuples that violate the functional dependency. For example, we can see that (BLACK, BK), (WHITE, WH), and ('GRY', 'SILVE', 'GY') appear to be representations for the same color, giving us an indication for a possible mapping to standardize vehicle colors.

# %%
for x in obj_fd.keys():
    if len(obj_fd[x]) >1:
        print(x, ": " , obj_fd[x])
# Out:
# GBH2444NY :  ['BLACK', 'BK']
# 42555JUNY :  ['WHITE', 'WH']
# DSD2130NY :  ['GOLD', 'GY']
# GMZ3750NY :  ['BLK', 'BK']
# GEJ8235NY :  ['WHT', 'WH']
# 74452JWNY :  ['WHT', 'WH', 'WHITE']
# 49216KANY :  ['WH', 'WHT', 'BRN', 'WHITE']
# 79638KANY :  ['GRY', 'SILVE', 'GY']
# 24393MCNY :  ['WH', 'WHITE']
# GXC7520NY :  ['GREY', 'GY']
# GRC4443NY :  ['GREY', 'GY']
# T639084CNY :  ['BLACK', 'BK']
# GTJ6780NY :  ['BLACK', 'BK']
# PF090WFL :  ['SLVR', 'GREY']
# FTT2816NY :  ['BLUE', 'BL']
# 56248MGNY :  ['BR', 'BROWN', 'GOLD']
# 12996JUNY :  ['WH', 'WHITE']
# 80963MBNY :  ['GREY', 'GRAY', 'GRY', 'GY']
# HAK2246NY :  ['BK', 'BLACK']
# HFJ2092NY :  ['GY', 'LTG']
# GVG3196NY :  ['GY', 'SLVR']
# GXB2024NY :  ['BLACK', 'BK']
# HCT2268NY :  ['RED', 'RD']
# T687197CNY :  ['BLACK', 'BK']
# GBS7839NY :  ['BLUE', 'BK']
# EAB5723NY :  ['TAN', 'OTHER']
# 2PS558MA :  ['SILVE', 'GREY']
# VLL2419VA :  ['GRAY', 'GREEN', 'BLUE', 'GREY']
# FPJ4878NY :  ['SILVE', 'GREY', 'GY']
# 35415MBNY :  ['BROWN', 'BR', 'BRWN']
# FFN5218NY :  ['WHT', 'WH']
# GMR1833NY :  ['GREY', 'GY']
# 8V81ANY :  ['YEL', 'YW']
# GWB6455NY :  ['GREEN', 'BL']
# FRX9131NY :  ['GRY', 'GY']
# 27219MDNY :  ['BROWN', 'BR']
# K15254KPA :  ['GY', 'OTHER']
# HDW2491NY :  ['WH', 'WHITE']
# T233518IL :  ['GRAY', 'SILVE', 'GY', 'GREY']
# GVS9937NY :  ['WHITE', 'WH']
# GXC4650NY :  ['BLUE', 'GY']
# P281024IN :  ['WHT', 'WHITE']
# HDB8349NY :  ['BLU', 'GR']
# GVV8756NY :  ['WHT', 'WH']
# HBZ8887NY :  ['TAN', 'GOLD']
# GTZ2134NY :  ['GY', 'LTGY']
# GHU9090NY :  ['GRY', 'SILVE']
# GNW6880NY :  ['WH', 'GY']
# GTD8916NY :  ['BLK', 'BK']
# GYJ3266NY :  ['BLACK', 'BLK']
# GVS1462NY :  ['BK', 'BLACK']
# TK773MPTIN :  ['WH', 'WHITE']
# GPZ2990NY :  ['GY', 'GRY']
# GYR6847NY :  ['BLK', 'BK']
# HAA2883NY :  ['BLK', 'BK']
# HBU1621NY :  ['BL', 'BK']
# GJW6789NY :  ['GY', 'TN']
# GXW9744NY :  ['WHT', 'WHITE']
# HBN1062NY :  ['WHITE', 'WH']
# GVS8079NY :  ['RED', 'RD']
# HDU5202NY :  ['BLK', 'BK']
# GSN4693NY :  ['GREY', 'GY']
# GMH5380NY :  ['BLACK', 'BK']
# HDD9996NY :  ['BLK', 'BLACK']
# JXJ3792PA :  ['SILVR', 'BLACK', 'GREY']
# GVG3504NY :  ['BK', 'BLACK']
# GKH4621NY :  ['GRY', 'SILVE']
# HBE7539NY :  ['BL', 'BK']
# GBN1605NY :  ['BL', 'BLK', 'BLACK', 'BK']
# GNW8870NY :  ['GREY', 'GY']
# GXB4829NY :  ['BLACK', 'BLUE']
# GUV7236NY :  ['BLK', 'GREEN', 'GR']
# GJC9028NY :  ['BLK', 'BK']
# GRE7586NY :  ['WHITE', 'WH']
# TRANS277NY :  ['BLK', 'BK']
# GDN7323NY :  ['GOLD', 'GL']
# HBZ7171NY :  ['SILVR', 'GY']
# GKC4710NY :  ['RED', 'RD']
# HEX7234NY :  ['WHITE', 'WH']
# T691459CNY :  ['SILVE', 'GREY']
# GME4238NY :  ['BLUE', 'BL']
# HDH9221NY :  ['RED', 'RD']
# LIFFEY45NY :  ['OR', 'ORANG', 'GRAY']
# MAJOR01NY :  ['WH', 'WHITE', 'OTHER']
# L26939CT :  ['WH', 'WHITE']
# PAL5124MN :  ['WH', 'WHITE', 'WHT']
# GZJ6837NY :  ['GY', 'DKG']
# GED3775NY :  ['SLR', 'SILVE', 'GY']
# R96932MA :  ['WH', 'WHITE']
# GMG9523NY :  ['WHITE', 'WH']
# GJD8751NY :  ['BLACK', 'BL']
# GYV4369NY :  ['GREY', 'GY']
# T672593CNY :  ['BLACK', 'BK']
# GVK2896NY :  ['BLACK', 'BK']
# HDV3236NY :  ['GOLD', 'TN']
# HCD5764NY :  ['WHITE', 'WH']
# GMB1924NY :  ['BLACK', 'BK']
# GST7153NY :  ['SILVE', 'TN']
# HBN6556NY :  ['SILVE', 'GY', 'GRAY']
# GRN1376NY :  ['BLACK', 'BK']
# GKZ5134NY :  ['WHITE', 'WH']
# HCC1303NY :  ['WHIE', 'WH']
# GFE7326NY :  ['BLACK', 'BK']
# GXP9086NY :  ['BLACK', 'BK']
# HFB1158NY :  ['SILVE', 'GREY']
# GGT5511NY :  ['BLUE', 'BL']
# GSX3070NY :  ['RED', 'RD']
# HES3749NY :  ['BLACK', 'BK']
# GRV3288NY :  ['GRAY', 'BK', 'GY']
# GPU2135NY :  ['WH', 'WHITE', 'GY']
# GYH8251NY :  ['RED', 'RD']
# GGR1782NY :  ['GY', 'SILVE']
# L46FNWNJ :  ['WHITE', 'WT']
# HFB4035NY :  ['BLUE', 'BL']
# GPB6260NY :  ['BLACK', 'BK']
# GEG9974NY :  ['GY', 'GRAY']
# GAX4132NY :  ['WHITE', 'WH']
# HBN2592NY :  ['GRAY', 'GY']
# GTZ3429NY :  ['GREEN', 'GR']
# GZH4863NY :  ['BLACK', 'BK']
# HCP3691NY :  ['GY', 'GREY', 'OTHER', 'GOLD']
# HEB1283NY :  ['BLK', 'BK']
# GCN1010NY :  ['RED', 'RD']
# GYD4880NY :  ['RED', 'RD']
# M28FYRNJ :  ['GRAY', 'SILVE']
# GRS3523NY :  ['BLACK', 'BK']
# HDT1677NY :  ['RED', 'RD']
# JYP2931PA :  ['GOLD', 'BEIGE']
# HAY2002NY :  ['BLACK', 'BK']
# HAW4072NY :  ['WHITE', 'WH']
# GCD7340NY :  ['BLUE', 'BL']
# GXM3314NY :  ['BLUE', 'BL']
# GMW6720NY :  ['RED', 'RD']
# GWH8291NY :  ['BLACK', 'BK']
# GTL8108NY :  ['GRAY', 'GY']
# GVF3372NY :  ['BLUE', 'BL']
# JNF4183PA :  ['RED', 'MAROO']
# K26671KPA :  ['BK', 'GREY', 'BLUE']
# KI65883NY :  ['BK', 'BLACK']
# GRH2350NY :  ['BK', 'BLACK']
# J31FHTNJ :  ['TN', 'AR']
# GWU3429NY :  ['GRAY', 'GY']
# K71EZLNJ :  ['BK', 'BLACK', 'BLK']
# HCT1243NY :  ['BLACK', 'BK']
# GPE2086NY :  ['BLACK', 'BK']
# GWG5681NY :  ['WHITE', 'WH']
# GFP4171NY :  ['BLACK', 'BK']
# GSV7875NY :  ['WHITE', 'WH']
# T663174CNY :  ['WHITE', 'WH']
# GTW1758NY :  ['GRAY', 'GY']
# GAR6477NY :  ['MAROO', 'RD']
# HAX2482NY :  ['BLK', 'BK']
# GRJ9639NY :  ['GY', 'GREY']
# GXN8900NY :  ['WHITE', 'WH']
# GWH8004NY :  ['BLUE', 'BL']
# GTF3250NY :  ['BLACK', 'BK']
# T671906CNY :  ['BLACK', 'BK']
# HCS8510NY :  ['GRAY', 'GY']
# HBT8722NY :  ['BLACK', 'BK']
# GWB1631NY :  ['BLACK', 'BK']
# GSV8194NY :  ['BLACK', 'BLUE', 'GY']
# GUF5201NY :  ['BLUE', 'BL']
# HET2192NY :  ['BLACK', 'BLUE', 'GREY', 'BL']
# GGR9099NY :  ['WHITE', 'WH']
# GXS9360NY :  ['WHITE', 'WH']
# HES2791NY :  ['GOLD', 'GL']
# GRJ9234NY :  ['GREY', 'SILVE', 'SILVR']
# GPT5874NY :  ['BLUE', 'BL']
# GXG2285NY :  ['WHITE', 'WH']
# GGX5717NY :  ['SILVR', 'GY']
# HDE8116NY :  ['BLACK', 'BK']
# GLL2375NY :  ['WHT', 'WHITE']
# T604078CNY :  ['BLK', 'BLACK', 'BK']
# GPF1763NY :  ['GRAY', 'GY']
# HAW5301NY :  ['BLUE', 'BL']
# GLH2299NY :  ['BLACK', 'BK']
# GXT8334NY :  ['WHITE', 'WH']
# GZS2236NY :  ['BLUE', 'BL']
# T644279CNY :  ['BLK', 'BK']
# T639217CNY :  ['WHITE', 'WH']
# GVE1965NY :  ['TAN', 'TN']
# HDG6485NY :  ['BL', 'BLUE']
# HAX9157NY :  ['WHITE', 'WH']
# HBN2884NY :  ['WHT', 'WH']
# G67FEFNJ :  ['BLU', 'BLUE']
# GWH8177NY :  ['GY', 'SILVE']
# HAS6083NY :  ['GRAY', 'GY']
# GYD6067NY :  ['BLK', 'BK']
# JRD3233PA :  ['BK', 'BLACK']
# GLR6762NY :  ['RED', 'RD']
# GKB9313NY :  ['WH', 'WHITE']
# GKE1412NY :  ['BLACK', 'BK']
# GDR1010NY :  ['BLUE', 'GY']
# GCF6294NY :  ['GRAY', 'SILVE']
# GEB9275NY :  ['GREY', 'GY']
# GPF1433NY :  ['GREY', 'GY']
# GUV7911NY :  ['GREY', 'GR']
# GDF3496NY :  ['WHTIE', 'WH', 'WHITE']
# HEK1516NY :  ['WHITE', 'WH']
# GXJ3187NY :  ['GREY', 'GY']
# GXM8093NY :  ['BLUE', 'BL']
# GBN4783NY :  ['SILVE', 'GY']
# GUD1572NY :  ['BLACK', 'BK']
# GSV3939NY :  ['SILVE', 'GY']
# GPW5447NY :  ['WHITE', 'WH']
# JFN4376PA :  ['SILVR', 'SILVE', 'GREY']
# GGS6816NY :  ['RED', 'RD']
# GFN3770NY :  ['WHITE', 'WHT']
# JXS6198PA :  ['SILVR', 'GREY']
# GPT3397NY :  ['BLACK', 'BK']
# GZT3249NY :  ['BLUE', 'BL']
# GTR6190NY :  ['BLACK', 'BK']
# GEG7971NY :  ['WHITE', 'WH']
# HAH6777NY :  ['GREY', 'GY']
# GNR8226NY :  ['GRAY', 'DKG', 'DKGY']
# GWH8731NY :  ['WHITE', 'WH']
# GEL3401NY :  ['BLACK', 'GRAY', 'DK/', 'DKGY']
# GTZ5470NY :  ['GRAY', 'GY']
# HEE5283NY :  ['SILVR', 'GY', 'GREY']
# M13FPTNJ :  ['GRAY', 'GREY', 'GY']
# GPU1404NY :  ['BLACK', 'BK']
# GEL3473NY :  ['BLACK', 'BK']
# GWH8814NY :  ['BLUE', 'BL']
# GTV6152NY :  ['GREY', 'GY']
# GMG4714NY :  ['WHITE', 'WH']
# HDD6218NY :  ['GRAY', 'GY']
# GCX3799NY :  ['BLR', 'BLACK']
# GDS9902NY :  ['TAN', 'GREY']
# HDW3198NY :  ['ORANG', 'BK']
# GSS2788NY :  ['BLUE', 'BL']
# GRT7849NY :  ['BLACK', 'BK']
# REX1698NY :  ['GRAY', 'GRY']
# GPD7787NY :  ['GREEN', 'GY']
# GEL2480NY :  ['BURG', 'RED', 'MR']
# HCK5679NY :  ['TAN', 'TN']
# GRT4189NY :  ['GRAY', 'GY']
# HCU7946NY :  ['GRAY', 'GY', 'GREY']
# GED7007NY :  ['GREEN', 'GR']
# T638198CNY :  ['BLUE', 'BL']
# HES1931NY :  ['BLUE', 'BL']
# GXJ2690NY :  ['BLACK', 'BK']
# HCX3255NY :  ['BLACK', 'BK']
# GZR6843NY :  ['WHITE', 'WH']
# GTV4517NY :  ['SILVE', 'GY']
# HCM1376NY :  ['GRAY', 'OTHER']
# GEF9013NY :  ['BLUE', 'BL']
# HFK5910NY :  ['BLACK', 'BK']
# HAL3695NY :  ['WHITE', 'WHT', 'WH']
# HBR5364NY :  ['BLACK', 'BK']
# HBA1091NY :  ['WHITE', 'WH']
# GNY2457NY :  ['BLUE', 'BL']
# GLH5883NY :  ['GRAY', 'GY']
# HBZ7705NY :  ['GRAY', 'GY']
# LK0028NY :  ['GRAY', 'GY']
# HBX1871NY :  ['GRAY', 'GY']
# HAL5374NY :  ['GRAY', 'GY']
# HCP8463NY :  ['GRAY', 'GY']
# GSU8864NY :  ['WHITE', 'WH']
# GPX3035NY :  ['BLACK', 'BK']
# GZB3753NY :  ['WHITE', 'WH']
# GVA1595NY :  ['BLACK', 'GY', 'GREY']
# HBS8084NY :  ['GREY', 'GY']
# GUP1357NY :  ['BLK', 'BK']
# GTJ8167NY :  ['GRAY', 'GREY', 'GY']
# GKC6788NY :  ['GRAY', 'GY']
# GEL1750NY :  ['BLK', 'BK', 'BLACK']
# GRA7387NY :  ['GRAY', 'GY']
# HBB2740NY :  ['WHITE', 'BLK', 'BK', 'BL', 'YELLO']
# GVW1761NY :  ['BLACK', 'BK']
# G17FTHNJ :  ['WH', 'WT']
# GEN9521NY :  ['ORANG', 'TN']
# GHJ5743NY :  ['GY', 'GREY', 'BR']
# GSX6802NY :  ['GY', 'LTG']
# GRE9911NY :  ['GY', 'GR']
# GPN3847NY :  ['BLK', 'BK']
# GSX2819NY :  ['GRAY', 'GY']
# HEJ1296NY :  ['BLUE', 'GRAY', 'BL']
# HCX4792NY :  ['BLACK', 'BK']
# GPU7840NY :  ['GREY', 'GY']
# HEE4297NY :  ['GREY', 'GY']
# GNS5695NY :  ['RED', 'RD']
# GSC6510NY :  ['GREEN', 'BL']
# GMS2951NY :  ['GREY', 'BL']
# GLK1399NY :  ['GREEN', 'GR']
# HAC2197NY :  ['BLACK', 'BK']
# GGF7828NY :  ['BLUE', 'BL']
# GZU8824NY :  ['GREY', 'GY']
# HEJ6657NY :  ['BLACK', 'BK']
# GMB9076NY :  ['RED', 'RD']
# GWU2653NY :  ['BLUE', 'BL']
# HDD5377NY :  ['GREEN', 'GR']
# HDD3507NY :  ['GREY', 'GREEN', 'BLUE']
# HDD3619NY :  ['WHITE', 'WH']
# HHJ21FNJ :  ['GREY', 'SILVE']
# GUZ6284NY :  ['BLUE', 'BL']
# GKP8574NY :  ['BROWN', 'WH']
# HDW3454NY :  ['BLACK', 'BLK', 'BK']
# HAB7349NY :  ['GRAY', 'GRY', 'GY']
# GTK3382NY :  ['BK', 'BLACK']
# GJP9902NY :  ['RD', 'RED']
# GWK5530NY :  ['GREY', 'BK']
# GNW2792NY :  ['GREY', 'GY']
# GUL8013NY :  ['BK', 'BLACK']
# GRF4856NY :  ['BK', 'TN']
# GTP8563NY :  ['GREY', 'GY']
# GJB9453NY :  ['GREY', 'GY']
# GPJ6635NY :  ['WHITE', 'WH']
# GXM5674NY :  ['BLK', 'BLACK']
# GUH6712NY :  ['GRAY', 'GY']
# GSY2928NY :  ['BLK', 'BK', 'BLACK']
# GUM4619NY :  ['BLACK', 'BL']
# JWR2236PA :  ['TAN', 'GY']
# HCS2053NY :  ['BLK', 'BLACK', 'BK']
# GXM3258NY :  ['BLK', 'BK']
# GVK7809NY :  ['BK', 'BL']
# GTS2450NY :  ['TAN', 'TN']
# P867535IL :  ['RD', 'RED']
# GMJ4005NY :  ['BLACK', 'BK']
# GNK4243NY :  ['GY', 'GREY']
# M26FRPNJ :  ['BR', 'GOLD']
# HES4926NY :  ['BK', 'GREY']
# GWC5254NY :  ['BK', 'BLACK']
# GKB2597NY :  ['BK', 'BLACK']
# GUL8096NY :  ['BURG', 'RD']
# HCL2390NY :  ['BLACK', 'BLK']
# GVM4186NY :  ['GRAY', 'GY']
# HAT5041NY :  ['GRAY', 'GY', 'TAN']
# HCX2285NY :  ['GRAY', 'GY']
# HAK5387NY :  ['GREEN', 'GR']
# HAM6598NY :  ['WHITE', 'WH']
# HES2721NY :  ['GOLD', 'TN']
# GZE8571NY :  ['RD', 'ORANG']
# HCZ7374NY :  ['WHITE', 'WH']
# HAL1842NY :  ['GRAY', 'BR']
# HCR2227NY :  ['BLACK', 'BK']
# GZC4692NY :  ['GRAY', 'LTG', 'LTGY']
# HET1770NY :  ['RED', 'RD']
# GAJ6304NY :  ['GRAY', 'SLV']
# P257706IN :  ['WH', 'WHITE']
# JSH9681PA :  ['GRAY', 'BLUE']
# GUR5249NY :  ['WHITE', 'WH', 'WHT']
# T520471CNY :  ['BLACK', 'BK']
# HDG5772NY :  ['BLACK', 'BK']
# GXA7964NY :  ['BLACK', 'BK']
# HDU9533NY :  ['BROWN', 'GY']
# GUV1268NY :  ['SILVE', 'GY']
# GZK7462NY :  ['BLK', 'RED']
# HDY3075NY :  ['GRAY', 'GREY', 'LTG']
# GTL1030NY :  ['BURGU', 'BK']
# GHP2493NY :  ['GREY', 'GY']
# L25CTHNJ :  ['BLUE', 'BL']
# GZY2845PA :  ['SILVE', 'GREY']
# HDX3765NY :  ['RED', 'RD']
# HBE4187NY :  ['BLACK', 'BK']
# PLB6237GA :  ['GRAY', 'SIL']
# HES3656NY :  ['GREEN', 'GY']
# HDD5234NY :  ['WHITE', 'WH', 'BLACK']
# HCV9194NY :  ['GREY', 'GY']
# GCJ7349NY :  ['BLK', 'BK']
# HYX8814PA :  ['BLK', 'BLACK']
# GHV4773NY :  ['WHITE', 'WH']
# HAE6421NY :  ['BLACK', 'BK']
# H61FDSNJ :  ['GREY', 'GY']
# HDH6246NY :  ['WHITE', 'WH']
# GZP9986NY :  ['BLUE', 'BL']
# GUR1114NY :  ['GRAY', 'GY']
# IJB58NY :  ['SILVR', 'GY']
# GZK6300NY :  ['GRAY', 'GY']
# HAM3437NY :  ['BLK', 'BLACK']
# GWM3208NY :  ['BURGU', 'MR']
# GSW3847NY :  ['BLUE', 'GY']
# GHW2064NY :  ['BLACK', 'BK']
# GLY2297NY :  ['GRAY', 'BR', 'GREY']
# HAE6873NY :  ['WHITE', 'WH']
# T664866CNY :  ['GREEN', 'GR']
# GCR2685NY :  ['GRAY', 'OTHER']
# HBG3069NY :  ['BROWN', 'BR']
# GRU6462NY :  ['BLACK', 'BLK', 'BK']
# GMF2063NY :  ['BURG', 'RD']
# GYJ3014NY :  ['WHT', 'WH']
# GJH1519NY :  ['SILVE', 'BK']
# HCF6320NY :  ['GRAY', 'BK']
# GWH8612NY :  ['BLUE', 'BK']
# HCT1375NY :  ['BLUE', 'BL']
# GXA7820NY :  ['GREEN', 'GR']
# PC951TFL :  ['TAN', 'GY']
# GVU6569NY :  ['RED', 'RD']
# T644528CNY :  ['GREEN', 'GR']
# HES3533NY :  ['GRAY', 'GY']
# GZH2913NY :  ['GY', 'TN']
# GLB1316NY :  ['GRY', 'SILVE', 'OTHER', 'GOLD']
# JJT2268PA :  ['WH', 'WHITE']
# GNG7881NY :  ['GREY', 'GY']
# GUW1287NY :  ['GRY', 'GY']
# HEH2861NY :  ['RED', 'RD']
# HEA1484NY :  ['GY', 'SILVE']
# GWM2060NY :  ['WH', 'WHITE']
# JTX2097PA :  ['GY', 'GREY', 'OTHER', 'TAN']
# HBJ6670NY :  ['RED', 'RD']
# GJP3682NY :  ['BLACK', 'BK']
# GWT3038NY :  ['GREY', 'GY']
# T685841CNY :  ['BLACK', 'BK']
# GUV7538NY :  ['BLACK', 'BLK', 'OTHER']
# T693638CNY :  ['BLACK', 'BLK']
# HBU5013NY :  ['BLACK', 'BK']
# GGZ2763NY :  ['GRAY', 'GY']
# GUX2371NY :  ['WJITE', 'WH']
# GMZ7300NY :  ['BLACK', 'BK']
# HER3887NY :  ['GRAY', 'GY']
# GFR3025NY :  ['SILVE', 'BLUE', 'BL']
# GTL4684NY :  ['BLACK', 'BK']
# GVJ1461NY :  ['BLACK', 'BK']
# GCG2048NY :  ['WGUTE', 'BL', 'WHITE']
# GNJ3639NY :  ['GREY', 'GY']
# HDV2163NY :  ['BLUE', 'LTG', 'BL']
# GMB5768NY :  ['RED', 'OTHER']
# HDC6294NY :  ['BLACK', 'BK']
# HAY4944NY :  ['WH', 'GY']
# GKJ3196NY :  ['BLUE', 'GREY']
# GXS9974NY :  ['BLK', 'BK']
# HES2196NY :  ['BLUE', 'BL']
# GVL3739NY :  ['BK', 'BLK']
# HFA6986NY :  ['BLUE', 'WH']
# GBZ3110NY :  ['BLACK', 'BK']
# N389011LA :  ['GR', 'GOLD']
# T627722CNY :  ['WT', 'WH']
# GVM1590NY :  ['BL', 'GY']
# HAR7931NY :  ['WHITE', 'WH']
# GZX3560NY :  ['BLACK', 'BK']
# GKM5335NY :  ['GREY', 'GY']
# HEF2394NY :  ['BLACK', 'BK']
# GFW2930NY :  ['BLACK', 'BK']
# HCT2162NY :  ['TAN', 'TN']
# HDV5536NY :  ['RED', 'DKR', 'DKRD']
# GVM1135NY :  ['BLK', 'BK']
# GWL9409NY :  ['BL', 'BLU']
# GWK7129NY :  ['RED', 'RD']
# GVH1148NY :  ['BLK', 'BK']
# L277276NJ :  ['PRG', 'PURPL']
# K002818TX :  ['WH', 'WHITE', 'OTHER']
# HKV4504PA :  ['GRY', 'GREY', 'SILVE']
# HAL3355NY :  ['GRY', 'GY']
# K54FEXNJ :  ['BLACK', 'BK']
# GTP8938NY :  ['WH', 'GY', 'WHITE']
# KC2BWLNY :  ['BK', 'BLACK']
# HDW6714NY :  ['BLK', 'BK']
# GMU1354NY :  ['BLK', 'BK']
# T525443CNY :  ['SILVE', 'GY', 'GRAY']
# HBU4964NY :  ['GRAY', 'GY']
# JWA1647PA :  ['GREY', 'GY']
# GZE1298NY :  ['GR', 'GREY', 'SILVE', 'OTHER']
# GXA6850NY :  ['GOLD', 'TAN', 'TN']
# GUM8173NY :  ['BLUE', 'GY']
# HDV2471NY :  ['RED', 'ORANG']
# HEA4760NY :  ['BLACK', 'BK']
# HDD4595NY :  ['BLACK', 'BLK', 'BK']
# GZT4617NY :  ['GRAY', 'GY']
# GYU7384NY :  ['BRN', 'GL']
# HES3327NY :  ['GRY', 'LTGY']
# GSV7884NY :  ['BLK', 'BLACK']
# T671784CNY :  ['BLK', 'BK']
# JKX3874PA :  ['GRAY', 'GOLD']
# GZN3242NY :  ['BLK', 'BK']
# GXN6542NY :  ['BLACK', 'BK']
# HDW5698NY :  ['BLUE', 'BL']
# HCY3040NY :  ['SILVR', 'GRAY', 'BL']
# HET2326NY :  ['BLACK', 'BK', 'BLK']
# HDF5388NY :  ['WHITE', 'WH']
# HET1422NY :  ['RED', 'DKR']
# HEJ5603NY :  ['WHITE', 'WH']
# JZN3560PA :  ['GRAY', 'SILVE']
# GTT2928NY :  ['GOLD', 'BR']
# P835316IL :  ['WHT', 'WHITE']
# HAS2373NY :  ['SILVE', 'GY']
# HCE3211NY :  ['BLACK', 'BK']
# JGD6899PA :  ['SILVE', 'BEIGE']
# GFH6634NY :  ['GRAY', 'GY']
# HBN6249NY :  ['BLACK', 'BL']
# HET1417NY :  ['GRAY', 'GY']
# GYU7822NY :  ['BLACK', 'BLK']
# HCN8601NY :  ['WHITE', 'WH']
# GRR4840NY :  ['BLK', 'BK']
# GNV9459NY :  ['BLK', 'BLACK', 'BK']
# GTE5438NY :  ['GRY', 'GY']
# HCT2196NY :  ['BK', 'BLACK', 'BLK']
# HBE8302NY :  ['GY', 'TN']
# T524083CNY :  ['SIL', 'GY', 'SILVE']
# HBA7792NY :  ['PINK', 'WH']
# HDF5554NY :  ['GRAY', 'SILVE', 'GY']
# GVK1890NY :  ['BLK', 'BK', 'BLACK']
# GWB8841NY :  ['GY', 'GRAY']
# HCE1726NY :  ['WHITE', 'WH']
# HBN5840NY :  ['GRAY', 'GY']
# GNB8429NY :  ['GOLD', 'GY']
# GGY9216NY :  ['BLK', 'BK']
# GODNMEMD :  ['SILVE', 'GREY']
# GLN6028NY :  ['BLCK', 'BK', 'BLACK']
# GMF2786NY :  ['BLCK', 'BLACK']
# HCS2067NY :  ['BLK', 'BLACK']
# GLS8114NY :  ['GRY', 'GY']
# HET1023NY :  ['GOLD', 'TN']
# GYJ7411NY :  ['ORANG', 'RED']
# GZZ3430NY :  ['TAN', 'OTHER']
# GRT3351NY :  ['BLK', 'BK', 'BLACK']
# GZY6029NY :  ['BLK', 'BK']
# HBN6911NY :  ['GREEN', 'GR']
# GRG6512NY :  ['BLK', 'BLACK', 'BK']
# HCU8739NY :  ['BLK', 'BK']
# J70FFSNJ :  ['RED', 'OTHER']
# GZF7471NY :  ['BK', 'GR']
# JB256TFL :  ['TAN', 'BROWN', 'OTHER']
# GZN9608NY :  ['GY', 'GRY']
# G44CTVNJ :  ['GY', 'GREY']
# GMV2848NY :  ['BLACK', 'BK']
# HDT2020NY :  ['GRAY', 'GY']
# HEH2987NY :  ['BLACK', 'BK']
# GRT4618NY :  ['BLUE', 'BL']
# GZT3498NY :  ['TAN', 'WH']
# GWY8672NY :  ['GRY', 'GY']
# HEJ1856NY :  ['WH', 'WHITE']
# GEA7013NY :  ['SILVE', 'GY']
# HBN5141NY :  ['TAN', 'TN']
# HAW5850NY :  ['SLVR', 'GRY', 'SILVE']
# HDT4610NY :  ['BLK', 'BK']
# GRJ9623NY :  ['RED', 'RD']
# HCP7720NY :  ['GRY', 'GY']
# GTP6006NY :  ['WHITE', 'WH']
# JZX8963PA :  ['TAN', 'GREY', 'SILVE']
# GCS1619NY :  ['GREY', 'GY', 'GR', 'GRY']
# HCT2113NY :  ['GY', 'GRY', 'GR']
# GHL2822NY :  ['BROWN', 'GY']
# MCJ70FNJ :  ['GREEN', 'BLACK']
# GNK4481NY :  ['PURPL', 'RD']
# GTD8941NY :  ['BLACK', 'BK']
# K035104TX :  ['WH', 'WHITE']
# L249415NJ :  ['WH', 'WHITE']
# GZW5739NY :  ['GREY', 'BR']
# GZM2337NY :  ['SILVE', 'GY']
# HBT1881NY :  ['BROWN', 'GY']
# GDM2079NY :  ['BLUE', 'BL', 'OTHER']
# GXA6310NY :  ['SILVR', 'SILVE']
# JTY7432PA :  ['BLACK', 'OTHER']
# HAW4491NY :  ['BLACK', 'BK']
# G27FLKNJ :  ['SILVR', 'SILVE', 'GREY', 'GY']
# GUU8557NY :  ['GREY', 'GY']
# GPK5201NY :  ['GREY', 'GY']
# GVT8242NY :  ['BLUE', 'BL']
# GNS6552NY :  ['BLACK', 'BK']
# HBU4322NY :  ['BLACK', 'BK']
# GYD3217NY :  ['SILVR', 'GY']
# GWC7121NY :  ['SILVR', 'GY']
# N70FXUNJ :  ['SILVR', 'SILVE', 'OTHER', 'GREY']
# GZC6058NY :  ['SILVR', 'GY']
# GMG6848NY :  ['WHITE', 'WH']
# HCA5760NY :  ['SILVE', 'GY']
# GYH3805NY :  ['GRAY', 'GY']
# HAX5378NY :  ['GRAY', 'GY']
# HAV2142NY :  ['GREY', 'GY']
# HES1802NY :  ['BLACK', 'BK']
# GZK3672NY :  ['BLACK', 'BK']
# GPC1538NY :  ['RED', 'RD']
# HAZ9652NY :  ['BLUE', 'BL']
# GJP3764NY :  ['GRAY', 'GR']
# HBS6142NY :  ['BLACK', 'BK']
# HBN6422NY :  ['BLACK', 'BK']
# HDC6276NY :  ['BROWN', 'BR']
# HCP6065NY :  ['BLACK', 'BK']
# T617861CNY :  ['RED', 'RD']
# GWB4254NY :  ['BLACK', 'BK']
# HBT1367NY :  ['BLACK', 'BK']
# GYR6469NY :  ['BLACK', 'GREY']
# GXR1559NY :  ['SILVE', 'GY']
# GSB7536NY :  ['SILVE', 'GRY']
# GWL9301NY :  ['BLUE', 'BL']
# JWV2592PA :  ['GY', 'BLACK']
# HEE4340NY :  ['BLACK', 'BK', 'BLK']
# GSR4666NY :  ['BLK', 'BK']
# GTB2363NY :  ['BLK', 'BK', 'BLACK']
# GVU5781NY :  ['WHITE', 'WH']
# HCL5787NY :  ['WH', 'WHITE']
# HWV4612PA :  ['GRAY', 'SILVE']
# REELJRNY :  ['WHITE', 'GREY', 'WH']
# HAL1591NY :  ['YELLO', 'TAN', 'GOLD', 'GL']
# GHN2330NY :  ['GRAY', 'SILVE', 'GY']
# HDS2205NY :  ['WHITE', 'WH']
# GRG8728NY :  ['BK', 'BLACK']
# GWC8091NY :  ['WHITE', 'WH']
# GNK8720NY :  ['BK', 'BL', 'BLACK']
# GGT5380NY :  ['BLUE', 'BL']
# GFG5217NY :  ['RED', 'RD']
# GUX8214NY :  ['BLACK', 'BK']
# JYH3647PA :  ['GREY', 'SILVE', 'GR']
# GXA7289NY :  ['SO VE', 'GY']
# HX47157NY :  ['WHITE', 'TAN']
# HBX2651NY :  ['SILVE', 'SILVR', 'GY']
# GRG7719NY :  ['SILVE', 'GY']
# GXA5266NY :  ['SILVE', 'SILVR', 'GY']
# HDX7580NY :  ['BLACK', 'BK']
# HAY5885NY :  ['BLACK', 'BK']
# GHN4592NY :  ['GREEN', 'BL']
# GCJ6841PA :  ['BLUE', 'OTHER']
# GXA6434NY :  ['BEIGE', 'TN']
# JJH2461PA :  ['GREY', 'SILVE']
# GZH8918NY :  ['BLACK', 'BK']
# HAC2189NY :  ['GREY', 'GY']
# GUW4581NY :  ['GREY', 'GY']
# GNY2510NY :  ['GOLD', 'TN']
# HCC7050NY :  ['WHITE', 'WH']
# GXA9828NY :  ['GRAY', 'GY']
# GHN9766NY :  ['WHITE', 'WH']
# GYX2170NY :  ['BLACK', 'BK']
# HBN1278NY :  ['WHITE', 'WH']
# GZH2895NY :  ['BEIGE', 'GL']
# JYE4460PA :  ['GREY', 'SILVE']
# GZP1017NY :  ['RED', 'RD']
# K86CCZNJ :  ['SILVE', 'GREY']
# JDA2966PA :  ['BLUE', 'BLK']
# GSD2581NY :  ['BLUE', 'BL']
# GZH7727NY :  ['GREEN', 'GR']
# GZH3974NY :  ['WHITE', 'WH']
# HBN4181NY :  ['SILVE', 'BLUE', 'GY']
# GYR3078NY :  ['BLACK', 'BK']
# GFV3536NY :  ['BLACK', 'BK']
# GNG5997NY :  ['RED', 'RD']
# GLN3628NY :  ['RED', 'RD']
# T679936CNY :  ['BLACK', 'BK']
# HFD1842NY :  ['SILVE', 'GY']
# HCS8317NY :  ['GRAY', 'GY']
# HBX2460NY :  ['GRY', 'GY']
# HBX1585NY :  ['WH', 'WHITE']
# GTV9978NY :  ['GREY', 'GY']
# GFP7996NY :  ['BLACK', 'BK']
# HBX2826NY :  ['BLACK', 'BK', 'BLK']
# GXM6781NY :  ['WHITE', 'WT']
# GDW1682NY :  ['BLUE', 'BL']
# GRT3330NY :  ['BLACK', 'BK']
# GUP4461NY :  ['BLACK', 'BK']
# GZK3458NY :  ['WHITE', 'WH']
# GUW8929NY :  ['WHITE', 'WH']
# HAA8549NY :  ['WHITE', 'WH']
# GXG5431NY :  ['GRAY', 'GY']
# GWM3711NY :  ['RED', 'RD']
# JWG6150PA :  ['GRY', 'GY']
# GSY2843NY :  ['BLK', 'BK']
# HCL2881NY :  ['BLACK', 'BK']
# GJU1775NY :  ['GY', 'GL']
# GYA6347NY :  ['SILVE', 'GY']
# HCG8326NY :  ['BLACK', 'GREY', 'GY']
# GYD3262NY :  ['BLK', 'BK']
# HAY8210NY :  ['RED', 'RD']
# HDS2009NY :  ['WHITE', 'WH']
# GHS2692NY :  ['GREY', 'GY']
# HEB1404NY :  ['SILVE', 'GY']
# JZL6797PA :  ['SILV', 'GRAY']
# GXS6115NY :  ['SILV', 'GY']
# GEP8537NY :  ['SILV', 'GY']
# HDD4954NY :  ['SILV', 'GY']
# GYA8507NY :  ['BK', 'BLACK']
# K83FGENJ :  ['GRAY', 'SILVE']
# H46ENCNJ :  ['SILVE', 'GY', 'BRN', 'GREY']
# GRU8355NY :  ['SILVR', 'GY']
# GJP9192NY :  ['WHITE', 'WH']
# GJB4656NY :  ['SILVR', 'GY']
# GUY8898NY :  ['BLACK', 'BK']
# HBZ8882NY :  ['BLK', 'BLACK', 'BK']
# HFD3103NY :  ['SIL', 'GY']
# GZC4972NY :  ['BROWN', 'BR']
# GGS5132NY :  ['BLUE', 'BL']
# GGS7869NY :  ['TAN', 'GREY']
# GMK8878NY :  ['BLACK', 'BK']
# HBB4697NY :  ['BLK', 'BK']
# GRJ9557NY :  ['GRAY', 'BLK']
# GEN7289NY :  ['SILVE', 'GL']
# HBB2918NY :  ['SILVE', 'GY']
# GRK1115NY :  ['BLACK', 'BK']
# HBG4058NY :  ['GY', 'GREY']
# HPH9053PA :  ['BLK', 'BLACK']
# GXL8805NY :  ['BL', 'GY']
# GWT8915NY :  ['BLACK', 'BK']
# GFT2223NY :  ['BLK', 'BK']
# GUH1160NY :  ['WHITE', 'WH']
# HDC5991NY :  ['WHITE', 'WH']
# GTS6221NY :  ['BLK', 'BK']
# GSF8525NY :  ['BLK', 'BLACK']
# HEH6173NY :  ['BLUE', 'BL']
# GEP5709NY :  ['BLK', 'GY']
# GXF5230NY :  ['GREY', 'GY']
# HBB4491NY :  ['BLUE', 'BL']
# KBM4535PA :  ['BK', 'BLACK']
# GPD6773NY :  ['SILVE', 'GY']
# GCW6655NY :  ['BLK', 'BK']
# HDB7700NY :  ['BLUE', 'BL']
# HAY7744NY :  ['GRY', 'GY']
# HDV4910NY :  ['BLK', 'BK']
# GYR1623NY :  ['WHITE', 'WH']
# GEA3634NY :  ['BLACK', 'BK']
# JTN2268PA :  ['GREEN', 'GREY']
# GWT8924NY :  ['BLK', 'BK']
# GSV8550NY :  ['GRY', 'GY']
# GLU6499NY :  ['WT', 'WH']
# GNZ1306OH :  ['GY', 'SILVE']
# GZY4075NY :  ['GREEN', 'GRN']
# GTS3765NY :  ['WHITE', 'GY']
# GYC5789NY :  ['BLK', 'BK']
# GJM2791NY :  ['GRY', 'GREY']
# GXG3478NY :  ['WHI', 'WH']
# JPX5425PA :  ['GRAY', 'GRY']
# GLH9983NY :  ['SILVR', 'GRAY']
# GXB5035NY :  ['TN', 'OTHER', 'TAN']
# HCH5921NY :  ['BLACK', 'BK']
# L47FDSNJ :  ['GY', 'GREY', 'BLACK']
# HCU2295NY :  ['GY', 'GREY']
# HAX7907NY :  ['BLACK', 'BK']
# GZH7049NY :  ['BLACK', 'BLK']
# HEA8508NY :  ['WHITE', 'WH']
# T693177CNY :  ['BLACK', 'BK']
# GVM3974NY :  ['GRY', 'GY']
# GGZ8709NY :  ['GRY', 'GY']
# GJZ3370NY :  ['GRY', 'GY']
# HCZ2851NY :  ['BLUE', 'GREEN', 'BL', 'GR']
# HBB3626NY :  ['GRAY', 'GY']
# GNC2908NY :  ['GRAY', 'GY', 'GREY']
# GFV4221NY :  ['BLACK', 'BK']
# HCZ1437NY :  ['BLACK', 'BK']
# GTS6675NY :  ['GOLD', 'RD']
# GWK9665NY :  ['GRAY', 'GREY']
# GTT2727NY :  ['GRAY', 'GRY']
# GPD8198NY :  ['GREY', 'GY']
# GNH4457NY :  ['GY', 'LTG']
# GMA7675NY :  ['BK', 'BLACK']
# GSY2613NY :  ['GREEN', 'GR']
# GLH1336NY :  ['BLK', 'BK']
# HAL6993NY :  ['SILVE', 'GY']
# GEH8554NY :  ['BLK', 'BK']
# GSC6871NY :  ['BLUE', 'BL']
# GPW3619NY :  ['BLUE', 'BL']
# T655367CNY :  ['BLACK', 'BK']
# GYW6728NY :  ['SILVE', 'GY']
# GUK6973NY :  ['BLACK', 'BK']
# GWK3834NY :  ['WHITE', 'WH']
# GZN1744NY :  ['WHITE', 'WH']
# GZP8042NY :  ['BLACK', 'RED', 'BK']
# GRG3359NY :  ['WHITE', 'GR']
# HBU4549NY :  ['BLACK', 'BL']
# GWF7984NY :  ['WHITE', 'WH']
# HCR3950NY :  ['TAN', 'TN']
# GNX4345NY :  ['BLUE', 'GY']
# GSC1051PA :  ['GREY', 'SILVE']
# GZD6641NY :  ['RED', 'RD']
# GXC2257NY :  ['WHITE', 'WH']
# HDV5177NY :  ['BLACK', 'BK']
# HDM1096NY :  ['WHITE', 'WH']
# GUY2453NY :  ['RED', 'RD']
# HXV7208PA :  ['SILVR', 'GREY']
# GDF8286NY :  ['GRAY', 'GY']
# GNT6812NY :  ['BLACK', 'BK']
# GYS1954NY :  ['GRAY', 'GY']
# GZN6995NY :  ['GRAY', 'GY']
# GLS8285NY :  ['GRAY', 'GY']
# GXV8228NY :  ['BLACK', 'BK']
# HCS3935NY :  ['WHITE', 'WH']
# GRB8122NY :  ['GOLD', 'GY']
# HEJ5054NY :  ['BLUE', 'BL']
# HAM4930NY :  ['BLACK', 'BK']
# HAM3262NY :  ['BLACK', 'BK']
# GKY2372NY :  ['BLUE', 'GY']
# HAZ1091NY :  ['GRAY', 'GY']
# HCU1667NY :  ['BLUE', 'RLU']
# GST3943NY :  ['YELLO', 'WH', 'OTHER']
# GZL4195NY :  ['BLACK', 'BK']
# GXV5813NY :  ['WHITE', 'WH']
# HDD3655NY :  ['BLUE', 'GREY']
# GRF2287NY :  ['GREEN', 'GR']
# GWJ6660NY :  ['RED', 'RD']
# GDS3126NY :  ['WHITE', 'WH']
# HDZ2550NY :  ['GR', 'GREY', 'GY']
# GNB2650NY :  ['GR', 'GY']
# GPV5395NY :  ['TAN', 'GY']
# GGJ4320NY :  ['BLACK', 'BK']
# GSR4087NY :  ['RED', 'RD']
# GYX9300NY :  ['GRAY', 'GY']
# GXS4568NY :  ['BLACK', 'BK']
# TLV14KNJ :  ['SL', 'SILVE']
# TND73ENJ :  ['BLK', 'BLACK']
# TPZ52JNJ :  ['WH', 'WHITE']
# TNC88TNJ :  ['SIL V', 'SILVE', 'GY', 'SL']
# TNW702NJ :  ['GY', 'SL']
# GUV8627NY :  ['BLACK', 'BK']
# HDV5033NY :  ['RED', 'RD']
# GXW5422NY :  ['GREY', 'GY']
# HDX2748NY :  ['BLK', 'GR']
# HES3890NY :  ['TAN', 'GREY', 'GY']
# T687332CNY :  ['BLK', 'BK']
# GBB9130NY :  ['WHITE', 'WH']
# GZJ6606NY :  ['GRAY', 'SILV', 'GY']
# GZH3440NY :  ['GREEN', 'GR']
# GHE9193NY :  ['WHITE', 'WH']
# GZE1465NY :  ['GY', 'BK']
# GMS2381NY :  ['BLK', 'BLACK']
# GMS2104NY :  ['GY', 'GRY']
# GNL1347NY :  ['GRAY', 'GY']
# GLP7382NY :  ['GY', 'SILVE']
# GXV4323NY :  ['GRAY', 'SILVE']
# HDV4731NY :  ['WH', 'GY', 'SILVE']
# HBB1051NY :  ['BLK', 'BK']
# HBN8468NY :  ['BLACK', 'BK']
# GEL3055NY :  ['BLACK', 'BK']
# HDX3722NY :  ['WHITE', 'WH']
# GMZ5008NY :  ['WHITE', 'WH']
# GXY6689NY :  ['WHITE', 'WH']
# T59FCZNJ :  ['TAN', 'TN', 'GOLD.']
# GAD4670NY :  ['BK', 'BLACK', 'BLK']
# T656675CNY :  ['BLK', 'BK']
# GTZ8525NY :  ['GY', 'BK']
# GMJ5937NY :  ['GRY', 'GY']
# HCF6215NY :  ['BK', 'GY']
# JYL5396PA :  ['GY', 'GREY']
# HDV4214NY :  ['BLACK', 'BK']
# HCM8781NY :  ['WHITE', 'WH']
# HCV4616NY :  ['SLV', 'GREY']
# HCT2641NY :  ['BGE', 'GY']
# GMZ8879NY :  ['GRY', 'OTHER', 'TN']
# T686998CNY :  ['BLACK', 'BK']
# T680415CNY :  ['BLK', 'BK']
# HES3251NY :  ['BR', 'BK']
# GZK8949NY :  ['RED', 'RD']
# JTL0881PA :  ['BLK', 'BLACK', 'PURPL']
# GBT6303NY :  ['BLACK', 'GY', 'BL']
# GPF1333NY :  ['GRAY', 'GY']
# HCN4343NY :  ['GRAY', 'GREY', 'GY']
# GNH4328NY :  ['GRAY', 'GOLD', 'TN']
# GPE2156NY :  ['RED', 'RD']
# GPN8568NY :  ['WT', 'WH']
# HCT2055NY :  ['BK', 'BLACK']
# N91DWNNJ :  ['GY', 'GREY', 'SIL']
# GHH3606NY :  ['GY', 'SILVE']
# GNE7686NY :  ['GY', 'GREY', 'BR']
# GTL1779NY :  ['WH', 'WHI']
# T39CRVNJ :  ['TAN', 'TN']
# P74FZWNJ :  ['MAROO', 'RED']
# GWD5435NY :  ['WHI', 'WH']
# HDF6402NY :  ['GR', 'BL']
# GVG5376NY :  ['RD', 'RED']
# JZD1514PA :  ['BK', 'BLACK']
# GTS3747NY :  ['WH', 'GY']
# GTS7043NY :  ['GY', 'GREY']
# K41EEBNJ :  ['BK', 'BLACK']
# GGF3687NY :  ['RD', 'RED']
# HFA1019NY :  ['BK', 'BLACK']
# GXV1661NY :  ['GY', 'GREY']
# GGWA25FL :  ['GY', 'GRAY']
# HEE2954NY :  ['BK', 'BLACK']
# GRA6376NY :  ['BLK', 'BK']
# GKZ8292NY :  ['BK', 'BLK']
# GCP8697NY :  ['BLK', 'BLACK', 'BK']
# GTX1240NY :  ['GY', 'SILVE']
# GYW4241NY :  ['GRAY', 'GY']
# HES5476NY :  ['TAN', 'GL']
# HDW2292NY :  ['BLK', 'BL']
# HDU9537NY :  ['BLK', 'BLACK']
# HBN7504NY :  ['BLACK', 'BK', 'BLK']
# GMZ6958NY :  ['RED', 'OTHER']
# HBN7196NY :  ['TAN', 'SILVE', 'GY']
# GYU8374NY :  ['GREY', 'GY']
# JPG4534PA :  ['BLUE', 'BLACK']
# HBN1486NY :  ['RED', 'RD']
# HDG6999NY :  ['BLUE', 'BL']
# S98FKLNJ :  ['SILVE', 'OTHER', 'GREY']
# GKY4814NY :  ['GOLD', 'TN']
# GPX3034NY :  ['SILVE', 'GY']
# GHG9295NY :  ['GY', 'GR']
# GZH5473NY :  ['TAN', 'GREY', 'GL']
# T690989CNY :  ['BLACK', 'BK']
# GJE6445NY :  ['GRAY', 'GY']
# HBR8470NY :  ['GRAY', 'GY']
# GKW4709NY :  ['GRAY', 'GY', 'BR', 'SIL']
# GUM3091NY :  ['BLACK', 'BK']
# HES3507NY :  ['SILVE', 'GRAY', 'GY']
# GGC3133NY :  ['GREY', 'SILVE', 'GY']
# GXV7598NY :  ['WH', 'WHITE']
# GYC3174NY :  ['GREY', 'WH', 'WHITE']
# GZY3068NY :  ['BLK', 'BLACK']
# GUX7280NY :  ['BLK', 'BK']
# HAT1853NY :  ['BLK', 'BK']
# HEX7545NY :  ['BK', 'TN']
# GRK1894NY :  ['GY', 'GREY']
# GYR2113NY :  ['WH', 'WHITE']
# GMX8024NY :  ['GY', 'GREY']
# GBN2132NY :  ['GY', 'GREY']
# GNY2615NY :  ['GREEN', 'GREY', 'GR']
# GTJ4052NY :  ['WHT', 'WHITE']
# GNW2086NY :  ['BLK', 'BK']
# GZC3206NY :  ['BLK', 'BR']
# GFC7196NY :  ['BLK', 'BLACK', 'BK']
# GZT2833NY :  ['BLU', 'BLK', 'GR']
# GXW9880NY :  ['GY', 'LTG']
# HDG7247NY :  ['WHI', 'WH', 'GRY']
# GFC7802NY :  ['BLKJ', 'BK']
# HBR8822NY :  ['GREY', 'GY']
# HCU1762NY :  ['BLK', 'BK']
# HBU4182NY :  ['BLUE', 'BL']
# HDV1050NY :  ['BLK', 'BK']
# GEK9882NY :  ['TAN', 'GOLD', 'TN']
# GSX2458NY :  ['GREY', 'GY']
# GZT4705NY :  ['GREY', 'GRAY']
# T516039CNY :  ['BLK', 'BLACK', 'BK']
# GXA5437NY :  ['BLK', 'BLACK', 'BK']
# HAK5897NY :  ['WHITE', 'WH']
# JJC0162PA :  ['SILVR', 'GREY']
# GZH1335NY :  ['GRAY', 'GY']
# GYP8201NY :  ['WHITE', 'WH']
# HAX7497NY :  ['GRAY', 'SILVE', 'OTHER']
# HVV2062PA :  ['BK', 'GREY', 'SILVE']
# GZH5490NY :  ['WHITE', 'WH']
# T687138CNY :  ['BLACK', 'BK']
# GZL3824NY :  ['GRAY', 'BLACK', 'GRY']
# GMU2409NY :  ['BLK', 'BK']
# GGL3053NY :  ['BLK', 'BK']
# HBN1196NY :  ['GRAY', 'GR', 'GY']
# HZN4492PA :  ['BLUE', 'BLACK']
# T680327CNY :  ['BLK', 'BK']
# T42FNXNJ :  ['TAN', 'GOLD', 'OTHER']
# GTD8674NY :  ['BLACK', 'RD']
# HFK8942NY :  ['WHT', 'WHITE']
# JWL8665PA :  ['BLU', 'BLUE']
# HAM8448NY :  ['BLK', 'GREY']
# JPF7585PA :  ['WH', 'WHITE']
# GWK4780NY :  ['WH', 'WHITE']
# JVJ1219PA :  ['WH', 'WHITE']
# GXP9605NY :  ['BL', 'BLUE']
# HDV1831NY :  ['WH', 'WHITE']
# HJH6853PA :  ['GR', 'GREY']
# HCE4899NY :  ['BLK', 'BK']
# GUX2417NY :  ['GRE', 'GR']
# HAZ6743NY :  ['BLK', 'BK']
# GXW1939NY :  ['BLK', 'BK']
# GFR1427NY :  ['WHT', 'WHITE', 'WH']
# HAL4614NY :  ['WHT', 'WH']
# GSP9522NY :  ['GREEN', 'GR']
# GZT9811NY :  ['WH', 'WHITE']
# HAM9491NY :  ['BLK', 'BK']
# T682606CNY :  ['WHT', 'WH', 'WHITE']
# GCE8914NY :  ['BLK', 'BK']
# HBX2894NY :  ['BLK', 'BK']
# GXD8670NY :  ['TN', 'GY']
# GKW8615NY :  ['GREY', 'GY']
# GTJ9561NY :  ['GRY', 'GY']
# HDZ3879NY :  ['BLU', 'BL']
# GXW1403NY :  ['BLU', 'BL']
# GXM4390NY :  ['BLUE', 'BL']
# GBX6638NY :  ['RD', 'RED']
# HAA2845NY :  ['BLACK', 'BK']
# GMZ6158NY :  ['WHITE', 'WH']
# T672391CNY :  ['BLK', 'BK']
# T482880CNY :  ['BLK', 'BK']
# GMZ3772NY :  ['GRY', 'GY']
# GUM1629NY :  ['TAN', 'BR']
# HBN2381NY :  ['GRY', 'GY']
# GWV2902NY :  ['GRY', 'BK', 'GY']
# HFA7809NY :  ['BK', 'BLACK']
# HES4547NY :  ['GRY', 'GY', 'BR']
# GXB1288NY :  ['BLACK', 'GY']
# GNT2937NY :  ['BLACK', 'BK']
# GMG8450NY :  ['GREY', 'GY']
# GYK9114NY :  ['WHITE', 'WH']
# GJP3190NY :  ['SILVE', 'GY']
# GUW2517NY :  ['GY', 'GREY']
# GAU6731NY :  ['GY', 'GRAY']
# GSA4578NY :  ['GY', 'BLACK']
# HCD1695NY :  ['GY', 'BL']
# GPR4731NY :  ['GRAY', 'GR', 'OTHER']
# T65EVZNJ :  ['BLK', 'BLACK', 'BK']
# GGH8809NY :  ['BLK', 'BK']
# GTS3704NY :  ['WH', 'GY']
# JHK0016PA :  ['GY', 'GRAY']
# KBT8336PA :  ['BK', 'BLACK']
# GMT8984NY :  ['TN', 'BR']
# GDY2413NY :  ['GREEN', 'GR']
# GMA9874NY :  ['RED', 'RD']
# GXR6686NY :  ['GRAY', 'GY']
# GJZ1722NY :  ['BLACK', 'BK']
# L89BCCNJ :  ['GY', 'SILVE', 'GREY']
# HBB1367NY :  ['BLK', 'BK']
# GTD7952NY :  ['RD', 'RED']
# GYD4162NY :  ['BLK', 'BK', 'BLACK']
# GSH3235NY :  ['GY', 'GREY', 'TN']
# GUJ6704NY :  ['SILVE', 'GY']
# GMB1360NY :  ['RED', 'RD']
# RR1F67PA :  ['GY', 'TAN', 'GREY']
# GYV8588NY :  ['BLK', 'BLACK']
# GTS3051NY :  ['WHT', 'WHITE', 'WH']
# GZH6994NY :  ['GRAY', 'WH', 'GY']
# GVV8488NY :  ['GY', 'GREY']
# GZJ7730NY :  ['WH', 'WHITE']
# GTZ5753NY :  ['WHITE', 'WH']
# T661172CNY :  ['BLUE', 'GY']
# GWF8730NY :  ['WHITE', 'WH']
# HBN2662NY :  ['BLACK', 'BK']
# GZF8659NY :  ['WHITE', 'WH']
# GTD6650NY :  ['BLK', 'BK']
# GFZ3076NY :  ['GRAY', 'GY']
# GUK4027NY :  ['SILVE', 'GY']
# GCV8712NY :  ['BLACK', 'BK']
# GXB2196NY :  ['GREY', 'BL']
# GVS8328NY :  ['GY', 'GRY']
# P31GAMNJ :  ['GY', 'SILVE', 'GREY']
# HDY9745NY :  ['WHITE', 'WH']
# GMJ9374NY :  ['GRAY', 'SILVE']
# GZH3280NY :  ['BLK', 'GR']
# HEZ8588NY :  ['BLK', 'BLACK']
# GYU8808NY :  ['GOLD', 'TN']
# HBR8047NY :  ['BK', 'BLACK']
# HCC6767NY :  ['BK', 'BLACK']
# HBU4011NY :  ['BLUE', 'BL']
# HDG7024NY :  ['GRY', 'TN']
# GTD9698NY :  ['GRY', 'GY']
# SANXNY :  ['GRAY', 'GY', 'BLACK']
# GTH9846NY :  ['GRY', 'GY']
# GSC2545NY :  ['BLACK', 'BK']
# GKE2466NY :  ['BLACK', 'BK']
# HDC5721NY :  ['BLACK', 'BK']
# M92AAWNJ :  ['RD', 'RED']
# GGU5272NY :  ['WHITE', 'WH']
# HAP6777NY :  ['GRAY', 'GREY', 'GY']
# HCG8442NY :  ['BLUE', 'BL']
# HFB2992NY :  ['GRAY', 'GY']
# GPF1538NY :  ['GLD', 'BK']
# GSM1821NY :  ['BLK', 'BK']
# HAY7268NY :  ['BLUE', 'BL']
# T634697CNY :  ['GRY', 'SILVE']
# GRT7040NY :  ['WHITE', 'WH']
# GWH9309NY :  ['WHT', 'WHITE', 'WH']
# HBN7679NY :  ['BLUE', 'BL']
# GMZ9938NY :  ['BLK', 'BL']
# GLK2859NY :  ['BLACK', 'BK']
# GZH7733NY :  ['GREEN', 'GR']
# GWM5780NY :  ['BLU', 'BK']
# GYW3503NY :  ['BLK', 'BK']
# HCA4462NY :  ['WHITE', 'WH']
# GMU9144NY :  ['GRAY', 'BL']
# GYX2629NY :  ['WH', 'WHITE']
# GSA3420NY :  ['BLK', 'GY', 'BLACK']
# JTG2738PA :  ['GREY', 'OTHER']
# GAC5219NY :  ['SILVE', 'GREY', 'GY']
# T638178CNY :  ['BLUE', 'WHITE', 'BLK', 'WH']
# T649446CNY :  ['WHITE', 'WH']
# HFM8420NY :  ['BLK', 'BLACK']
# T672810CNY :  ['BLACK', 'BK']
# GYF9766NY :  ['BLACK', 'BK']
# HBN1631NY :  ['BLACK', 'BK']
# GYH9861NY :  ['GREY', 'GY']
# GNE7783NY :  ['BLK', 'BK']
# HES3859NY :  ['WHITE', 'WH']
# HAL1663NY :  ['GRY', 'GREY', 'GY']
# GSW3320NY :  ['GY', 'BL']
# HDC6528NY :  ['GREY', 'WH']
# HCL8261NY :  ['GY', 'WH']
# GDG9602NY :  ['RED', 'MR']
# KBE1447PA :  ['BLACK', 'BK']
# GUG8793NY :  ['BLUE', 'BL']
# GAK4702NY :  ['WHITE', 'WH']
# GLJ9231NY :  ['WHITE', 'WH']
# HAW5343NY :  ['SILVR', 'GY']
# HFB2609NY :  ['BLK', 'BLACK']
# GHE9074NY :  ['GRY', 'SILVE', 'GY']
# R829298IL :  ['BLUE', 'OTHER']
# HCT1405NY :  ['BLK', 'BLACK']
# GPW6099NY :  ['GRAY', 'BLACK']
# GZH6910NY :  ['RED', 'MR']
# JWY0524PA :  ['GY', 'GREY']
# HCT1291NY :  ['BK', 'BLK']
# GHR7324NY :  ['RD', 'RED']
# GXH9685NY :  ['GRAY', 'GY']
# GMZ4298NY :  ['GREY', 'SILVE', 'GY']
# HCF6337NY :  ['BLK', 'BK']
# HCF6331NY :  ['BLK', 'BLACK', 'BK']
# HCN8846NY :  ['WHITE', 'WH']
# GCR2090NY :  ['GRAY', 'LT/', 'SILVE']
# HBN5592NY :  ['BLUE', 'BL']
# GUW2698NY :  ['GREEN', 'GR']
# GZH8690NY :  ['BLK', 'BK']
# T641908CNY :  ['BLK', 'BK']
# HBS6188NY :  ['WHITE', 'WH']
# GXW8372NY :  ['BLK', 'BK']
# HES1543NY :  ['GRAY', 'GY']
# GNL6012NY :  ['BLUE', 'BK']
# GHP1908NY :  ['WHITE', 'WH']
# T682962CNY :  ['GRAY', 'GY']
# HBN3699NY :  ['BLUE', 'BL']
# HDT9546NY :  ['WH', 'GY']
# HET1568NY :  ['GREEN', 'GR']
# KBF8291PA :  ['WH', 'WHITE']
# HAW4934NY :  ['BLACK', 'BK']
# GXW9902NY :  ['RED', 'RD']
# JJP8592PA :  ['BLCK', 'BLACK']
# GXX4799NY :  ['BLK', 'BK', 'SILVE']
# GXA9366NY :  ['TAN', 'GY']
# HDF5057NY :  ['BLUE', 'GREY', 'BL']
# GTE8694NY :  ['GRAY', 'GY']
# GTC7883NY :  ['WHITE', 'WH']
# GZH1908NY :  ['RED', 'RD']
# JPB109MD :  ['GY', 'BLACK']
# GWH9371NY :  ['BLUE', 'BL']
# GJZ2000NY :  ['RED', 'BR']
# GLP4448NY :  ['BLK', 'BLACK', 'BLUE', 'BL']
# GHN4920NY :  ['BLK', 'BK']
# GND5849NY :  ['GRAY', 'GY']
# HBE1305PA :  ['GRAY', 'SILVE']
# GRZ8575NY :  ['BLK', 'BLACK']
# GFR4585NY :  ['BL', 'GR']
# HDD3378NY :  ['GREEN', 'BL']
# GXB9499NY :  ['BLACK', 'GY']
# GXW1380NY :  ['GOLD', 'GY']
# GKY4435NY :  ['BLUE', 'GR']
# GXB5417NY :  ['TAN', 'TN']
# GVE8771NY :  ['BLUE', 'BL', 'WHITE']
# GTV9374NY :  ['GRAY', 'GY']
# HCM4565NY :  ['GREY', 'GY']
# GSH3475NY :  ['WH', 'WHITE']
# HDD8082NY :  ['WHITE', 'WH']
# GNY1128NY :  ['GY', 'TN']
# GKX6702NY :  ['WHT', 'WHITE']
# GUX2916NY :  ['BLK', 'BLACK', 'BK']
# GTL1899NY :  ['BLK', 'BK']
# GLS7078NY :  ['RD', 'MR']
# HCD7812NY :  ['SILVE', 'GY']
# GCP3975NY :  ['TAN', 'BR']
# J46FYJNJ :  ['GREY', 'SILVE', 'SL']
# GZX2537NY :  ['GREY', 'GY']
# GUV2200NY :  ['GREY', 'GY']
# GWM3959NY :  ['BLK', 'BLUE']
# HCU7944NY :  ['BLK', 'BK']
# NB1211NY :  ['WT', 'WHITE', 'BLUE']
# GHF2877NY :  ['BLK', 'BLACK']
# GBL1166NY :  ['BLK', 'BK']
# GTJ6355NY :  ['BLK', 'BK']
# GUU8175NY :  ['GRAY', 'GREY']
# HBT9629NY :  ['BLACK', 'BK']
# GTL3513NY :  ['BLK', 'BK']
# GZP6655NY :  ['GRAY', 'GY']
# M15FMWNJ :  ['SIL', 'SILVE']
# HEH3080NY :  ['WH', 'WHITE']
# HDF4079NY :  ['GRY', 'GY']
# GVT2090NY :  ['BLACK', 'BK']
# GYP1783NY :  ['WHITE', 'WH']
# HCM1295NY :  ['TAN', 'TN']
# HAL7717NY :  ['TAN', 'GY']
# HDB7833NY :  ['BLUE', 'GY']
# GED7404NY :  ['GRAY', 'GY']
# HBB2207NY :  ['SIL', 'GRY', 'GY']
# HCV6605NY :  ['GRAY', 'BL']
# HAC7592NY :  ['GRAY', 'GY']
# GDX8208NY :  ['GREEN', 'GR']
# HBS3158NY :  ['SILVR', 'GY']
# GPN1495NY :  ['GY', 'GREY']
# HCC9453NY :  ['BLACK', 'BK']
# GYP2207NY :  ['WHITE', 'WH']
# GCM9067NY :  ['GREY', 'GY']
# HAL4666NY :  ['SILVE', 'GY']
# GUP1444NY :  ['SILVE', 'GY']
# HER5576NY :  ['GRAY', 'GY']
# GDW2304NY :  ['BLK', 'BLACK', 'BK']
# T688977CNY :  ['BK', 'BLK']
# GLN7193NY :  ['BLACK', 'BK']
# HDD4072NY :  ['GREY', 'GY']
# T523941CNY :  ['BLK', 'BK']
# GMD4749OH :  ['GRY', 'SILVE']
# GTR8194NY :  ['WHITE', 'GY']
# JTB8393PA :  ['BLUE', 'SILVE']
# HAE6499NY :  ['BLACK', 'BK']
# GVF9635NY :  ['BLUE', 'BL']
# HBU2080NY :  ['GRY', 'GY']
# GFT5090NY :  ['GOLD', 'TN']
# HVS5196PA :  ['GRY', 'GRAY', 'OTHER']
# HBU2947NY :  ['BLACK', 'BLUE', 'ORANG']
# GGY3683NY :  ['BLK', 'BLACK', 'BK']
# JEN318NY :  ['GRY', 'SILVE', 'GRAY']
# HDC5724NY :  ['GRAY', 'GY']
# GNN9332NY :  ['GRAY', 'GY']
# GFP6848NY :  ['WHITE', 'WH']
# GTM5538NY :  ['GRAY', 'GR']
# HFB7253NY :  ['GY', 'GREY']
# GAR5729NY :  ['BLACK', 'BK']
# HAR5944NY :  ['BLK', 'PR']
# GYU6029NY :  ['BLK', 'BK']
# HBU2672NY :  ['RED', 'RD']
# GWD2114NY :  ['BLACK', 'BK']
# GWF4419NY :  ['SILVE', 'GY']
# GTY2998NY :  ['SILV', 'TAN']
# GCV4917NY :  ['BLUE', 'BK']
# GWC7029NY :  ['WHITE', 'WH']
# GYP8335NY :  ['BLK', 'BK']
# GSV9663PA :  ['BLK', 'BLACK']
# GPL8883NY :  ['TAN', 'TN']
# GRB8427NY :  ['GREEN', 'GR']
# GRT3695NY :  ['GREEN', 'GR']
# GTJ8760NY :  ['GRAY', 'GY']
# GWM2181NY :  ['GY', 'GRAY']
# GFC7118NY :  ['BLK', 'BK']
# GEN6804NY :  ['TAN', 'TN']
# N79FHCNJ :  ['WH', 'GY']
# GYG9777NY :  ['BLACK', 'BK']
# GMU3689NY :  ['BLK', 'BK']
# GTJ3487NY :  ['WHITE', 'WH']
# HAM9368NY :  ['BLACK', 'BK']
# GXH4893NY :  ['GRAY', 'GREY', 'GY']
# GPH8046NY :  ['GREY', 'GY']
# GES3131NY :  ['BLACK', 'BK']
# GFG5227NY :  ['BLACK', 'BK']
# GVM8261NY :  ['GY', 'GRY', 'BK']
# GMH9085NY :  ['WHITE', 'WH']
# T692411CNY :  ['BLACK', 'BLK', 'BK']
# GXS5914NY :  ['WHITE', 'WH']
# GJD3297NY :  ['SILVE', 'GY']
# GLJ8614NY :  ['GRAY', 'GY']
# T674164CNY :  ['BLK', 'BK']
# GKJ3600NY :  ['GREEN', 'GR']
# GTJ3992NY :  ['WHITE', 'WH']
# GXB4939NY :  ['WHITE', 'WH']
# HDC5003NY :  ['BLUE', 'BL']
# GJB9518NY :  ['SILVR', 'GY']
# GST1727NY :  ['BLK', 'BK']
# GXY6733NY :  ['BLK', 'BK']
# GLJ5168NY :  ['BLACK', 'BK']
# GPN1603NY :  ['GREY', 'GY']
# GDP1582NY :  ['WHITE', 'WH']
# GEU1422NY :  ['WHITE', 'WH']
# GTT7500NY :  ['BLUE', 'BL']
# GNX5927NY :  ['GY', 'GR']
# KBK0321PA :  ['GY', 'GRAY', 'GREY']
# GRP2684NY :  ['BLACK', 'BK']
# HEZ3611NY :  ['BLK', 'BK']
# HFD3601NY :  ['GREY', 'GY']
# GTV7838NY :  ['BLK', 'BLACK', 'BK']
# HCC1791NY :  ['RED', 'RD']
# GYD6586NY :  ['GOLD', 'GL']
# HBB3861NY :  ['BLUE', 'BL']
# GYD5372NY :  ['GY', 'BL']
# GYP4530NY :  ['BLK', 'BK']
# GJP7426NY :  ['SILVE', 'GY']
# HDV3478NY :  ['BLUE', 'BL']
# GZC6900NY :  ['SILVE', 'GY']
# L856746IL :  ['GREY', 'SILVE', 'GRAY', 'SL']
# GNN9878NY :  ['WHITE', 'WH']
# GYW1421NY :  ['WHITE', 'WH']
# GYD5074NY :  ['RED', 'RD']
# T650937CNY :  ['YELLO', 'BK']
# GKM5337NY :  ['BLK', 'BK']
# GAM6503NY :  ['GREY', 'SILVE', 'GY']
# HDD4473NY :  ['BRN', 'BK']
# HCF1177NY :  ['BLK', 'BLACK', 'BK']
# GJZ4554NY :  ['BLACK', 'BK']
# HAS8566NY :  ['SL', 'BK', 'SILVE', 'SILVR', 'GRY', 'GY']
# HDU2025NY :  ['BK', 'BLK']
# GKR7135NY :  ['BLK', 'BK']
# GTJ4563NY :  ['BLACK', 'BK']
# HDV2670NY :  ['BLACK', 'BK']
# GTB8908NY :  ['WHITE', 'WH']
# HFD2494NY :  ['GRN', 'GREEN', 'GR']
# J55GEZNJ :  ['WHT', 'WHITE']
# GBH3020NY :  ['WHT', 'WH']
# HBG4391NY :  ['BG', 'GL']
# GDY5597NY :  ['BLUE', 'BL']
# GUY2320NY :  ['RED', 'RD']
# HAP2690NY :  ['BLUE', 'BL']
# HCE8803NY :  ['BLUE', 'BL']
# HDV1418NY :  ['BLACK', 'BK']
# GGT5241NY :  ['BLACK', 'BK']
# HCG8650NY :  ['BLUE', 'BL']
# GRP5653NY :  ['WHITE', 'WH']
# GSU1372NY :  ['BLACK', 'BLK']
# HEE1085NY :  ['SILVE', 'GY']
# GMT9337NY :  ['GRAY', 'GY']
# JZZ0350PA :  ['GRAY', 'GREY', 'GY']
# GZZ2138NY :  ['GRAY', 'GY']
# GUE6690NY :  ['GRAY', 'GY']
# GWB2271NY :  ['RED', 'RD']
# JTH4967PA :  ['GY', 'SILVE']
# GMT9760NY :  ['BRO', 'BL']
# T665842CNY :  ['BLACK', 'BK']
# HDX1261NY :  ['BLUE', 'BL']
# GFE9141NY :  ['SILVE', 'GY']
# KAY4627VA :  ['BLK', 'BLACK']
# HBT4079NY :  ['BLK', 'BK', 'BLACK']
# HCD5575NY :  ['BLK', 'BL']
# HBU1980NY :  ['WHITE', 'WH']
# HAN8625NY :  ['GN', 'BLACK', 'GR']
# GVW5666NY :  ['SILVR', 'GY']
# HCR7581NY :  ['WHITE', 'WH']
# GUR3183NY :  ['BLUE', 'BL']
# HCF6374NY :  ['SILVR', 'GRAY', 'GREY', 'GY']
# HBN2908NY :  ['GN', 'GREY']
# HEA6471NY :  ['BLACK', 'BL']
# HBV4440NY :  ['WHITE', 'WH']
# HDV3222NY :  ['GRAY', 'GY']
# HDK3523NY :  ['BLACK', 'BK']
# GZT9595NY :  ['SILVE', 'GY']
# HDC5704NY :  ['GRAY', 'GY']
# JZL6753PA :  ['BK', 'BLACK']
# MRABCNY :  ['WHITE', 'WH']
# GUM3859NY :  ['BLUE', 'BL']
# HAR6473NY :  ['BLK', 'BK']
# GGF7312NY :  ['GREEN', 'TN']
# KBE5176PA :  ['GY', 'SILVE']
# GKU2011NY :  ['GRY', 'GY']
# J75DWANJ :  ['WHITE', 'WT']
# GGP2537NY :  ['BLK', 'BLACK', 'BK']
# HCU2477NY :  ['RED', 'RD']
# HAX4267NY :  ['BLK', 'BK']
# GZE1617NY :  ['RED', 'RD']
# T694315CNY :  ['BLACK', 'BLK', 'BK']
# GMZ4114NY :  ['BLACK', 'BK']
# TEB60FNJ :  ['BLUE', 'WT', 'WHITE']
# T686587CNY :  ['BLACK', 'BK']
# GNR9071NY :  ['GRAY', 'GY']
# T662784CNY :  ['GREY', 'GY']
# HEW5493NY :  ['BLUE', 'BL']
# HCU2503NY :  ['SLVR', 'GY']
# GSS8943NY :  ['WH', 'WHITE']
# GFD8841NY :  ['GRAY', 'GY']
# T672383CNY :  ['BLACK', 'BK']
# GUZ5252NY :  ['WHITE', 'WH']
# GWV5352NY :  ['GRAY', 'GY']
# GZF7951NY :  ['BLK', 'BK']
# GAR3748NY :  ['GOLD', 'BR']
# HDD3626NY :  ['BLUE', 'BL']
# GUL9400NY :  ['GRAY', 'GY']
# GNN8550NY :  ['WHITE', 'WH']
# GPP7832NY :  ['WHITE', 'WH']
# GRH4212NY :  ['SILVE', 'GY']
# GUW2222NY :  ['GREY', 'GY']
# GGZ5169NY :  ['GREY', 'GY', 'SILVE']
# K12FGZNJ :  ['GREEN', 'BLACK', 'OTHER']
# GSW7727NY :  ['WHITE', 'GY']
# HBB4847NY :  ['BLACK', 'BK']
# T698190CNY :  ['WHITE', 'BL']
# HCN3655NY :  ['BLACK', 'GY']
# HDE5217NY :  ['WHITE', 'WH']
# GRG5260NY :  ['SILVE', 'GR']
# HEE6658NY :  ['WHITE', 'WH']
# GFC5087NY :  ['BLUE', 'BL']
# HDX1463NY :  ['WHITE', 'WH']
# GDB3864NY :  ['SILVE', 'GY']
# GJY8813NY :  ['BLACK', 'BK']
# J88AGRNJ :  ['SILVE', 'GREY']
# HBT5642NY :  ['GRAY', 'GY']
# GTX2026NY :  ['RED', 'RD']
# GUP6227NY :  ['GRAY', 'GY']
# HBS5934NY :  ['BLACK', 'BK']
# HCR1840NY :  ['SILVE', 'GY']
# GPY9671NY :  ['TAN', 'BROWN']
# GMR4099NY :  ['BLACK', 'BK']
# GVK5506NY :  ['SILVE', 'SILVR', 'LTG', 'LTGY']
# GXE4193NY :  ['BLACK', 'BK']
# HBB2675NY :  ['WHITE', 'GR']
# GDG5256NY :  ['BLACK', 'BK']
# HDK3851NY :  ['RED', 'RD']
# HAL1876NY :  ['GRY', 'BL']
# HFD3208NY :  ['RED', 'RD']
# HAX6731NY :  ['BLK', 'BLACK']
# L59FJENJ :  ['BLK', 'BK']
# GHG4831NY :  ['BK', 'BLACK']
# GWF2093NY :  ['BLACK', 'BK']
# GLL6764NY :  ['BLK', 'BK']
# HDV3871NY :  ['GRAY', 'GY']
# GWM1819NY :  ['SIL', 'GY']
# HCL2995NY :  ['BLACK', 'BK']
# HAB2991NY :  ['GRY', 'GY']
# GUU9557NY :  ['BLK', 'BK']
# GDV2322NY :  ['GRY', 'GY']
# GTV7812NY :  ['GRY', 'GY']
# GXN5079NY :  ['GRY', 'GREY', 'GY']
# HDV2026NY :  ['BLUE', 'BL']
# GNV9900NY :  ['GRAY', 'GY']
# HCA9047NY :  ['BLUE', 'GY']
# HDV5265NY :  ['GY', 'SILVE']
# GRT1996NY :  ['SILVE', 'GY']
# GBE2278NY :  ['WHITE', 'WH']
# GXD5853NY :  ['BLK', 'BK']
# HCB1553NY :  ['BLK', 'BK']
# HFD2568NY :  ['BLK', 'BL', 'BLUE']
# GYS1901NY :  ['BLK', 'BK']
# GKR1336NY :  ['BLK', 'BK', 'BLACK']
# GZC5782NY :  ['BLACK', 'BK']
# GJM1764NY :  ['BK', 'BLACK']
# GSR4194NY :  ['WH', 'WHITE']
# JZB3478PA :  ['BL', 'BLUE']
# GLM9877NY :  ['BLACK', 'BK']
# GDR5137NY :  ['GY', 'GREY', 'GRAY']
# GXF5515NY :  ['RED', 'RD']
# HCL3458NY :  ['GRAY', 'GY']
# GHG6426NY :  ['WHT', 'WH']
# K25243KPA :  ['WHITE', 'WH']
# PF277WFL :  ['BLACK', 'BLUE']
# GIY1533OH :  ['WH', 'WHITE']
# GHR5044NY :  ['RED', 'RD']
# HCZ1841NY :  ['GRY', 'GY']
# GCK8374NY :  ['GREY', 'GY']
# GJY8751NY :  ['TAN', 'TN']
# GST1260NY :  ['GRAY', 'GY']
# GUU8252NY :  ['GREEN', 'GY']
# GST4068NY :  ['BLK', 'GY']
# T679046CNY :  ['GREY', 'GY']
# T669088CNY :  ['BLK', 'BK']
# JWA4166PA :  ['GREY', 'OTHER']
# GKX2745NY :  ['GRY', 'SILVE', 'GREY', 'GY']
# GWE6756NY :  ['GY', 'BR']
# HCC4747NY :  ['BK', 'BLK']
# GRV6567NY :  ['GY', 'GREY']
# JYW9864PA :  ['BL', 'BLUE']
# HCR6239NY :  ['BK', 'BLACK', 'BLK']
# GRA6849NY :  ['SILVE', 'GREY', 'GY']
# GTR1697NY :  ['WHT', 'WH']
# GYG7557NY :  ['WHT', 'WH']
# T653722CNY :  ['GRY', 'GY']
# GNT2780NY :  ['WHT', 'WH']
# HDD2825NY :  ['GRY', 'GY']
# GAYD58FL :  ['GRY', 'GREY', 'BLU']
# GWC5724NY :  ['BLU', 'BLUE', 'BL']
# GRF2115NY :  ['GRY', 'GY']
# HAN2670NY :  ['WHT', 'WH']
# GZD4789NY :  ['WHT', 'WH']
# JXR6311PA :  ['GREEN', 'BLUE']
# GCE2457NY :  ['SILVE', 'GY']
# HBT6571NY :  ['BLK', 'BK']
# HBX3544NY :  ['RED', 'RD']
# HAX7459NY :  ['GRY', 'GY']
# G1120GFL :  ['RD', 'RED']
# GZP7137NY :  ['WHT', 'WH']
# GNJ2892NY :  ['GREY', 'BK']
# GWD6465NY :  ['GY', 'BR']
# GZC3476NY :  ['GRAY', 'GY']
# HDW8685NY :  ['WHITE', 'WH']
# HCG5705NY :  ['WHITE', 'WH']
# GZY3617NY :  ['GREY', 'GY']
# GFC8478NY :  ['WHITE', 'WH']
# GZJ5740NY :  ['BLACK', 'BK']
# GVK5276NY :  ['WHITE', 'WH', 'BK']
# L35FTLNJ :  ['SILVR', 'SILVE', 'GY']
# GWM2387NY :  ['BLACK', 'BK']
# HDV4529NY :  ['TAN', 'GL']
# GYD6262NY :  ['GRY', 'GY']
# GYD5715NY :  ['BLACK', 'BK']
# GYR2092NY :  ['BLACK', 'BK']
# GAR6581NY :  ['WHITE', 'WH']
# GEK1002NY :  ['BLK', 'BLACK', 'BK']
# GVK8460NY :  ['BLK', 'BL']
# GUJ5973NY :  ['BLK', 'BK']
# HCC1035NY :  ['WHITE', 'WH']
# GWU9210NY :  ['GRAY', 'GY']
# GXD9896NY :  ['BLK', 'RD']
# GZT8730NY :  ['BLUE', 'GY']
# GFH7851NY :  ['GREY', 'GRAY']
# M80DLYNJ :  ['BLK', 'BLACK']
# GVC5287NY :  ['BLUE', 'GY']
# GYD5809NY :  ['BLACK', 'BK', 'BLK']
# T671490CNY :  ['BLACK', 'BK']
# GRA3507NY :  ['WHITE', 'WH']
# GPV2897NY :  ['GOLD', 'TN']
# GPJ9560NY :  ['BLACK', 'BK']
# GNH4821NY :  ['BLACK', 'GR']
# HSM3774PA :  ['GREY', 'GRAY']
# HDC5487NY :  ['SILVE', 'GY']
# GZC5041NY :  ['SILVE', 'GY']
# HAN4778NY :  ['BLACK', 'BK']
# T691821CNY :  ['BLACK', 'BK']
# HDX4710NY :  ['BLACK', 'BK']
# GWF5224NY :  ['GOLD', 'GY']
# HZV8672PA :  ['BLACK', 'GREY']
# GUL8146NY :  ['GRY', 'GY']
# GDX9451NY :  ['GY', 'BL']
# GZJ5086NY :  ['WHITE', 'WH']
# HCY4122NY :  ['BLACK', 'BK']
# GEB4565NY :  ['GY', 'SILVE']
# GHM7168NY :  ['BLUE', 'BL', 'BLU']
# GWK3953NY :  ['BLACK', 'BK']
# HAB8667NY :  ['GREY', 'GY']
# HCN8942NY :  ['WHITE', 'WH']
# GIEF87FL :  ['GY', 'GREY']
# GPP3663NY :  ['GRAY', 'GY']
# GYP5113NY :  ['BLACK', 'BK']
# HDY6453NY :  ['WHITE', 'WH']
# GFW3131NY :  ['WHITE', 'WH']
# HBB4655NY :  ['BLUE', 'BL']
# HCC3087NY :  ['BLACK', 'BK']
# HDD4168NY :  ['GREEN', 'GY']
# JZZ8710PA :  ['BLUE', 'BLACK']
# GXW9299NY :  ['GRAY', 'GY']
# GPE2030NY :  ['GRAY', 'GY']
# GYX1134NY :  ['WHITE', 'WH']
# GXS8401NY :  ['GY', 'GREY']
# HFD3986NY :  ['SILVR', 'GY']
# GDL6807NY :  ['BLK', 'BLACK', 'BK']
# GXZ4513NY :  ['BK', 'BLK']
# GCW3757NY :  ['BLK', 'BK']
# GMB7531NY :  ['GY', 'SILVE']
# HAP6865NY :  ['GY', 'SILVE']
# GVP8719NY :  ['SILVR', 'GY']
# GXT4196NY :  ['BLACK', 'BK']
# HAL2045NY :  ['SILVE', 'GY']
# HDD4293NY :  ['GRY', 'GY']
# GEB9619NY :  ['GREY', 'GY']
# GZK1157NY :  ['BLUE', 'GY']
# GXE6421NY :  ['GRAY', 'WHITE', 'SILVE']
# HAL5932NY :  ['BLACK', 'BK']
# HDK3763NY :  ['GY', 'LTG']
# GHM3335NY :  ['BL', 'GRY', 'GY']
# GBV2247NY :  ['WHITE', 'WH']
# NYMATERNY :  ['SILVE', 'GY']
# GRV1494NY :  ['GRV', 'GY']
# GNW4020NY :  ['WHITE', 'WH']
# GNP4911NY :  ['WHT', 'WH']
# GLC2914NY :  ['BK', 'BLK']
# HDZ7196NY :  ['BLUE', 'BL']
# HBB2194NY :  ['BLK', 'BK']
# GXG3353NY :  ['BLK', 'BK']
# GZC6703NY :  ['BLK', 'BK']
# JYK1009PA :  ['BL', 'BLACK']
# GWG3190NY :  ['WHT', 'WH']
# GTJ5287NY :  ['WHT', 'WH']
# GKC4184NY :  ['BLK', 'BK']
# GPD6755NY :  ['WHT', 'WH']
# GCF3046NY :  ['BLK', 'BK']
# HFA9615NY :  ['GY', 'GREY']
# GNT2054NY :  ['BK', 'BLK']
# GEY7371NY :  ['WHT', 'WHITE', 'WH']
# GHT9577NY :  ['BLK', 'BK']
# HEA4216NY :  ['BLK', 'BK']
# HAW9602NY :  ['GRAY', 'GY']
# GZY2239NY :  ['SILVR', 'GY']
# GZP3594NY :  ['BLK', 'BLACK']
# GZX3869NY :  ['BLK', 'BK']
# GFD4030NY :  ['WH', 'WHITE']
# GVG1187NY :  ['WH', 'WHITE']
# GLK2194NY :  ['BLK', 'BK']
# GAR7214NY :  ['RED', 'RD']
# GZR5646NY :  ['RED', 'MR']
# GTT2435NY :  ['RED', 'RD']
# GUE7113NY :  ['GREY', 'GY']
# HAM9708NY :  ['WTR', 'WH']
# GKX8182NY :  ['GREEB', 'GR']
# GMB9512NY :  ['BLK', 'BK']
# HAM2263NY :  ['SILVE', 'GY']
# GUE7777NY :  ['TAN', 'GY']
# JRN3166PA :  ['BLU', 'BLUE']
# GLA8157NY :  ['BLACK', 'BK']
# HBS5559NY :  ['WHITE', 'WH']
# GZC5658NY :  ['TAN', 'TN']
# T684832CNY :  ['BLACK', 'BK']
# GGRF04FL :  ['BLUE', 'BLU']
# GBC2901NY :  ['WHT', 'WH']
# HEW5433NY :  ['WHITE', 'WH']
# GVK4278NY :  ['SLV', 'GY']
# HCC3161NY :  ['BLK', 'BK']
# HDS3825NY :  ['BLK', 'BK']
# GXA8758NY :  ['BLK', 'WH']
# GXG5328NY :  ['BLK', 'BK']
# T24EJANJ :  ['BL', 'BLUE']
# HAS1849NY :  ['BLACK', 'BK']
# GZC4821NY :  ['BLUE', 'BL']
# GVR2633NY :  ['GY', 'GL', 'TN']
# GTB1805NY :  ['GR', 'GY']
# GXD7684NY :  ['TAN', 'TN']
# HCD2833NY :  ['GRAY', 'BL']
# GXN8518NY :  ['TN', 'GY']
# GVD4705NY :  ['BLK', 'BK']
# GHV1166NY :  ['WHITE', 'WH']
# GUK1911NY :  ['PURPL', 'PR']
# HAM6377NY :  ['GY', 'BK']
# GVT4592NY :  ['GY', 'GR']
# GRC2446NY :  ['BLACK', 'BK']
# GHL2955NY :  ['G', 'GR', 'GREY']
# GTT1185NY :  ['GOLD', 'TN']
# GMS1160NY :  ['BLACK', 'BK']
# HDU9151NY :  ['BLK', 'BK']
# HBX4579NY :  ['BLK', 'BK']
# GAB6317NY :  ['TAN', 'GL']
# GMT7804NY :  ['GREY', 'GRY']
# HEX7602NY :  ['BLK', 'BK']
# GDE3994NY :  ['BLK', 'GREY', 'GY']
# GMR7669NY :  ['BLUE', 'BLACK']
# GST2253NY :  ['SILVE', 'GY']
# GKZ8545NY :  ['SILVE', 'SILVR']
# HEB2730NY :  ['WHITE', 'WH']
# HCT1520NY :  ['BLU', 'BLACK', 'BLK', 'BK']
# GPF2755NY :  ['RED', 'MR']
# K31FMWNJ :  ['WHITE', 'WT']
# GUV9295NY :  ['TAN', 'TN']
# GUX8881NY :  ['BLACK', 'BR']
# HAV1175NY :  ['BLUE', 'BL']
# GXG5160NY :  ['BLK', 'BK']
# T644288CNY :  ['GRN', 'GR']
# HCC9701NY :  ['BLUE', 'BL']
# GJB7343NY :  ['WHITE', 'WH']
# GGL9817NY :  ['WHITE', 'WH']
# GFM5737NY :  ['BLACK', 'BK']
# GTX2064NY :  ['WHITE', 'WH']
# GLL9643NY :  ['BLACK', 'GR']
# GST6091NY :  ['RED', 'BURGU']
# GRS8388NY :  ['GRAY', 'GY', 'SILVE']
# GWD7125NY :  ['SILVR', 'GY']
# GUG8729NY :  ['BLACK', 'BK']
# HAW5289NY :  ['GREY', 'GY']
# HES2866NY :  ['WHITE', 'WH']
# HBX1151NY :  ['TAN', 'GY']
# T686724CNY :  ['WHITE', 'WH']
# HBN7357NY :  ['BLK', 'BK']
# GPL2576NY :  ['WHITE', 'WH']
# JDM3791PA :  ['GRAY', 'GREY', 'SILVE']
# GZT8408NY :  ['ORANG', 'OR', 'SILVE']
# HBN5060NY :  ['RED', 'RD']
# HES4945NY :  ['BLACK', 'BK', 'BLK']
# T603126CNY :  ['BLK', 'BK']
# GVG9799NY :  ['BLK', 'BLUE']
# HES4877NY :  ['BLUE', 'BL']
# HBN1106NY :  ['GREY', 'GY']
# GYU8385NY :  ['WHITE', 'WH']
# GHW1242NY :  ['GRAY', 'GREY', 'GY']
# KLEEN16NY :  ['WHITE', 'WH']
# T654048CNY :  ['BLK', 'BK']
# KDF424SC :  ['SILVR', 'BLACK']
# HCF6711NY :  ['GREY', 'GY']
# S21ESRNJ :  ['GREY', 'OTHER', 'BLUE']
# ...
# Z83FWZNJ :  ['WHITE', 'WT']
# VAP1855VA :  ['GREEN', 'GRN']
# 19020MGNY :  ['GREY', 'GY']
# 70612MDNY :  ['WH', 'WHITE']
# 26387MENY :  ['WHITE', 'WH']
# AN178TNJ :  ['TAN', 'YELLO']
# CMIS85FL :  ['WHITE', 'WHI']
# 235DLZMN :  ['SILVE', 'GRY/G']
# 31365MGNY :  ['OTHER', 'GREEN']
# AN758RNJ :  ['YELLO', 'WHITE']
# FTB9265NY :  ['WH', 'WHITE']
# 7595BBDVA :  ['BLACK', 'BLK']
# FSV1588NY :  ['GREY', 'WH']
# B14ECYNJ :  ['WHITE', 'WT']
# EPL5295PA :  ['PURPL', 'BLUE']
# 89964JVNY :  ['WHITE', 'OTHER']
# A76CFTNJ :  ['GREY', 'GY']
# DYN6778NY :  ['GREY', 'GY']
# VAB1103VA :  ['GREEN', 'TEA']
# 66119JRNY :  ['GREEN', 'WH']
# FEX9698NY :  ['BLACK', 'BK']
# Y95FCFNJ :  ['SILVE', 'GY']
# XCG6541VA :  ['GREY', 'SIL']
# EYB1043NY :  ['BLACK', 'BK']
# EGA4801NY :  ['WHITE', 'WH']
# EVVN89FL :  ['GREY', 'GRY']
# VGZ7038VA :  ['GREY', 'GRY']
# 71607JXNY :  ['WH', 'WHITE']
# EIWT49FL :  ['BLACK', 'BLK']
# AXK8916NY :  ['BLACK', 'BK']
# 19465MBNY :  ['GREY', 'GR']
# 61039MBNY :  ['WHITE', 'WH']
# EMZ8650NY :  ['GY', 'SILVE']
# FXT9609NY :  ['RED', 'RD']
# 1G93BNY :  ['YELLO', 'YW']
# AJW9016WA :  ['TAN', 'GOLD']
# 646KEDMN :  ['BLACK', 'BLK/B']
# 26206JRNY :  ['WH', 'WHITE']
# DWW2498NY :  ['GR', 'GREEN']
# 289AIPIN :  ['BLACK', 'BLK']
# EPJ3382NY :  ['WHITE', 'WH']
# 88977MCNY :  ['WH', 'WHITE']
# 51413MHNY :  ['BK', 'BLACK']
# 21531MANY :  ['WH', 'WHITE']
# ECM7117NY :  ['BLACK', 'BK']
# BZV9682GA :  ['GREY', 'SILVE']
# 90188JZNY :  ['WHITE', 'WH']
# XW682SNJ :  ['BLACK', 'BK']
# EVF1195NY :  ['OTHER', 'BR']
# DB9M173TX :  ['GREY', 'GREEN']
# CP6Z059TX :  ['TAN', 'GOLD']
# 19876NY :  ['RED', 'RD']
# 34154MHNY :  ['ORW', 'ORWH']
# 6ADPB7CT :  ['BLACK', 'BLK']
# DPB8860NY :  ['BK', 'BLACK']
# C71FAXNJ :  ['SILVE', 'GREY']
# ETHQ83FL :  ['WHITE', 'WHI']
# FCW8874NY :  ['GY', 'GREY']
# Z53EBPNJ :  ['GREY', 'SILVE']
# A35DXHNJ :  ['BLACK', 'BK']
# B18FLDNJ :  ['BLACK', 'BK']
# FYW8166NY :  ['BLACK', 'BK']
# 11441JYNY :  ['WHITE', 'OTHER']
# 30712JXNY :  ['WH', 'WHITE', 'GREEN']
# U89ASVNJ :  ['SILVE', 'SIL']
# CLSB33FL :  ['GREY', 'GRY']
# 85335MANY :  ['WH', 'OTHER']
# 38149KANY :  ['WH', 'WHITE']
# 31882AUNY :  ['GR', 'GREEN']
# FPH2334NY :  ['GREY', 'GY']
# 33226MBNY :  ['WHITE', 'WH']
# DDC3938NY :  ['GREY', 'GR']
# 3AAVH6CT :  ['GREEN', 'GRN']
# 711742NNJ :  ['OTHER', 'GREY']
# AH981LNJ :  ['SILVE', 'WHITE']
# XDMK71NJ :  ['WHITE', 'BLACK']
# 45009MGNY :  ['BLACK', 'OTHER']
# 579700NY :  ['GOLD', 'GY']
# FFZ3742NY :  ['GR', 'GREEN']
# 41639JXNY :  ['WHITE', 'WH']
# 33616MGNY :  ['RD', 'RED']
# FEB8544NY :  ['RED', 'RD']
# EGF6198NY :  ['GREY', 'GY']
# EFF7944NY :  ['BLACK', 'BK']
# DNJ6EFL :  ['SILVE', 'GREY']
# W89CMXNJ :  ['OTHER', 'GREY']
# 390WTDWI :  ['BLACK', 'BK']
# EKR1766NY :  ['BLUE', 'BL']
# 3BR8625MD :  ['BLUE', 'OTHER']
# DGK8286NY :  ['SILVE', 'GY']
# 6086UWNJ :  ['GREEN', 'GN']
# EVW8137NY :  ['WH', 'WHGY']
# D84GBZNJ :  ['BLACK', 'BK']
# 58640JZNY :  ['WH', 'WHITE']
# 21712KANY :  ['WH', 'WHITE']
# 85142JUNY :  ['OTHER', 'WHITE']
# BSD6315NY :  ['BLACK', 'BK']
# BDR1564NY :  ['GY', 'SILVE']
# FWT7146NY :  ['WHITE', 'WH']
# EZE9710OH :  ['BLACK', 'GREY']
# DZY8498NY :  ['GREY', 'GR']
# BMH4589NC :  ['SILVE', 'GREY']
# Y94FMJNJ :  ['OTHER', 'BG']
# FAN3928NY :  ['GY', 'WHITE']
# FHC3236NY :  ['BK', 'BLACK']
# DK931YNY :  ['BLACK', 'BK']
# XBVP13NJ :  ['SILVE', 'SL']
# FYX2275NY :  ['GY', 'SILVE']
# 84070JZNY :  ['WH', 'WHITE']
# 2CE850MN :  ['BROWN', 'MAR/M']
# FHR1611NY :  ['BLACK', 'BK']
# 27272MDNY :  ['WH', 'BLACK']
# 11242MHNY :  ['WHITE', 'WH']
# 9F63HNY :  ['YELLO', 'YW']
# Y67FJCNJ :  ['GREY', 'BLUE']
# VCV8625VA :  ['WHITE', 'WHI']
# AGM2199NY :  ['WHITE', 'WH']
# DDC34FL :  ['BLUE', 'BLU']
# 25336MANY :  ['WHITE', 'WH']
# F21EPRNJ :  ['WHITE', 'WT']
# EDM4438NY :  ['RD', 'RED']
# 252HAEIN :  ['BLACK', 'BLK']
# 93843MDNY :  ['WHITE', 'WH']
# E98FXLNJ :  ['SILVE', 'SL']
# B587401ME :  ['BLUE', 'GREEN']
# 98271MDNY :  ['WH', 'WHITE']
# Z26GCPNJ :  ['WHITE', 'WT']
# 56728KANY :  ['WHITE', 'WH']
# FDX9182NY :  ['WH', 'WHITE']
# CVJN73FL :  ['BLACK', 'BLK']
# DFH5134NY :  ['BK', 'BLACK']
# 722VANFL :  ['SILVE', 'SIL']
# 23229MDNY :  ['WHITE', 'WH']
# EWS5987NY :  ['GREY', 'GY']
# C25FSGNJ :  ['WHITE', 'WT']
# 244WMFCT :  ['BLACK', 'BLK']
# 95336MDNY :  ['WH', 'WHITE']
# 61258MCNY :  ['WHITE', 'WH']
# 3AFHW9CT :  ['GREY', 'GRY']
# 33882MCNY :  ['RED', 'RD']
# 25514LVNY :  ['WHITE', 'WH']
# XT673VNJ :  ['BLACK', 'BK']
# 91828MHNY :  ['BLW', 'BLWH']
# C67GKJNJ :  ['TAN', 'SL']
# EEH6527NY :  ['BLUE', 'BL']
# W35DEWNJ :  ['SILVE', 'SL']
# FJG9317NY :  ['GREY', 'GY']
# CSRZ57FL :  ['BLACK', 'BLK']
# 409NCKTX :  ['OTHER', 'BLUE']
# ETC5596NY :  ['BLACK', 'BK']
# AB50475CT :  ['OTHER', 'BLACK']
# WSF9151VA :  ['OTHER', 'GREY']
# 22473MBNY :  ['WHITE', 'WH']
# DZJ1486NY :  ['SILVE', 'GY']
# 27818MENY :  ['RD/', 'RED']
# 31829TRNY :  ['BLUE', 'BL']
# 66981MENY :  ['RED', 'RD']
# 2L76BNY :  ['YELLO', 'YW']
# 19957MHNY :  ['WH', 'WHITE']
# AYV5091NY :  ['SILVE', 'GY']
# BEP3083NY :  ['SILVE', 'GY']
# WF98ZTGA :  ['BLACK', 'BLK']
# VKA9745VA :  ['WHITE', 'WHI']
# 3AEKN7CT :  ['GREEN', 'BLU']
# BLNIEVENY :  ['WHITE', 'WH']
# EXT5203NY :  ['GREEN', 'GR']
# AA91870CT :  ['BLACK', 'BLK']
# 3ALEF5CT :  ['BLACK', 'BROWN']
# 21483MGNY :  ['WHITE', 'WHBL']
# 21410MENY :  ['WHITE', 'WH']
# EBG6930NY :  ['BR', 'OTHER']
# 565RH5MA :  ['SILVE', 'OTHER']
# 39037JVNY :  ['WH', 'WHITE']
# XBVT95NJ :  ['WHITE', 'WT']
# A89FMJNJ :  ['GOLD', 'TAN']
# FWF9141NY :  ['DK/', 'DKGY']
# 75433JDNY :  ['DK/', 'DKBL']
# ESM4067NY :  ['BLACK', 'BK']
# 68027MHNY :  ['WH', 'WHITE']
# 26436JVNY :  ['WHITE', 'WH']
# FR5942NC :  ['SILVE', 'GREY']
# 42929MHNY :  ['BL', 'BLUE']
# APF9357GA :  ['GREY', 'GRY']
# 7140UWNJ :  ['GREY', 'GY']
# B92EUPNJ :  ['GREY', 'SL']
# 66940JKNY :  ['GY', 'GREY']
# CQDY74FL :  ['WHITE', 'WHI']
# DY8916DC :  ['GREY', 'BLUE']
# FZB1673NY :  ['BK', 'BLACK']
# 51127MCNY :  ['WHITE', 'WH']
# 55491JZNY :  ['WH', 'WHITE']
# XCMU28NJ :  ['WHITE', 'WT']
# XU584UNJ :  ['WHITE', 'WHT']
# CAH5736NY :  ['BLACK', 'BK']
# ETL6220NY :  ['GREY', 'GY']
# U98CLWNJ :  ['GREY', 'GY']
# A68FJPNJ :  ['BLACK', 'BK']
# CGV072IA :  ['SILVE', 'GREY']
# B9752VTN :  ['OTHER', 'GREY']
# 648LXRIN :  ['GREY', 'BLUE']
# E39ERMNJ :  ['BLUE', 'BL']
# B55GABNJ :  ['BLACK', 'SILVE']
# 34517JRNY :  ['WH', 'WHITE']
# E36FWJNJ :  ['WHITE', 'WH']
# DGB2635NY :  ['GREY', 'GY']
# ETM2317NY :  ['BLACK', 'GY']
# C33GBZNJ :  ['GREY', 'GY']
# 2879URME :  ['BLACK', 'GREY']
# 10094JCNY :  ['BLACK', 'BL']
# EQZL99FL :  ['BLUE', 'BLU']
# 1741126ME :  ['BLACK', 'BLK']
# FFM2280NY :  ['GREY', 'BK']
# BYSV683ON :  ['GREY', 'SILVE']
# A92FFTNJ :  ['BLACK', 'BLK']
# FWJ3340NY :  ['BLACK', 'BK']
# AA37000CT :  ['OTHER', 'SILVE']
# COOP83NY :  ['OTHER', 'BK']
# FXY2996NY :  ['WHITE', 'WH']
# WPW12ENJ :  ['OTHER', 'BLUE']
# FTH6068NY :  ['SILVE', 'GY']
# ADM3665NY :  ['BLACK', 'BK']
# 5ASAN7CT :  ['GREY', 'GRY']
# 33623MGNY :  ['WHITE', 'WH']
# ETK2450NY :  ['SILVE', 'GY']
# ERIJ59FL :  ['GREY', 'SIL']
# DGB6219NY :  ['BLACK', 'GY']
# BPG5785GA :  ['GREY', 'UNK']
# 45411MGNY :  ['WH', 'WHT']
# AGK1990NY :  ['GREY', 'GY']
# 96197JTNY :  ['WHITE', 'WH']
# BN01937PA :  ['OTHER', 'TAN']
# 89219MGNY :  ['SILVE', 'GY']
# 97593JWNY :  ['GREY', 'GY']
# 52629MBNY :  ['WHITE', 'WH']
# ECN9138NY :  ['SILVE', 'GY']
# 68485PANY :  ['WHITE', 'WH']
# BS768BNY :  ['BLACK', 'BK']
# 23333MDNY :  ['BLUE', 'BL']
# WMV4479VA :  ['GREY', 'SILVE']
# XX131VNJ :  ['GREEN', 'BLUE']
# 83177MGNY :  ['BLACK', 'BK']
# EVW1615NY :  ['GREY', 'GY']
# FPY8091NY :  ['BLUE', 'BK']
# 35247BBNY :  ['BLACK', 'BK']
# CCGF41FL :  ['WHITE', 'WHI']
# 5ATPV5CT :  ['WHITE', 'WHI']
# 14541MBNY :  ['WHITE', 'WH']
# A15EWXNJ :  ['GREY', 'SL']
# BN01903PA :  ['YELLO', 'GOLD']
# FEA3585NY :  ['WHITE', 'WH']
# 13082MJNY :  ['RD', 'RED']
# AHT6671NY :  ['BLUE', 'BL']
# 2682211PA :  ['OTHER', 'GREY']
# 43239MENY :  ['WHITE', 'WH']
# EWZ5303NY :  ['WH', 'GY']
# W35EGKNJ :  ['WHITE', 'BK']
# FEN2835NY :  ['SILVE', 'GY']
# 15130MCNY :  ['WH', 'WHITE']
# 35596JMNY :  ['BLACK', 'DKGY']
# EMGQ82FL :  ['GREY', 'BLK']
# Y34DRENJ :  ['BLACK', 'BK']
# FPB4400NY :  ['BLACK', 'BK']
# X13DYJNJ :  ['OTHER', 'WT']
# 66766MENY :  ['WHITE', 'WH']
# ZCY8564PA :  ['BLACK', 'BLUE']
# 64945JTNY :  ['BLACK', 'BK']
# XAVJ52NJ :  ['WHITE', 'WT']
# DWM7245NY :  ['SILVE', 'GY']
# CJZ8690NY :  ['BLACK', 'BK']
# 51527MGNY :  ['WH', 'WT']
# 92030MGNY :  ['WHITE', 'WH']
# 95003JSNY :  ['WHITE', 'WH']
# FYK4940NY :  ['GREEN', 'GR']
# WLY6455VA :  ['GREY', 'SIL']
# EJS6519NY :  ['RED', 'RD']
# VJU1525VA :  ['BLACK', 'BLU']
# EWM3771NY :  ['SILVE', 'GY']
# 92926MA :  ['BLACK', 'GREY']
# 6422BQFL :  ['GREEN', 'GRN']
# FFM7323NY :  ['WHITE', 'WH']
# 4H66ANY :  ['YELLO', 'YW']
# 37672MHNY :  ['WHITE', 'WH']
# 53899MCNY :  ['WHITE', 'WH']
# VFX9894VA :  ['WHITE', 'WHI']
# U8629DTN :  ['BLACK', 'BLK']
# XCLZ80NJ :  ['WHITE', 'WH']
# 21372MGNY :  ['WHITE', 'WH']
# XCRJ17NJ :  ['WHITE', 'WH']
# CKU9217NY :  ['BK', 'BLACK']
# 14611MENY :  ['WHITE', 'WH']
# FXC1597NY :  ['BLACK', 'BK']
# 67013JTNY :  ['WHITE', 'WH']
# FFV1404NY :  ['BLUE', 'BL']
# 2D41BNY :  ['YELLO', 'YW']
# CSNYCNY :  ['WH', 'BLACK']
# 9V33HNY :  ['YELLO', 'YW']
# XY916HNJ :  ['WHITE', 'WT']
# 185ZNSCT :  ['WHITE', 'WHI']
# D74CBFNJ :  ['BLACK', 'BK']
# 36837MGNY :  ['BL', 'BLUE']
# FYW4773NY :  ['BLACK', 'BK']
# FEJ1838NY :  ['BLACK', 'BK']
# BFQY85FL :  ['BLUE', 'BLU']
# EVD2528NY :  ['BK', 'BKGY']
# ESF5618NY :  ['BLACK', 'BKBL']
# DUC8770NY :  ['WHITE', 'WH']
# Y16FPKNJ :  ['GREY', 'GY']
# FAP8615NY :  ['BLUE', 'BL']
# XU892WNJ :  ['YELLO', 'WT']
# CZX1150NY :  ['BLACK', 'BK']
# F96DSSNJ :  ['WHITE', 'WT']
# CVST07FL :  ['WHITE', 'WHI']
# EWD4865NY :  ['GREY', 'GY']
# EEY5506NY :  ['SILVE', 'WH']
# CXDS59FL :  ['BLACK', 'BLK']
# FDJ8817NY :  ['DKB', 'DKBL']
# FPH9547NY :  ['BLACK', 'BK']
# CVH1380NY :  ['BLACK', 'BK']
# 2074200ME :  ['BROWN', 'RED']
# DBR8580NY :  ['GR', 'GREY']
# 73513MDNY :  ['BLACK', 'BK']
# FJK5959NY :  ['GREY', 'GY']
# ESB3378NY :  ['GY', 'BLUE']
# FPV1376NY :  ['WH', 'WHITE']
# FWG6108NY :  ['BLACK', 'BK']
# EYB6929NY :  ['BLACK', 'BK']
# FGY5203NY :  ['WHITE', 'WH']
# U10BRJNJ :  ['BLACK', 'BK']
# EPZ6833NY :  ['SILVE', 'GY']
# FTG5514NY :  ['BL', 'BLACK']
# CWQC70FL :  ['WHITE', 'WHI']
# FGP3946NY :  ['SILVE', 'GY']
# ETA8046NY :  ['SILVE', 'GY']
# CUVQ47FL :  ['OTHER', 'SIL']
# 48474JWNY :  ['BLUE', 'BL']
# AC63645CT :  ['BLACK', 'GRY']
# 8MAKNY :  ['GREY', 'GY']
# U177275TN :  ['BROWN', 'RED']
# EGKU56FL :  ['GREY', 'BRO']
# 95079JANY :  ['WHITE', 'WH']
# 160XRECT :  ['BLUE', 'GRY']
# 97647JSNY :  ['WHITE', 'WH']
# V47DGGNJ :  ['BLACK', 'BK']
# E93FAJNJ :  ['BLUE', 'BK']
# X72FPDNJ :  ['TAN', 'BG']
# CRXY31FL :  ['BLACK', 'BLK']
# EZRZ31FL :  ['BLACK', 'BLK']
# 380AZKNV :  ['GREY', 'GRAY']
# VMT3894VA :  ['SILVE', 'GREY']
# DME4100NY :  ['TN', 'TAN']
# WWN8345VA :  ['GREY', 'GRY']
# FWL8077NY :  ['SILVE', 'GY']
# XDJH50NJ :  ['WHITE', 'WT']
# 35509MDNY :  ['WHITE', 'WH']
# B29EDGNJ :  ['BLACK', 'BK']
# EYG1145NY :  ['WHITE', 'WH']
# 2C87KNY :  ['YELLO', 'YW']
# C39FTFNJ :  ['WHITE', 'WT']
# DDZ5811NY :  ['SILVE', 'GY']
# W16GJUNJ :  ['GREEN', 'GN']
# BAJ9733NY :  ['GY', 'GOLD']
# A14CCWNJ :  ['GREY', 'SILVE']
# ATJ3549NY :  ['BK', 'BLACK']
# 5E71BNY :  ['YELLO', 'YW']
# CML7511NC :  ['SILVE', 'GREY']
# E74DESNJ :  ['GREY', 'SL']
# 26206JYNY :  ['SILVE', 'GY']
# 48102JXNY :  ['GREY', 'GY']
# ETL3824NY :  ['RED', 'RD']
# BZC7505NY :  ['GREY', 'GR']
# 40087JUNY :  ['WHITE', 'WH']
# EHCM76FL :  ['BLACK', 'BLK']
# BNP2177NY :  ['WHITE', 'WHGY']
# FFG7471NY :  ['BK', 'GREEN']
# CRBB91FL :  ['WHITE', 'WHI']
# CSEV95FL :  ['WHITE', 'WHI']
# 35385MCNY :  ['YELLO', 'YW']
# FXV8163NY :  ['RED', 'RD']
# BIKR83FL :  ['PURPL', 'PLE']
# DHW9166NY :  ['BLACK', 'BK']
# DZAJ62FL :  ['BLACK', 'BLK']
# EPC5968NY :  ['BLUE', 'BL']
# FRH4142NY :  ['WHITE', 'WH']
# END7105NY :  ['BLACK', 'BK']
# DKML99FL :  ['GREY', 'GRY']
# BRLC29FL :  ['WHITE', 'WHI']
# DGX5874NY :  ['WHITE', 'WH']
# ESK6320NY :  ['BLACK', 'BK']
# FZM4973NY :  ['BL', 'BLUE']
# VUB71KNJ :  ['BLUE', 'GY']
# 124125NH :  ['SILVE', 'GREY']
# FHW5709NY :  ['BLACK', 'BK']
# 271WOYCT :  ['WHITE', 'WHI']
# ANZ2787NY :  ['GREY', 'GY']
# FAK1771NY :  ['GY', 'GYGY']
# 2349TUVA :  ['GREY', 'GRY']
# 972TPGFL :  ['BLACK', 'BLK']
# Z669582IL :  ['OTHER', 'GREY']
# BEU7054NY :  ['GREY', 'DKGY']
# FSV3551NY :  ['RED', 'RD']
# BXJ8430NY :  ['SILVE', 'GY']
# DGP2355NY :  ['GREY', 'GR']
# 525RCPMN :  ['WHITE', 'WHT/W']
# V44FJMNJ :  ['SILVE', 'SL']
# 92561MGNY :  ['WHITE', 'WH']
# 21271BBNY :  ['YELLO', 'YW']
# FBC5263NY :  ['BK', 'GREY']
# FHW7545NY :  ['GREY', 'GY']
# UFS90YNJ :  ['GREEN', 'GR']
# 86620PANY :  ['WHITE', 'WH']
# 8AKWP8CT :  ['WHITE', 'WHI']
# ECR1340NY :  ['GREY', 'WH']
# CAJ5222NY :  ['BLACK', 'GY']
# FZM7538NY :  ['RED', 'RD']
# 27229MDNY :  ['WHITE', 'WH']
# 89851MGNY :  ['WHITE', 'WH']
# EAZD06FL :  ['OTHER', 'SIL']
# X28FKNNJ :  ['GREY', 'GY']
# 1060EMTNY :  ['DK/', 'DKGY']
# FBX6887NY :  ['RD', 'RED']
# XAGT54NJ :  ['WHITE', 'WH']
# DVN2691NY :  ['BLUE', 'BL']
# F93BTHNJ :  ['GREEN', 'GN']
# 71466JKNY :  ['WHITE', 'WH']
# 94664MCNY :  ['WH', 'WHITE']
# WYB54DNJ :  ['GREY', 'GY']
# 71SJ27NY :  ['GREY', 'GY']
# XDTA24NJ :  ['WHITE', 'WHT']
# FAF2329NY :  ['BK', 'BKGY']
# CNM7140NY :  ['GY', 'GREY']
# Y70CDZNJ :  ['RED', 'RD']
# FZV3103NY :  ['WHITE', 'WH']
# CDL9935NY :  ['WHITE', 'WH']
# B41FNFNJ :  ['WHITE', 'WT']
# DZZ2163NY :  ['GREY', 'GY']
# CZT3679NY :  ['BLACK', 'BL']
# FSB8664NY :  ['GY', 'SL']
# ETX8242NY :  ['DK/', 'DKBL']
# DND3969NY :  ['LT/', 'LTGY']
# XBF1975VA :  ['SILVE', 'GRY']
# 55350JXNY :  ['BLUE', 'BL']
# HDT4596NY :  ['SILVE', 'GY']
# GVK5322NY :  ['RED', 'RD']
# GXX3569NY :  ['BLACK', 'BK']
# HDV5329NY :  ['BLUE', 'BL']
# J64GJTNJ :  ['BLUE', 'GY']
# GUH4377NY :  ['WHITE', 'WH']
# HDV5852NY :  ['BLUE', 'BL']
# GZM7677NY :  ['GREY', 'GY']
# GZK1252NY :  ['GT', 'GY']
# HAA8178NY :  ['GY', 'BL']
# GKE6491NY :  ['GREY', 'BR']
# GMJ5624NY :  ['GREY', 'GY']
# GZT4252NY :  ['BLUE', 'GR']
# GHS1381NY :  ['WHITE', 'WH']
# HDV2017NY :  ['GRAY', 'GY']
# HDT4638NY :  ['BLK', 'BK']
# GGS7511NY :  ['GRY', 'GY']
# HBB3285NY :  ['BLACK', 'BL']
# GSL3273NY :  ['BROWN', 'BR']
# GTP2985NY :  ['BLACK', 'BK']
# T686210CNY :  ['BLK', 'BK']
# HDV4154NY :  ['BLUE', 'BL']
# HAX7961NY :  ['GRAY', 'BL']
# GYD6258NY :  ['BLACK', 'BK']
# GXS8526NY :  ['BLUE', 'BL']
# GJZ4246NY :  ['BLUE', 'BL']
# HCD8765NY :  ['BLK', 'BL']
# GKY2550NY :  ['BLACK', 'BK']
# GGF2130NY :  ['SILV', 'LTGY']
# T698885CNY :  ['BLACK', 'BK']
# K96BSKNJ :  ['BLACK', 'BK']
# HDZ7229NY :  ['GY', 'GL']
# HBB4899NY :  ['GY', 'GR']
# HAB9132NY :  ['GY', 'GRAY']
# GEEKSHOPNY :  ['WHITE', 'WH']
# GFV4029NY :  ['GY', 'BL']
# GYH3824NY :  ['BLK', 'BK']
# GNB1822NY :  ['BK', 'GY']
# GZD3379NY :  ['WH', 'WHITE']
# PNA1909GA :  ['BR', 'BLK']
# T621823CNY :  ['BLK', 'BK']
# HFB1219NY :  ['BLACK', 'BK']
# GNC1065NY :  ['GN', 'GR']
# T637934CNY :  ['WHITE', 'WH']
# GXZ9424NY :  ['BLUE', 'BL']
# GSN3858NY :  ['BLK', 'BK']
# 65323PANY :  ['BK', 'BLU']
# BG99396NY :  ['BLUE', 'BLU']
# 4AKWH6CT :  ['BLACK', 'BLK']
# 2048556TX :  ['BLK', 'BK']
# FXP2928NY :  ['BLK', 'BK']
# C462529OH :  ['WHT', 'GRAY']
# BY606UNY :  ['BLACK', 'BK']
# 7946MIVA :  ['GY', 'GRY']
# 29BY473AL :  ['TAN', 'GLD']
# D43DDBNJ :  ['WH', 'WHITE']
# DSX2477NY :  ['GREY', 'GY']
# DGX4569NY :  ['BLACK', 'BK']
# BHP2337NC :  ['BLK', 'BK']
# 2400UQME :  ['GY', 'SILVE']
# EHR1883NY :  ['WHITE', 'WH']
# DLM8114NY :  ['GRAY', 'GY']
# CYF5835NY :  ['GRAY', 'GY']
# 47391MGNY :  ['WHITE', 'WH']
# DPJ3304NY :  ['SILVE', 'GY']
# FFM3060NY :  ['BLUE', 'BL']
# 9BR6812MD :  ['GY', 'GREY']
# F14FNXNJ :  ['WHITE', 'WT']
# 448YZRCT :  ['BK', 'BLK']
# F23GCXNJ :  ['GY', 'SL']
# 52872MHNY :  ['WHITE', 'WH']
# FWG3555NY :  ['BLUE', 'BL']
# DTDK04FL :  ['WH', 'WHI']
# 21653MDNY :  ['WT', 'WH']
# XDX638IN :  ['WH', 'WHITE']
# VAJ2341VA :  ['RD', 'RED']
# 29007BBNY :  ['YL', 'YW']
# FEZ3908NY :  ['TAN', 'GY']
# FHE7202NY :  ['BLK', 'BK']
# BBJ9884NY :  ['BLUE', 'BL']
# FDN3428NY :  ['RED', 'MR']
# 28815BBNY :  ['YELLO', 'YW']
# 2731TNFL :  ['BLUE', 'DBL']
# FPZ5577NY :  ['GRAY', 'GY']
# FDV8438NY :  ['GY', 'GR']
# W975WVNY :  ['TAN', 'GYGY']
# FFP4429NY :  ['GRAY', 'GY']
# FZC8707NY :  ['WHITE', 'WH']
# GWU6654NY :  ['WHITE', 'WH']
# GKL5216NY :  ['WHITE', 'WH']
# GZH1102NY :  ['RED', 'RD']
# OMAVIC87NY :  ['GREY', 'GY']
# OYB2142NJ :  ['WHITE', 'WH']
# GEP5704NY :  ['BK', 'BL']
# GJF2252NY :  ['BK', 'GY']
# GEF7569NY :  ['MR', 'BURG']
# GGF5472NY :  ['GR', 'GY']
# GRR9582NY :  ['WH', 'GY']
# T646675CNY :  ['WH', 'GY']
# GYD6191NY :  ['GY', 'BK']
# GEC2802NY :  ['BK', 'GY']
# GDT1150NY :  ['BK', 'GY']
# GRM8083NY :  ['BL', 'BK']
# 88344MGNY :  ['YELLO', 'WH']
# 59343MDNY :  ['WHITE', 'WH']
# FHG2954NY :  ['BLACK', 'BK']
# FFS3767NY :  ['BK', 'GY']
# DDP3218NY :  ['WH', 'GY']
# BYN6874NY :  ['GLGY', 'WHGY']
# CGS8846NY :  ['GY', 'BK']
# 103NY :  ['BK', 'BL']
# DVT8704NY :  ['BL', 'GY']
# FPN7503NY :  ['GY', 'BL']
# DLM8494NY :  ['BK', 'GY']
# FAK8937NY :  ['GR', 'BL']
# EBB5012NY :  ['GY', 'GRAY']
# T693014CNY :  ['GY', 'GREY']
# GNW5129NY :  ['BLACK', 'BK']
# T678753CNY :  ['BLUE', 'BK']

# %% [markdown]
# To clean the data using functional dependency outputs, we can standarize the name of the Vehicle_Color by choosing just one denomination and removing the other ones.

# %% [markdown]
# ### 7. Entity Resolution
# Identify and merge different representations of the same entity

# %%
# Using concat_ws() function of Pypsark SQL concatenated three string input columns (firstname, middlename, lastname) into a single string column (Fullname) and separated each column with “_” separator.

# %%
# Check the columns by looking at the schema
parking_df.printSchema()
# Out:
# root
#  |-- summons_number: string (nullable = true)
#  |-- issue_date: string (nullable = true)
#  |-- violation_code: string (nullable = true)
#  |-- violation_county: string (nullable = true)
#  |-- violation_description: string (nullable = true)
#  |-- violation_location: string (nullable = true)
#  |-- violation_precinct: string (nullable = true)
#  |-- violation_time: string (nullable = true)
#  |-- time_first_observed: string (nullable = true)
#  |-- meter_number: string (nullable = true)
#  |-- issuer_code: string (nullable = true)
#  |-- issuer_command: string (nullable = true)
#  |-- issuer_precinct: string (nullable = true)
#  |-- issuing_agency: string (nullable = true)
#  |-- plate_id: string (nullable = true)
#  |-- plate_type: string (nullable = true)
#  |-- registration_state: string (nullable = true)
#  |-- street_name: string (nullable = true)
#  |-- vehicle_body_type: string (nullable = true)
#  |-- vehicle_color: string (nullable = true)
#  |-- vehicle_make: string (nullable = true)
#  |-- vehicle_year: string (nullable = true)

# %%
from pyspark.sql.functions import concat_ws,col
parking_df_er=parking_df.select(concat_ws(' ',
                                          parking_df.issue_date,
                                          parking_df.violation_code,
                                          parking_df.violation_county,
                                          parking_df.violation_time,
                                          parking_df.issuer_code,
                                          parking_df.issuer_command,
                                          parking_df.plate_id,
                                          parking_df.plate_type,
                                          parking_df.registration_state,
                                          parking_df.street_name,
                                         )
              .alias("features_parking"),"summons_number")
parking_df_er.show()
# Out:
# +--------------------+--------------+
# |    features_parking|summons_number|
# +--------------------+--------------+
# |2016-03-07 14 NY ...|    1307964308|
# |2016-03-02 98 BX ...|    1362655727|
# |2016-03-01 21 NY ...|    1363178234|
# |2016-03-02 74 K 1...|    1365797030|
# |2016-03-03 38 NY ...|    1366529595|
# |2016-03-07 20 NY ...|    1366571757|
# |2016-03-01 21 NY ...|    1363178192|
# |2016-03-12 21 BX ...|    1362906062|
# |2016-03-09 40 K 0...|    1367591351|
# |2016-03-19 20 NY ...|    1354042244|
# |2016-03-17 40 BX ...|    1359423576|
# |2016-03-19 85 BX ...|    1358746333|
# |2016-03-13 40 K 0...|    1361067974|
# |2016-03-29 40 NY ...|    1362335939|
# |2016-03-31 21 BX ...|    1362902056|
# |2016-03-16 46 K 0...|    1362963860|
# |2016-03-08 78 NY ...|    1365462523|
# |2016-03-14 19 NY ...|    1366567511|
# |2016-03-26 46 BX ...|    1366720556|
# |2016-03-20 45 NY ...|    1367171477|
# +--------------------+--------------+
# only showing top 20 rows

# %%
parking_df_sample = parking_df_er.limit(400)

# %%
parking_df_sample.show()
# Out:
# +--------------------+--------------+
# |    features_parking|summons_number|
# +--------------------+--------------+
# |2016-03-07 14 NY ...|    1307964308|
# |2016-03-02 98 BX ...|    1362655727|
# |2016-03-01 21 NY ...|    1363178234|
# |2016-03-02 74 K 1...|    1365797030|
# |2016-03-03 38 NY ...|    1366529595|
# |2016-03-07 20 NY ...|    1366571757|
# |2016-03-01 21 NY ...|    1363178192|
# |2016-03-12 21 BX ...|    1362906062|
# |2016-03-09 40 K 0...|    1367591351|
# |2016-03-19 20 NY ...|    1354042244|
# |2016-03-17 40 BX ...|    1359423576|
# |2016-03-19 85 BX ...|    1358746333|
# |2016-03-13 40 K 0...|    1361067974|
# |2016-03-29 40 NY ...|    1362335939|
# |2016-03-31 21 BX ...|    1362902056|
# |2016-03-16 46 K 0...|    1362963860|
# |2016-03-08 78 NY ...|    1365462523|
# |2016-03-14 19 NY ...|    1366567511|
# |2016-03-26 46 BX ...|    1366720556|
# |2016-03-20 45 NY ...|    1367171477|
# +--------------------+--------------+
# only showing top 20 rows

# %%
import pyspark.sql.functions as F
matrix = parking_df_sample.select(F.col('summons_number').alias('summons_number1'), F.col('features_parking').alias('features_parking1')) \
    .crossJoin(parking_df_sample.select(F.col('summons_number').alias('summons_number2'), F.col('features_parking').alias('features_parking2'))) \
    .filter(F.col('summons_number1') > F.col('summons_number2'))

# %% [markdown]
# We can use levenshtein distance to find similar entities

# %%
from pyspark.sql.functions import udf

from pyspark.sql.types import StringType, IntegerType
res = matrix.withColumn('similarity', F.levenshtein(F.col('features_parking1'), F.col('features_parking2')))

# %%
res.show(45)
# Out:
# +---------------+--------------------+---------------+--------------------+----------+
# |summons_number1|   features_parking1|summons_number2|   features_parking2|similarity|
# +---------------+--------------------+---------------+--------------------+----------+
# |     7363675041|2016-03-11 17 NY ...|     7363675028|2016-03-11 20 NY ...|        24|
# |     7363675119|2016-03-15 19 NY ...|     7363675028|2016-03-11 20 NY ...|        34|
# |     7363675119|2016-03-15 19 NY ...|     7363675041|2016-03-11 17 NY ...|        32|
# |     7363675132|2016-03-16 14 NY ...|     7363675028|2016-03-11 20 NY ...|        21|
# |     7363675132|2016-03-16 14 NY ...|     7363675041|2016-03-11 17 NY ...|        19|
# |     7363675132|2016-03-16 14 NY ...|     7363675119|2016-03-15 19 NY ...|        33|
# |     7363675156|2016-03-16 19 NY ...|     7363675028|2016-03-11 20 NY ...|        25|
# |     7363675156|2016-03-16 19 NY ...|     7363675041|2016-03-11 17 NY ...|        25|
# |     7363675156|2016-03-16 19 NY ...|     7363675119|2016-03-15 19 NY ...|        31|
# |     7363675156|2016-03-16 19 NY ...|     7363675132|2016-03-16 14 NY ...|        20|
# |     7363675170|2016-03-17 20 NY ...|     7363675028|2016-03-11 20 NY ...|        12|
# |     7363675170|2016-03-17 20 NY ...|     7363675041|2016-03-11 17 NY ...|        24|
# |     7363675170|2016-03-17 20 NY ...|     7363675119|2016-03-15 19 NY ...|        33|
# |     7363675170|2016-03-17 20 NY ...|     7363675132|2016-03-16 14 NY ...|        17|
# |     7363675170|2016-03-17 20 NY ...|     7363675156|2016-03-16 19 NY ...|        26|
# |     7363675181|2016-03-17 19 NY ...|     7363675028|2016-03-11 20 NY ...|        17|
# |     7363675181|2016-03-17 19 NY ...|     7363675041|2016-03-11 17 NY ...|        28|
# |     7363675181|2016-03-17 19 NY ...|     7363675119|2016-03-15 19 NY ...|        26|
# |     7363675181|2016-03-17 19 NY ...|     7363675132|2016-03-16 14 NY ...|        23|
# |     7363675181|2016-03-17 19 NY ...|     7363675156|2016-03-16 19 NY ...|        28|
# |     7363675181|2016-03-17 19 NY ...|     7363675170|2016-03-17 20 NY ...|        16|
# |     7363675211|2016-03-18 19 NY ...|     7363675028|2016-03-11 20 NY ...|        27|
# |     7363675211|2016-03-18 19 NY ...|     7363675041|2016-03-11 17 NY ...|        31|
# |     7363675211|2016-03-18 19 NY ...|     7363675119|2016-03-15 19 NY ...|        36|
# |     7363675211|2016-03-18 19 NY ...|     7363675132|2016-03-16 14 NY ...|        29|
# |     7363675211|2016-03-18 19 NY ...|     7363675156|2016-03-16 19 NY ...|        24|
# |     7363675211|2016-03-18 19 NY ...|     7363675170|2016-03-17 20 NY ...|        26|
# |     7363675211|2016-03-18 19 NY ...|     7363675181|2016-03-17 19 NY ...|        26|
# |     7372176610|2016-03-04 38 K 0...|     7363675028|2016-03-11 20 NY ...|        33|
# |     7372176610|2016-03-04 38 K 0...|     7363675041|2016-03-11 17 NY ...|        32|
# |     7372176610|2016-03-04 38 K 0...|     7363675119|2016-03-15 19 NY ...|        40|
# |     7372176610|2016-03-04 38 K 0...|     7363675132|2016-03-16 14 NY ...|        31|
# |     7372176610|2016-03-04 38 K 0...|     7363675156|2016-03-16 19 NY ...|        32|
# |     7372176610|2016-03-04 38 K 0...|     7363675170|2016-03-17 20 NY ...|        35|
# |     7372176610|2016-03-04 38 K 0...|     7363675181|2016-03-17 19 NY ...|        37|
# |     7372176610|2016-03-04 38 K 0...|     7363675211|2016-03-18 19 NY ...|        34|
# |     7372176610|2016-03-04 38 K 0...|     7363675235|2016-03-19 31 NY ...|        34|
# |     7372176610|2016-03-04 38 K 0...|     7363675247|2016-03-19 14 NY ...|        33|
# |     7372176610|2016-03-04 38 K 0...|     7363675259|2016-03-19 31 NY ...|        28|
# |     7372176610|2016-03-04 38 K 0...|     7363675272|2016-03-19 14 NY ...|        28|
# |     7372176610|2016-03-04 38 K 0...|     7363675284|2016-03-19 16 NY ...|        33|
# |     7372176610|2016-03-04 38 K 0...|     7363675340|2016-03-22 20 NY ...|        32|
# |     7372176610|2016-03-04 38 K 0...|     7363675375|2016-03-22 20 NY ...|        34|
# |     7372176610|2016-03-04 38 K 0...|     7363675387|2016-03-22 14 NY ...|        27|
# |     7372176610|2016-03-04 38 K 0...|     7363675399|2016-03-23 14 NY ...|        29|
# +---------------+--------------------+---------------+--------------------+----------+
# only showing top 45 rows

# %%
res.count()
# Out:
# 79800

# %%
res.orderBy('similarity', ascending=True).show(40)
# Out:
# [Stage 282:>                                                        (0 + 1) / 1]
# +---------------+--------------------+---------------+--------------------+----------+
# |summons_number1|   features_parking1|summons_number2|   features_parking2|similarity|
# +---------------+--------------------+---------------+--------------------+----------+
# |     7372179002|2016-03-11 71 K 0...|     7372178990|2016-03-11 70 K 0...|         2|
# |     7372180715|2016-03-17 71 K 0...|     7372180703|2016-03-17 74 K 0...|         2|
# |     7372177303|2016-03-07 71 K 0...|     7372177297|2016-03-07 38 K 0...|         3|
# |     7372178459|2016-03-10 38 K 0...|     7372177807|2016-03-08 38 K 0...|         3|
# |     7372179464|2016-03-11 74 K 0...|     7372179452|2016-03-11 46 K 0...|         3|
# |     7372180065|2016-03-15 71 K 0...|     7372180053|2016-03-15 20 K 0...|         3|
# |     7367298227|2016-03-04 70 NY ...|     7367298215|2016-03-04 31 NY ...|         3|
# |     7372180624|2016-03-16 70 K 0...|     7372180612|2016-03-16 38 K 0...|         3|
# |     7372178903|2016-03-10 71 K 0...|     7372178897|2016-03-10 46 K 0...|         3|
# |     7366872131|2016-03-23 75 NY ...|     7366872120|2016-03-23 40 NY ...|         4|
# |     7372177110|2016-03-05 19 K 0...|     7372177108|2016-03-05 19 K 0...|         5|
# |     7372176980|2016-03-05 19 K 0...|     7372176967|2016-03-05 19 K 0...|         5|
# |     7372177054|2016-03-05 19 K 0...|     7372176967|2016-03-05 19 K 0...|         6|
# |     7372179373|2016-03-11 38 K 0...|     7372179361|2016-03-11 38 K 0...|         6|
# |     7372180727|2016-03-17 21 K 0...|     7372180715|2016-03-17 71 K 0...|         6|
# |     7372177054|2016-03-05 19 K 0...|     7372176980|2016-03-05 19 K 0...|         6|
# |     7372177870|2016-03-08 38 K 0...|     7372177868|2016-03-08 38 K 0...|         6|
# |     7372178988|2016-03-11 38 K 0...|     7372178976|2016-03-11 38 K 0...|         6|
# |     7372179830|2016-03-15 21 K 0...|     7372179816|2016-03-15 21 K 0...|         6|
# |     7372180016|2016-03-15 46 K 0...|     7372180004|2016-03-15 16 K 0...|         6|
# |     7372177250|2016-03-07 38 K 0...|     7372177248|2016-03-07 38 K 0...|         6|
# |     7372177807|2016-03-08 38 K 0...|     7372177790|2016-03-08 38 K 0...|         6|
# |     7372178423|2016-03-09 38 K 0...|     7372178400|2016-03-09 38 K 0...|         6|
# |     7372178800|2016-03-10 20 K 0...|     7372178654|2016-03-10 20 K 0...|         6|
# |     7372179180|2016-03-11 37 K 0...|     7372176633|2016-03-04 38 K 0...|         6|
# |     7372176785|2016-03-04 38 K 0...|     7372176773|2016-03-04 38 K 0...|         7|
# |     7372177030|2016-03-05 19 K 0...|     7372176992|2016-03-05 19 K 0...|         7|
# |     7372176797|2016-03-04 38 K 0...|     7372176785|2016-03-04 38 K 0...|         7|
# |     7372177108|2016-03-05 19 K 0...|     7372177054|2016-03-05 19 K 0...|         7|
# |     7372178861|2016-03-10 38 K 0...|     7372178850|2016-03-10 38 K 0...|         7|
# |     7372176992|2016-03-05 19 K 0...|     7372176967|2016-03-05 19 K 0...|         7|
# |     7372177133|2016-03-05 19 K 0...|     7372176980|2016-03-05 19 K 0...|         7|
# |     7372177133|2016-03-05 19 K 0...|     7372177110|2016-03-05 19 K 0...|         7|
# |     7372179622|2016-03-14 20 K 0...|     7372179518|2016-03-14 20 K 0...|         7|
# |     7372176992|2016-03-05 19 K 0...|     7372176980|2016-03-05 19 K 0...|         7|
# |     7372177005|2016-03-05 19 K 0...|     7372176943|2016-03-05 19 K 0...|         7|
# |     7372177133|2016-03-05 19 K 0...|     7372177108|2016-03-05 19 K 0...|         7|
# |     7372177534|2016-03-07 38 K 0...|     7372177522|2016-03-07 38 K 0...|         7|
# |     7372177777|2016-03-07 38 K 0...|     7372177534|2016-03-07 38 K 0...|         7|
# |     7372177030|2016-03-05 19 K 0...|     7372176980|2016-03-05 19 K 0...|         7|
# +---------------+--------------------+---------------+--------------------+----------+
# only showing top 40 rows

# %% [markdown]
# After we compute the similarity between entities, we can compare if they are really the same entity by inspecting individual outputs.
# For example let see this two entities which were found very similar (similarity equals to 2): ``1388230409`` and ``1388230392``. Looking at the rows we can see they are actually the same, the only thing that have changed is the violation_code. So it may be a human error while introducing the data. In this case we should rremove one of the entries.

# %%
parking_df.where((parking_df['summons_number'] == '1388230409') | \
	(parking_df['summons_number'] == '1388230392')). \
	show()
# Out:
# +--------------+----------+--------------+----------------+---------------------+------------------+------------------+--------------+-------------------+------------+-----------+--------------+---------------+--------------+--------+----------+------------------+-----------+-----------------+-------------+------------+------------+
# |summons_number|issue_date|violation_code|violation_county|violation_description|violation_location|violation_precinct|violation_time|time_first_observed|meter_number|issuer_code|issuer_command|issuer_precinct|issuing_agency|plate_id|plate_type|registration_state|street_name|vehicle_body_type|vehicle_color|vehicle_make|vehicle_year|
# +--------------+----------+--------------+----------------+---------------------+------------------+------------------+--------------+-------------------+------------+-----------+--------------+---------------+--------------+--------+----------+------------------+-----------+-----------------+-------------+------------+------------+
# |    1388230392|2016-03-13|            74|               K|                 null|                66|                66|         1159A|               null|           -|     932984|          0066|             66|             P| GTR2771|       PAS|                NY|     13 AVE|              SDN|           BK|         BMW|        2013|
# |    1388230409|2016-03-13|            70|               K|                 null|                66|                66|         1159A|               null|           -|     932984|          0066|             66|             P| GTR2771|       PAS|                NY|     13 AVE|              SDN|           BK|         BMW|        2013|
# +--------------+----------+--------------+----------------+---------------------+------------------+------------------+--------------+-------------------+------------+-----------+--------------+---------------+--------------+--------+----------+------------------+-----------+-----------------+-------------+------------+------------+

# %% [markdown]
# Analysing two more cases:

# %%
parking_df.where((parking_df['summons_number'] == '7372179002') | \
	(parking_df['summons_number'] == '7372178990')). \
	show()
# Out:
# +--------------+----------+--------------+----------------+---------------------+------------------+------------------+--------------+-------------------+------------+-----------+--------------+---------------+--------------+--------+----------+------------------+-----------+-----------------+-------------+------------+------------+
# |summons_number|issue_date|violation_code|violation_county|violation_description|violation_location|violation_precinct|violation_time|time_first_observed|meter_number|issuer_code|issuer_command|issuer_precinct|issuing_agency|plate_id|plate_type|registration_state|street_name|vehicle_body_type|vehicle_color|vehicle_make|vehicle_year|
# +--------------+----------+--------------+----------------+---------------------+------------------+------------------+--------------+-------------------+------------+-----------+--------------+---------------+--------------+--------+----------+------------------+-----------+-----------------+-------------+------------+------------+
# |    7372178990|2016-03-11|            70|               K| 70B-Impropr Dsply...|                61|                61|         0932A|               null|        null|     362602|          T302|             61|             T| HDC6978|       PAS|                NY|  E 15th St|             SUBN|          RED|       HONDA|        2002|
# |    7372179002|2016-03-11|            71|               K| 71-Insp. Sticker ...|                61|                61|         0934A|               null|        null|     362602|          T302|             61|             T| HDC6978|       PAS|                NY|  E 15th St|             SUBN|          RED|       HONDA|        2002|
# +--------------+----------+--------------+----------------+---------------------+------------------+------------------+--------------+-------------------+------------+-----------+--------------+---------------+--------------+--------+----------+------------------+-----------+-----------------+-------------+------------+------------+

# %%
parking_df.where((parking_df['summons_number'] == '7372180715') | \
	(parking_df['summons_number'] == '7372180703')). \
	show()
# Out:
# +--------------+----------+--------------+----------------+---------------------+------------------+------------------+--------------+-------------------+------------+-----------+--------------+---------------+--------------+--------+----------+------------------+-----------+-----------------+-------------+------------+------------+
# |summons_number|issue_date|violation_code|violation_county|violation_description|violation_location|violation_precinct|violation_time|time_first_observed|meter_number|issuer_code|issuer_command|issuer_precinct|issuing_agency|plate_id|plate_type|registration_state|street_name|vehicle_body_type|vehicle_color|vehicle_make|vehicle_year|
# +--------------+----------+--------------+----------------+---------------------+------------------+------------------+--------------+-------------------+------------+-----------+--------------+---------------+--------------+--------+----------+------------------+-----------+-----------------+-------------+------------+------------+
# |    7372180703|2016-03-17|            74|               K| 74-Missing Displa...|                61|                61|         0920A|               null|        null|     362602|          T302|             61|             T| GKK7643|       PAS|                NY|   E 7th St|             2DSD|           WH|         BMW|        2014|
# |    7372180715|2016-03-17|            71|               K| 71-Insp. Sticker ...|                61|                61|         0922A|               null|        null|     362602|          T302|             61|             T| GKK7643|       PAS|                NY|   E 7th St|             2DSD|           WH|         BMW|        2014|
# +--------------+----------+--------------+----------------+---------------------+------------------+------------------+--------------+-------------------+------------+-----------+--------------+---------------+--------------+--------+----------+------------------+-----------+-----------------+-------------+------------+------------+
# 23/04/20 02:57:03 WARN org.apache.spark.scheduler.cluster.YarnSchedulerBackend$YarnSchedulerEndpoint: Requesting driver to remove executor 2 for reason Container marked as failed: container_e02_1679692348553_19484_01_000002 on host: nyu-dataproc-sw-v05q.c.hpc-dataproc-19b8.internal. Exit status: -100. Diagnostics: Container released on a *lost* node.
# 23/04/20 02:57:03 ERROR org.apache.spark.scheduler.cluster.YarnScheduler: Lost executor 2 on nyu-dataproc-sw-v05q.c.hpc-dataproc-19b8.internal: Container marked as failed: container_e02_1679692348553_19484_01_000002 on host: nyu-dataproc-sw-v05q.c.hpc-dataproc-19b8.internal. Exit status: -100. Diagnostics: Container released on a *lost* node.

# %% [markdown]
# To fix all the issues, we may want to remove entities which has a mean similarity values less than 25. This measure was found looking at the stadistics.

# %%
# Show the statistics
res.select(res['similarity']).describe().show()
# Out:
# [Stage 274:>                                                        (0 + 1) / 1]
# +-------+------------------+
# |summary|        similarity|
# +-------+------------------+
# |  count|             79800|
# |   mean|25.613032581453634|
# | stddev| 6.093391357837535|
# |    min|                 2|
# |    max|                45|
# +-------+------------------+
